# %%
import requests
import time
import json
import os

import pandas as pd
import boto3
import awswrangler as wr

from bs4 import BeautifulSoup

# %% [markdown]
# # Get the list of IMO numbers from the database

# %%
DATABASE = ""
TABLE = ""
OUTPUT_LOCATION = ""

# %%
my_session = boto3.session.Session(
    region_name=os.environ['REGION'], 
    aws_access_key_id=os.environ['ACCESS_KEY'], 
    aws_secret_access_key=os.environ['SECRET']
)

# %%
query = f"""
    WITH latest_versions AS (
        SELECT CAST(year AS INTEGER) AS year, MAX(CAST(version AS INTEGER)) AS latest_version
        FROM "{DATABASE}"."{TABLE}"
        GROUP BY CAST(year AS INTEGER)
    ),

    latest_data AS (
        SELECT *
        FROM "{DATABASE}"."{TABLE}" se
        JOIN latest_versions lv
        ON CAST(se.year AS INT) = lv.year
        AND CAST(se.version AS INT) = lv.latest_version
    )
    
    SELECT DISTINCT(imo_number) FROM latest_data;
"""

# %%
distinc_imo_numbers = wr.athena.read_sql_query(query, database=DATABASE, boto3_session=my_session)

# %%
distinc_imo_numbers.head()
# Out:
#    imo_number
# 0     7037806
# 1     7128332
# 2     7305253
# 3     7310507
# 4     7349039

# %%
distinc_imo_numbers.shape
# Out:
# (21014, 1)

# %% [markdown]
# # Load the AIS ship data from Kaggle

# %%
df1 = pd.read_csv('../data/raw/ais_data.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0       mmsi navigationalstatus  sog    cog  heading     shiptype  \
# 0           0  219019621      Unknown value  0.0   86.0     86.0      Fishing
# 1           1  265628170      Unknown value  0.0  334.5      NaN  Port tender
# 2           2  219005719      Unknown value  0.0  208.7      NaN      Fishing
# 3           3  219028066      Unknown value  0.0    NaN      NaN     Pleasure
# 4           4  212584000             Moored  0.0  153.0    106.0        Cargo
#
#    width  length  draught
# 0    4.0     9.0      NaN
# 1    8.0    27.0      NaN
# 2    4.0    11.0      NaN
# 3    3.0    12.0      NaN
# 4   13.0    99.0      6.3

# %%
df1.shape
# Out:
# (358351, 10)

# %%
df1['mmsi'].nunique()
# Out:
# 3894

# %%
df2 = pd.read_csv('../data/raw/AIS_UNACORN_Seatracks_past12-hours.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0    cog   sog  beam callsign       cargo  heading  imonumber  \
# 0           0   64.0  11.0  65.0   9V9123  0-AllShips     64.0  9532599.0
# 1           1   65.4  12.1  65.0   9V9123  0-AllShips     64.0  9532599.0
# 2           2  323.0  14.1  35.0    V7QX3  0-AllShips    320.0  9813113.0
# 3           3  339.8  19.8  32.0     HOMQ  0-AllShips    342.0  9536818.0
# 4           4  337.8  10.7  32.0    V7JI6  0-AllShips    338.0  9712709.0
#
#     latitude  length   longitude       mmsi           name  \
# 0 -25.420000   360.0   84.633333  563950000  Yuan Zhuo Hai
# 1 -25.294915   360.0   84.933403  563950000  Yuan Zhuo Hai
# 2 -24.770147   228.0  106.331890  538008009     Barramundi
# 3 -24.511267   199.0  111.501532  371158000    Gaia Leader
# 4 -25.042857   199.0  111.283643  538006056     Star Lutas
#
#             navstatus   timeoffix vesseltype        date
# 0  0-Underway(Engine)  1607606344    7-Cargo  2020-12-10
# 1  0-Underway(Engine)  1607611680    7-Cargo  2020-12-10
# 2  0-Underway(Engine)  1607611196    7-Cargo  2020-12-10
# 3  0-Underway(Engine)  1607611210    7-Cargo  2020-12-10
# 4  0-Underway(Engine)  1607611211    7-Cargo  2020-12-10

# %%
df2.shape
# Out:
# (103997, 17)

# %%
df2['imonumber'].nunique()
# Out:
# 13577

# %%
df2['imonumber'] = df2['imonumber'].fillna(0)
df2['imonumber'] = df2['imonumber'].astype(int)

# %% [markdown]
# # Filter Kaggle dataset for the ships I have in database

# %%
thetis_ships = df2[df2['imonumber'].isin(distinc_imo_numbers['imo_number'].to_list())].copy()

# %%
thetis_ships.drop(['Unnamed: 0', 'latitude', 'longitude', 'navstatus', 'timeoffix', 'date', 'cog', 'sog', 'heading'], axis=1, inplace=True)

# %%
thetis_ships.head()
# Out:
#     beam callsign       cargo  imonumber  length       mmsi              name  \
# 3   32.0     HOMQ  0-AllShips    9536818   199.0  371158000       Gaia Leader
# 4   32.0    V7JI6  0-AllShips    9712709   199.0  538006056        Star Lutas
# 5   25.0    A8YA2   2-HazCatB    9459539   155.0  636015005  M/t Stolt Ocelot
# 7   32.0    V7MD5  0-AllShips    9280770   225.0  538002838        Anna Smile
# 10  32.0    3ELT6  0-AllShips    9738820   200.0  374875000       Nord Bering
#
#    vesseltype
# 3     7-Cargo
# 4     7-Cargo
# 5    8-Tanker
# 7     7-Cargo
# 10    7-Cargo

# %%
thetis_ships.shape
# Out:
# (8646, 8)

# %%
thetis_ships.duplicated().value_counts()
# Out:
# True     4934
# False    3712
# dtype: int64

# %%
thetis_ships.drop_duplicates(subset=['imonumber'], inplace=True)

# %%
thetis_ships.shape
# Out:
# (3704, 8)

# %%
thetis_ships['imonumber'].nunique()
# Out:
# 3704

# %%
thetis_ships.head()
# Out:
#     beam callsign       cargo  imonumber  length       mmsi              name  \
# 3   32.0     HOMQ  0-AllShips    9536818   199.0  371158000       Gaia Leader
# 4   32.0    V7JI6  0-AllShips    9712709   199.0  538006056        Star Lutas
# 5   25.0    A8YA2   2-HazCatB    9459539   155.0  636015005  M/t Stolt Ocelot
# 7   32.0    V7MD5  0-AllShips    9280770   225.0  538002838        Anna Smile
# 10  32.0    3ELT6  0-AllShips    9738820   200.0  374875000       Nord Bering
#
#    vesseltype
# 3     7-Cargo
# 4     7-Cargo
# 5    8-Tanker
# 7     7-Cargo
# 10    7-Cargo

# %%
thetis_ships.set_index('imonumber', inplace=True)

# %%
thetis_ships.to_json('../data/raw/kaggle_ship_data.json', orient="index", indent=4)

# %%
thetis_ships = json.loads(thetis_ships.to_json(orient="index"))

# %%
thetis_ships
# Out:
# {'9536818': {'beam': 32.0,
#   'callsign': 'HOMQ',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 371158000,
#   'name': 'Gaia Leader',
#   'vesseltype': '7-Cargo'},
#  '9712709': {'beam': 32.0,
#   'callsign': 'V7JI6',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 538006056,
#   'name': 'Star Lutas',
#   'vesseltype': '7-Cargo'},
#  '9459539': {'beam': 25.0,
#   'callsign': 'A8YA2',
#   'cargo': '2-HazCatB',
#   'length': 155.0,
#   'mmsi': 636015005,
#   'name': 'M/t Stolt Ocelot',
#   'vesseltype': '8-Tanker'},
#  '9280770': {'beam': 32.0,
#   'callsign': 'V7MD5',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 538002838,
#   'name': 'Anna Smile',
#   'vesseltype': '7-Cargo'},
#  '9738820': {'beam': 32.0,
#   'callsign': '3ELT6',
#   'cargo': '0-AllShips',
#   'length': 200.0,
#   'mmsi': 374875000,
#   'name': 'Nord Bering',
#   'vesseltype': '7-Cargo'},
#  '9188154': {'beam': 40.0,
#   'callsign': '3FZA9',
#   'cargo': '0-AllShips',
#   'length': 285.0,
#   'mmsi': 351934000,
#   'name': 'Ever Utile',
#   'vesseltype': '7-Cargo'},
#  '9687203': {'beam': 32.0,
#   'callsign': '3FJV',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 371222000,
#   'name': 'Global Splendour',
#   'vesseltype': '7-Cargo'},
#  '9282962': {'beam': 32.0,
#   'callsign': 'V7IG8',
#   'cargo': '0-AllShips',
#   'length': 294.0,
#   'mmsi': 538005938,
#   'name': 'Tianjin Bridge',
#   'vesseltype': '7-Cargo'},
#  '9464405': {'beam': 32.0,
#   'callsign': '3ERR6',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 370150000,
#   'name': 'Coral Ruby',
#   'vesseltype': '7-Cargo'},
#  '9473755': {'beam': 29.0,
#   'callsign': 'HORG',
#   'cargo': '0-AllShips',
#   'length': 178.0,
#   'mmsi': 354706000,
#   'name': 'Coreship Ol',
#   'vesseltype': '7-Cargo'},
#  '9865568': {'beam': 32.0,
#   'callsign': '3FTP5',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 353184000,
#   'name': 'Majestic Star',
#   'vesseltype': '7-Cargo'},
#  '9564279': {'beam': 45.0,
#   'callsign': 'D5XX8',
#   'cargo': '9-NoInfo',
#   'length': 288.0,
#   'mmsi': 636020152,
#   'name': 'Mount Song',
#   'vesseltype': '7-Cargo'},
#  '9767546': {'beam': 29.0,
#   'callsign': 'D5LV9',
#   'cargo': '0-AllShips',
#   'length': 179.0,
#   'mmsi': 636092730,
#   'name': 'Lefkada',
#   'vesseltype': '7-Cargo'},
#  '9629665': {'beam': 30.0,
#   'callsign': '3FZM9',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 373797000,
#   'name': 'Dl Jasmine',
#   'vesseltype': '7-Cargo'},
#  '9705079': {'beam': 49.0,
#   'callsign': '9HA3845',
#   'cargo': '1-HazCatA',
#   'length': 300.0,
#   'mmsi': 256163000,
#   'name': 'Cma Cgm Ural',
#   'vesseltype': '7-Cargo'},
#  '9357212': {'beam': 21.0,
#   'callsign': 'V2CN9',
#   'cargo': '9-NoInfo',
#   'length': 138.0,
#   'mmsi': 305057000,
#   'name': 'Bbc Delaware',
#   'vesseltype': '7-Cargo'},
#  '9558244': {'beam': 32.0,
#   'callsign': '9HA3054',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 229081000,
#   'name': 'Atlantic Elm',
#   'vesseltype': '7-Cargo'},
#  '9286592': {'beam': 32.0,
#   'callsign': '9HA3445',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 229609000,
#   'name': 'Thalassini',
#   'vesseltype': '7-Cargo'},
#  '9671448': {'beam': 19.0,
#   'callsign': 'PCXF',
#   'cargo': '9-NoInfo',
#   'length': 111.0,
#   'mmsi': 244810443,
#   'name': 'Eemslift Dafne',
#   'vesseltype': '7-Cargo'},
#  '9258612': {'beam': 32.0,
#   'callsign': 'LAYA7',
#   'cargo': '9-NoInfo',
#   'length': 182.0,
#   'mmsi': 258749000,
#   'name': 'Thelma    Victory',
#   'vesseltype': '8-Tanker'},
#  '9144407': {'beam': 32.0,
#   'callsign': 'C6OT4',
#   'cargo': '0-AllShips',
#   'length': 200.0,
#   'mmsi': 309823000,
#   'name': 'Plover Arrow',
#   'vesseltype': '7-Cargo'},
#  '9859789': {'beam': 32.0,
#   'callsign': '8PAS2',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 314482000,
#   'name': 'Gramos',
#   'vesseltype': '7-Cargo'},
#  '9514353': {'beam': 32.0,
#   'callsign': '3FUZ9',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 351224000,
#   'name': 'Serene Sky',
#   'vesseltype': '7-Cargo'},
#  '9599078': {'beam': 38.0,
#   'callsign': '3FAI7',
#   'cargo': '0-AllShips',
#   'length': 240.0,
#   'mmsi': 352593000,
#   'name': 'Am Liberia',
#   'vesseltype': '7-Cargo'},
#  '9625932': {'beam': 42.0,
#   'callsign': '3EYT6',
#   'cargo': '0-AllShips',
#   'length': 253.0,
#   'mmsi': 356440000,
#   'name': 'Msc Magali',
#   'vesseltype': '7-Cargo'},
#  '9678329': {'beam': 32.0,
#   'callsign': '3EZP9',
#   'cargo': '0-AllShips',
#   'length': 200.0,
#   'mmsi': 357396000,
#   'name': 'Navios La Paix',
#   'vesseltype': '7-Cargo'},
#  '9478834': {'beam': 43.0,
#   'callsign': '3EVY2',
#   'cargo': '0-AllShips',
#   'length': 240.0,
#   'mmsi': 373784000,
#   'name': 'Jubilant Success',
#   'vesseltype': '7-Cargo'},
#  '9620621': {'beam': 32.0,
#   'callsign': '3EYK2',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 373948000,
#   'name': 'Coral Amethyst',
#   'vesseltype': '7-Cargo'},
#  '9620516': {'beam': 43.0,
#   'callsign': 'BOUM',
#   'cargo': '0-AllShips',
#   'length': 254.0,
#   'mmsi': 414073000,
#   'name': 'He Hua Hai',
#   'vesseltype': '7-Cargo'},
#  '9706530': {'beam': 32.0,
#   'callsign': 'V7XC8',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 538007139,
#   'name': 'Alma',
#   'vesseltype': '7-Cargo'},
#  '9473274': {'beam': 33.0,
#   'callsign': 'V7AZ8',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 538007994,
#   'name': 'Spring Snow',
#   'vesseltype': '7-Cargo'},
#  '9867176': {'beam': 32.0,
#   'callsign': 'V7A2447',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 538008510,
#   'name': 'Jy London',
#   'vesseltype': '7-Cargo'},
#  '9744520': {'beam': 32.0,
#   'callsign': '9V5164',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 563027400,
#   'name': 'Bulk Venus',
#   'vesseltype': '7-Cargo'},
#  '9376359': {'beam': 32.0,
#   'callsign': 'A8MN6',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 636013382,
#   'name': 'Marielena',
#   'vesseltype': '7-Cargo'},
#  '9294501': {'beam': 32.0,
#   'callsign': 'D5IQ2',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 636016964,
#   'name': 'Blessed Luck',
#   'vesseltype': '7-Cargo'},
#  '9709465': {'beam': 30.0,
#   'callsign': 'D5KB7',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 636017264,
#   'name': 'Alkyonis',
#   'vesseltype': '7-Cargo'},
#  '9375941': {'beam': 32.0,
#   'callsign': 'D5PA7',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 636018288,
#   'name': 'Pelagic',
#   'vesseltype': '7-Cargo'},
#  '9832547': {'beam': 44.0,
#   'callsign': 'D5QR4',
#   'cargo': '0-AllShips',
#   'length': 250.0,
#   'mmsi': 636018645,
#   'name': 'Crudemed',
#   'vesseltype': '8-Tanker'},
#  '9618812': {'beam': 45.0,
#   'callsign': 'D5RQ7',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636018845,
#   'name': 'Aquanavigator',
#   'vesseltype': '7-Cargo'},
#  '9524669': {'beam': 29.0,
#   'callsign': '3FVL8',
#   'cargo': '0-AllShips',
#   'length': 175.0,
#   'mmsi': 371229000,
#   'name': 'Cactus K',
#   'vesseltype': '7-Cargo'},
#  '9865740': {'beam': 32.0,
#   'callsign': 'V7A2637',
#   'cargo': '1-HazCatA',
#   'length': 183.0,
#   'mmsi': 538008665,
#   'name': 'Jason',
#   'vesseltype': '8-Tanker'},
#  '9719343': {'beam': 30.0,
#   'callsign': '3FKU5',
#   'cargo': '0-AllShips',
#   'length': 182.0,
#   'mmsi': 357254000,
#   'name': 'Ts Challenge',
#   'vesseltype': '7-Cargo'},
#  '9835850': {'beam': 48.0,
#   'callsign': '9V5871',
#   'cargo': '5-Reserved',
#   'length': 274.0,
#   'mmsi': 563072100,
#   'name': 'Marlin Somerset',
#   'vesseltype': '8-Tanker'},
#  '9385154': {'beam': 29.0,
#   'callsign': 'V7UN3',
#   'cargo': '0-AllShips',
#   'length': 175.0,
#   'mmsi': 538007096,
#   'name': 'Super Kate',
#   'vesseltype': '7-Cargo'},
#  '9315707': {'beam': 44.0,
#   'callsign': 'C6UU9',
#   'cargo': '1-HazCatA',
#   'length': 288.0,
#   'mmsi': 308136000,
#   'name': 'Grace Acacia',
#   'vesseltype': '8-Tanker'},
#  '9855501': {'beam': 32.0,
#   'callsign': 'DUJZ',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 548978000,
#   'name': 'Aquavita Sun',
#   'vesseltype': '7-Cargo'},
#  '9566411': {'beam': 32.0,
#   'callsign': '3FGS',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 373665000,
#   'name': 'Xin Xiang Hai',
#   'vesseltype': '7-Cargo'},
#  '9690107': {'beam': 30.0,
#   'callsign': 'D5LR9',
#   'cargo': '9-NoInfo',
#   'length': 185.0,
#   'mmsi': 636092711,
#   'name': 'Seatrade Red',
#   'vesseltype': '7-Cargo'},
#  '9510371': {'beam': 32.0,
#   'callsign': 'A8PP2',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 636013805,
#   'name': 'La Charmais',
#   'vesseltype': '7-Cargo'},
#  '9384851': {'beam': 27.0,
#   'callsign': 'VRCT4',
#   'cargo': '0-AllShips',
#   'length': 169.0,
#   'mmsi': 477768700,
#   'name': 'Taihua Star',
#   'vesseltype': '7-Cargo'},
#  '9424209': {'beam': 60.0,
#   'callsign': 'A8UA7',
#   'cargo': '0-AllShips',
#   'length': 340.0,
#   'mmsi': 636014465,
#   'name': 'Cosmo Ace',
#   'vesseltype': '8-Tanker'},
#  '9476630': {'beam': 45.0,
#   'callsign': 'V7A2148',
#   'cargo': '0-AllShips',
#   'length': 290.0,
#   'mmsi': 538008254,
#   'name': 'Mineral Brussel',
#   'vesseltype': '7-Cargo'},
#  '9744013': {'beam': 46.0,
#   'callsign': 'ZCEW4',
#   'cargo': '2-HazCatB',
#   'length': 293.0,
#   'mmsi': 310774000,
#   'name': 'Gaslog Genoa',
#   'vesseltype': '8-Tanker'},
#  '9522697': {'beam': 46.0,
#   'callsign': '9V9079',
#   'cargo': '0-AllShips',
#   'length': 295.0,
#   'mmsi': 565491000,
#   'name': 'Stella Alice',
#   'vesseltype': '7-Cargo'},
#  '9419369': {'beam': 44.0,
#   'callsign': 'A8SA2',
#   'cargo': '0-AllShips',
#   'length': 250.0,
#   'mmsi': 636014184,
#   'name': 'Amfitriti',
#   'vesseltype': '8-Tanker'},
#  '9887621': {'beam': 32.0,
#   'callsign': '9V6486',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 563113600,
#   'name': 'Pratincole Pacific',
#   'vesseltype': '8-Tanker'},
#  '9726516': {'beam': 32.0,
#   'callsign': '3ERH8',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 356752000,
#   'name': 'Kmarin Oslo',
#   'vesseltype': '7-Cargo'},
#  '9794771': {'beam': 20.0,
#   'callsign': '9V5120',
#   'cargo': '0-AllShips',
#   'length': 109.0,
#   'mmsi': 563007500,
#   'name': 'Lilstella',
#   'vesseltype': '8-Tanker'},
#  '9636747': {'beam': 44.0,
#   'callsign': '9HA3424',
#   'cargo': '4-HazCatD',
#   'length': 294.0,
#   'mmsi': 229583000,
#   'name': 'Yari Lng',
#   'vesseltype': '8-Tanker'},
#  '9598139': {'beam': 45.0,
#   'callsign': 'HOQV',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 355979000,
#   'name': 'Frontier Phoenix',
#   'vesseltype': '7-Cargo'},
#  '9718686': {'beam': 32.0,
#   'callsign': 'V7MM2',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 538006383,
#   'name': 'Vulcania',
#   'vesseltype': '7-Cargo'},
#  '9717254': {'beam': 27.0,
#   'callsign': '3ENV6',
#   'cargo': '0-AllShips',
#   'length': 169.0,
#   'mmsi': 356339000,
#   'name': 'Belle Etoile',
#   'vesseltype': '7-Cargo'},
#  '9636694': {'beam': 32.0,
#   'callsign': 'FIHZ',
#   'cargo': '9-NoInfo',
#   'length': 183.0,
#   'mmsi': 228037800,
#   'name': 'Kiribora',
#   'vesseltype': '8-Tanker'},
#  '9646900': {'beam': 30.0,
#   'callsign': '9HA3385',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 229533000,
#   'name': 'La Richardais',
#   'vesseltype': '7-Cargo'},
#  '9858022': {'beam': 32.0,
#   'callsign': '3FLN5',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 374883000,
#   'name': 'Fj Viola',
#   'vesseltype': '7-Cargo'},
#  '9312339': {'beam': 27.0,
#   'callsign': 'VRZT6',
#   'cargo': '0-AllShips',
#   'length': 169.0,
#   'mmsi': 477522000,
#   'name': 'Cape Flattery',
#   'vesseltype': '7-Cargo'},
#  '9336012': {'beam': 45.0,
#   'callsign': 'D5OO7',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 636018188,
#   'name': 'Aquahope',
#   'vesseltype': '7-Cargo'},
#  '9537628': {'beam': 32.0,
#   'callsign': 'VRTA5',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 477401800,
#   'name': 'Xin Feng',
#   'vesseltype': '7-Cargo'},
#  '9708215': {'beam': 32.0,
#   'callsign': 'V7JZ6',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 538006130,
#   'name': 'Ardmore Seafox',
#   'vesseltype': '8-Tanker'},
#  '9309485': {'beam': 37.0,
#   'callsign': 'C4GF2',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 209317000,
#   'name': 'Cymona Star',
#   'vesseltype': '7-Cargo'},
#  '9460801': {'beam': 32.0,
#   'callsign': '3FWB3',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 352301000,
#   'name': 'Global King',
#   'vesseltype': '7-Cargo'},
#  '9748497': {'beam': 32.0,
#   'callsign': 'D5YF2',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 636020222,
#   'name': 'Indigo Jugem',
#   'vesseltype': '7-Cargo'},
#  '9493779': {'beam': 48.0,
#   'callsign': 'A8YB6',
#   'cargo': '0-AllShips',
#   'length': 275.0,
#   'mmsi': 636015015,
#   'name': 'Smyrni',
#   'vesseltype': '8-Tanker'},
#  '9322281': {'beam': 58.0,
#   'callsign': 'D5RW7',
#   'cargo': '0-AllShips',
#   'length': 332.0,
#   'mmsi': 636018894,
#   'name': 'Daishan',
#   'vesseltype': '8-Tanker'},
#  '9742390': {'beam': 23.0,
#   'callsign': '3EZI8',
#   'cargo': '0-AllShips',
#   'length': 132.0,
#   'mmsi': 351308000,
#   'name': 'Thorco Lanner',
#   'vesseltype': '7-Cargo'},
#  '9470923': {'beam': 45.0,
#   'callsign': 'SWIB',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 240706000,
#   'name': 'Maran Happiness',
#   'vesseltype': '7-Cargo'},
#  '9839076': {'beam': 32.0,
#   'callsign': '3EZA8',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 354437000,
#   'name': 'Dream Sky',
#   'vesseltype': '7-Cargo'},
#  '9702584': {'beam': 45.0,
#   'callsign': '9HA4259',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 249476000,
#   'name': 'Gortynia',
#   'vesseltype': '7-Cargo'},
#  '9435129': {'beam': 21.0,
#   'callsign': 'V2DK9',
#   'cargo': '0-AllShips',
#   'length': 138.0,
#   'mmsi': 305246000,
#   'name': 'Jannes',
#   'vesseltype': '7-Cargo'},
#  '9545297': {'beam': 45.0,
#   'callsign': '3FFH3',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 353267000,
#   'name': 'Pan Margaret',
#   'vesseltype': '7-Cargo'},
#  '9501851': {'beam': 45.0,
#   'callsign': '3EVK',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 370640000,
#   'name': 'Giant Ace',
#   'vesseltype': '7-Cargo'},
#  '9552422': {'beam': 45.0,
#   'callsign': 'HOHI',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 373508000,
#   'name': 'Southern Harmony',
#   'vesseltype': '7-Cargo'},
#  '9492335': {'beam': 45.0,
#   'callsign': 'V7QX8',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538003461,
#   'name': 'Baltic Wolf',
#   'vesseltype': '7-Cargo'},
#  '9427304': {'beam': 45.0,
#   'callsign': 'V7WI4',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538004299,
#   'name': 'Kate',
#   'vesseltype': '7-Cargo'},
#  '9278545': {'beam': 45.0,
#   'callsign': 'A8TY4',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 636014455,
#   'name': 'Andros Beauty',
#   'vesseltype': '7-Cargo'},
#  '9747883': {'beam': 45.0,
#   'callsign': 'D5VC5',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636019569,
#   'name': 'True Captain',
#   'vesseltype': '7-Cargo'},
#  '9401960': {'beam': 32.0,
#   'callsign': '5BPR4',
#   'cargo': '9-NoInfo',
#   'length': 225.0,
#   'mmsi': 209012000,
#   'name': 'Astraea Sb',
#   'vesseltype': '7-Cargo'},
#  '9509968': {'beam': 19.0,
#   'callsign': 'PBUS',
#   'cargo': '0-AllShips',
#   'length': 137.0,
#   'mmsi': 246619000,
#   'name': 'Floragracht',
#   'vesseltype': '7-Cargo'},
#  '9881366': {'beam': 32.0,
#   'callsign': 'H9CH',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 374462000,
#   'name': 'Aom Sophie Ii',
#   'vesseltype': '7-Cargo'},
#  '9523158': {'beam': 32.0,
#   'callsign': 'BRPC',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 412859000,
#   'name': 'Yue Guan Feng',
#   'vesseltype': '7-Cargo'},
#  '9608312': {'beam': 28.0,
#   'callsign': 'VRMA6',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 477463100,
#   'name': 'Da Kang',
#   'vesseltype': '7-Cargo'},
#  '9611747': {'beam': 46.0,
#   'callsign': 'VRNI9',
#   'cargo': '0-AllShips',
#   'length': 295.0,
#   'mmsi': 477694700,
#   'name': 'Cs Salubrity',
#   'vesseltype': '7-Cargo'},
#  '9602411': {'beam': 32.0,
#   'callsign': 'V7WH7',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 538007088,
#   'name': 'Billy Jim',
#   'vesseltype': '7-Cargo'},
#  '9836476': {'beam': 32.0,
#   'callsign': '9V6304',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 563082500,
#   'name': 'Bw Kobe',
#   'vesseltype': '7-Cargo'},
#  '9696527': {'beam': 32.0,
#   'callsign': 'D5GL9',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 636016499,
#   'name': 'Diomidis',
#   'vesseltype': '7-Cargo'},
#  '9880300': {'beam': 32.0,
#   'callsign': 'D5TZ3',
#   'cargo': '0-AllShips',
#   'length': 228.0,
#   'mmsi': 636019322,
#   'name': 'Cl Daliao He',
#   'vesseltype': '7-Cargo'},
#  '9832925': {'beam': 45.0,
#   'callsign': 'D5UB9',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636019347,
#   'name': 'Am Kirti',
#   'vesseltype': '7-Cargo'},
#  '9548237': {'beam': 38.0,
#   'callsign': 'D5BJ8',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 636015536,
#   'name': 'Clia',
#   'vesseltype': '7-Cargo'},
#  '9403619': {'beam': 40.0,
#   'callsign': 'V7NH8',
#   'cargo': '1-HazCatA',
#   'length': 292.0,
#   'mmsi': 538002961,
#   'name': 'Mol Proficiency',
#   'vesseltype': '7-Cargo'},
#  '9407500': {'beam': 32.0,
#   'callsign': 'D5AD4',
#   'cargo': '9-NoInfo',
#   'length': 190.0,
#   'mmsi': 636092302,
#   'name': 'Anna-barbara',
#   'vesseltype': '7-Cargo'},
#  '9603805': {'beam': 32.0,
#   'callsign': 'LAQO7',
#   'cargo': '0-AllShips',
#   'length': 204.0,
#   'mmsi': 258007000,
#   'name': 'Star Luster',
#   'vesseltype': '7-Cargo'},
#  '9826122': {'beam': 60.0,
#   'callsign': '9HA4741',
#   'cargo': '0-AllShips',
#   'length': 333.0,
#   'mmsi': 248644000,
#   'name': 'Maria P. Lemos',
#   'vesseltype': '8-Tanker'},
#  '9726504': {'beam': 32.0,
#   'callsign': '3FPE8',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 354709000,
#   'name': 'Kmarin Genoa',
#   'vesseltype': '7-Cargo'},
#  '9650133': {'beam': 33.0,
#   'callsign': '3FAA9',
#   'cargo': '0-AllShips',
#   'length': 197.0,
#   'mmsi': 356875000,
#   'name': 'Kouyou',
#   'vesseltype': '7-Cargo'},
#  '9409247': {'beam': 60.0,
#   'callsign': 'V7RY6',
#   'cargo': '9-NoInfo',
#   'length': 333.0,
#   'mmsi': 538003603,
#   'name': 'Athenian Victory',
#   'vesseltype': '8-Tanker'},
#  '9840453': {'beam': 62.0,
#   'callsign': 'V7A2853',
#   'cargo': '0-AllShips',
#   'length': 340.0,
#   'mmsi': 538008868,
#   'name': 'Sao Neptune',
#   'vesseltype': '7-Cargo'},
#  '9398137': {'beam': 50.0,
#   'callsign': '3FJR5',
#   'cargo': '0-AllShips',
#   'length': 300.0,
#   'mmsi': 354043000,
#   'name': 'Onozuru Maru',
#   'vesseltype': '7-Cargo'},
#  '9702510': {'beam': 32.0,
#   'callsign': 'V7LM4',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 538006298,
#   'name': 'Cp Shanghai',
#   'vesseltype': '7-Cargo'},
#  '9719393': {'beam': 30.0,
#   'callsign': 'V7HP8',
#   'cargo': '0-AllShips',
#   'length': 182.0,
#   'mmsi': 538007114,
#   'name': 'Ts Honour',
#   'vesseltype': '7-Cargo'},
#  '9507960': {'beam': 32.0,
#   'callsign': 'V7YH3',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 538007182,
#   'name': 'Sasebo Ace',
#   'vesseltype': '7-Cargo'},
#  '9608221': {'beam': 33.0,
#   'callsign': '3FOL9',
#   'cargo': '0-AllShips',
#   'length': 210.0,
#   'mmsi': 351251000,
#   'name': 'Water Lily',
#   'vesseltype': '7-Cargo'},
#  '9713167': {'beam': 30.0,
#   'callsign': '2IKK4',
#   'cargo': '2-HazCatB',
#   'length': 180.0,
#   'mmsi': 235110509,
#   'name': 'Berge Hakodate',
#   'vesseltype': '7-Cargo'},
#  '9875111': {'beam': 45.0,
#   'callsign': 'H3QA',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 353549000,
#   'name': 'Bulk Ginza',
#   'vesseltype': '7-Cargo'},
#  '9747948': {'beam': 45.0,
#   'callsign': '3FLT7',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 374126000,
#   'name': 'Navios Corali',
#   'vesseltype': '7-Cargo'},
#  '9409493': {'beam': 32.0,
#   'callsign': 'VRNJ5',
#   'cargo': '9-NoInfo',
#   'length': 180.0,
#   'mmsi': 477694500,
#   'name': 'Diamond Express',
#   'vesseltype': '8-Tanker'},
#  '9473432': {'beam': 28.0,
#   'callsign': 'VRGE4',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 477744100,
#   'name': 'Maple Fortune',
#   'vesseltype': '7-Cargo'},
#  '9492232': {'beam': 45.0,
#   'callsign': 'V7UE7',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538003936,
#   'name': 'Christina J',
#   'vesseltype': '7-Cargo'},
#  '9580376': {'beam': 45.0,
#   'callsign': 'V7VA3',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538004070,
#   'name': 'Raiatea',
#   'vesseltype': '7-Cargo'},
#  '9469003': {'beam': 45.0,
#   'callsign': 'A8VL8',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636014624,
#   'name': 'Bulk Mexico',
#   'vesseltype': '7-Cargo'},
#  '9410480': {'beam': 45.0,
#   'callsign': 'D5NU4',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636018016,
#   'name': 'Haralambos',
#   'vesseltype': '7-Cargo'},
#  '9241657': {'beam': 47.0,
#   'callsign': 'D5QJ2',
#   'cargo': '0-AllShips',
#   'length': 290.0,
#   'mmsi': 636018582,
#   'name': 'Agia Trias',
#   'vesseltype': '7-Cargo'},
#  '9774367': {'beam': 45.0,
#   'callsign': 'MAPG9',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 232006421,
#   'name': 'Berge Sarstein',
#   'vesseltype': '7-Cargo'},
#  '9238038': {'beam': 42.0,
#   'callsign': 'ZIPR7',
#   'cargo': '0-AllShips',
#   'length': 278.0,
#   'mmsi': 235496000,
#   'name': 'Trader',
#   'vesseltype': '8-Tanker'},
#  '9434383': {'beam': 45.0,
#   'callsign': 'SVBK7',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 241149000,
#   'name': 'Maran Glory',
#   'vesseltype': '7-Cargo'},
#  '9386512': {'beam': 45.0,
#   'callsign': '9HA2121',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 248005000,
#   'name': 'Robusto',
#   'vesseltype': '7-Cargo'},
#  '9702572': {'beam': 45.0,
#   'callsign': '9HA4258',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 249472000,
#   'name': 'Proti',
#   'vesseltype': '7-Cargo'},
#  '9546801': {'beam': 45.0,
#   'callsign': '3FVJ6',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 354124000,
#   'name': 'Am Port Cartier',
#   'vesseltype': '7-Cargo'},
#  '9747950': {'beam': 45.0,
#   'callsign': '3FIP6',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 374305000,
#   'name': 'Navios Mars',
#   'vesseltype': '7-Cargo'},
#  '9395202': {'beam': 45.0,
#   'callsign': 'BOCO',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 413543000,
#   'name': 'Nian Feng Hai',
#   'vesseltype': '7-Cargo'},
#  '9860063': {'beam': 50.0,
#   'callsign': 'BHCQ',
#   'cargo': '0-AllShips',
#   'length': 299.0,
#   'mmsi': 416051000,
#   'name': 'Csc Victor',
#   'vesseltype': '7-Cargo'},
#  '9738131': {'beam': 45.0,
#   'callsign': 'VRQL6',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 477023100,
#   'name': 'Xin Li Hai',
#   'vesseltype': '7-Cargo'},
#  '9611735': {'beam': 46.0,
#   'callsign': 'VRNF9',
#   'cargo': '0-AllShips',
#   'length': 295.0,
#   'mmsi': 477441200,
#   'name': 'Cs Grace',
#   'vesseltype': '7-Cargo'},
#  '9551727': {'beam': 45.0,
#   'callsign': 'V7JV7',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538007125,
#   'name': 'True Dream',
#   'vesseltype': '7-Cargo'},
#  '9453389': {'beam': 36.0,
#   'callsign': '5BGB3',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 209723000,
#   'name': 'Kastelli Wave',
#   'vesseltype': '7-Cargo'},
#  '9462512': {'beam': 45.0,
#   'callsign': '5BTD3',
#   'cargo': '9-NoInfo',
#   'length': 290.0,
#   'mmsi': 209765000,
#   'name': 'Eurydice D',
#   'vesseltype': '7-Cargo'},
#  '9457842': {'beam': 38.0,
#   'callsign': '9HA4928',
#   'cargo': '9-NoInfo',
#   'length': 229.0,
#   'mmsi': 215027000,
#   'name': 'Shuang Xi',
#   'vesseltype': '7-Cargo'},
#  '9750933': {'beam': 49.0,
#   'callsign': 'MAVT5',
#   'cargo': '0-AllShips',
#   'length': 300.0,
#   'mmsi': 232007360,
#   'name': 'Berge Toubkal',
#   'vesseltype': '7-Cargo'},
#  '9440332': {'beam': 45.0,
#   'callsign': 'SVBO2',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 241197000,
#   'name': 'Maran Virtue',
#   'vesseltype': '7-Cargo'},
#  '9423920': {'beam': 45.0,
#   'callsign': '9HA2168',
#   'cargo': '9-NoInfo',
#   'length': 292.0,
#   'mmsi': 248087000,
#   'name': 'Skythia',
#   'vesseltype': '7-Cargo'},
#  '9789685': {'beam': 26.0,
#   'callsign': 'CQAI9',
#   'cargo': '0-AllShips',
#   'length': 150.0,
#   'mmsi': 255806187,
#   'name': 'Uhl Frontier',
#   'vesseltype': '7-Cargo'},
#  '9620566': {'beam': 43.0,
#   'callsign': '3FMB',
#   'cargo': '0-AllShips',
#   'length': 254.0,
#   'mmsi': 370071000,
#   'name': 'Ma Lian Hai',
#   'vesseltype': '7-Cargo'},
#  '9377937': {'beam': 45.0,
#   'callsign': 'VRBR3',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 477099500,
#   'name': 'C H S Cosmos',
#   'vesseltype': '7-Cargo'},
#  '9701334': {'beam': 45.0,
#   'callsign': 'VRON9',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 477314600,
#   'name': 'Golden Aso',
#   'vesseltype': '7-Cargo'},
#  '9476848': {'beam': 45.0,
#   'callsign': 'V7QN2',
#   'cargo': '9-NoInfo',
#   'length': 292.0,
#   'mmsi': 538006721,
#   'name': 'Seattle',
#   'vesseltype': '7-Cargo'},
#  '9473183': {'beam': 35.0,
#   'callsign': 'V7SF5',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 538006860,
#   'name': 'Selina',
#   'vesseltype': '7-Cargo'},
#  '9743174': {'beam': 45.0,
#   'callsign': 'V7PR3',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538007732,
#   'name': 'Golden Calvus',
#   'vesseltype': '7-Cargo'},
#  '9311464': {'beam': 45.0,
#   'callsign': 'V7GA4',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 538008101,
#   'name': 'The Mothership',
#   'vesseltype': '7-Cargo'},
#  '9447770': {'beam': 32.0,
#   'callsign': 'V7A2418',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 538008487,
#   'name': 'Cedar Express',
#   'vesseltype': '8-Tanker'},
#  '9384954': {'beam': 45.0,
#   'callsign': 'V7A2916',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 538008929,
#   'name': 'Imperial Fortune',
#   'vesseltype': '7-Cargo'},
#  '9856490': {'beam': 50.0,
#   'callsign': 'V7A2948',
#   'cargo': '0-AllShips',
#   'length': 299.0,
#   'mmsi': 538008956,
#   'name': 'Golden Competence',
#   'vesseltype': '7-Cargo'},
#  '9618111': {'beam': 30.0,
#   'callsign': '9V9439',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 566211000,
#   'name': 'Soldoy',
#   'vesseltype': '7-Cargo'},
#  '9603439': {'beam': 50.0,
#   'callsign': '9V9450',
#   'cargo': '0-AllShips',
#   'length': 300.0,
#   'mmsi': 566662000,
#   'name': 'Cape Azalea',
#   'vesseltype': '7-Cargo'},
#  '9521394': {'beam': 45.0,
#   'callsign': 'D5EG2',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636016068,
#   'name': 'Indian Friendship',
#   'vesseltype': '7-Cargo'},
#  '9691931': {'beam': 50.0,
#   'callsign': 'D5GW2',
#   'cargo': '0-AllShips',
#   'length': 300.0,
#   'mmsi': 636016582,
#   'name': 'Lavinia Oldendorff',
#   'vesseltype': '7-Cargo'},
#  '9592783': {'beam': 45.0,
#   'callsign': 'D5MU6',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636017804,
#   'name': 'Attikos',
#   'vesseltype': '7-Cargo'},
#  '9735165': {'beam': 50.0,
#   'callsign': 'D5XZ4',
#   'cargo': '0-AllShips',
#   'length': 300.0,
#   'mmsi': 636020166,
#   'name': 'Maharaj',
#   'vesseltype': '7-Cargo'},
#  '9595670': {'beam': 32.0,
#   'callsign': 'VRKQ7',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 477978100,
#   'name': 'Darya Lok',
#   'vesseltype': '7-Cargo'},
#  '9830070': {'beam': 32.0,
#   'callsign': 'VRSM7',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 477286800,
#   'name': 'Cssc He Mei',
#   'vesseltype': '7-Cargo'},
#  '9659919': {'beam': 32.0,
#   'callsign': '9V2164',
#   'cargo': '9-NoInfo',
#   'length': 199.0,
#   'mmsi': 563335000,
#   'name': 'Orient Amabie',
#   'vesseltype': '7-Cargo'},
#  '9633147': {'beam': 38.0,
#   'callsign': '9V6294',
#   'cargo': '0-AllShips',
#   'length': 235.0,
#   'mmsi': 563081700,
#   'name': 'Cmb Chardonnay',
#   'vesseltype': '7-Cargo'},
#  '9425514': {'beam': 32.0,
#   'callsign': '9V6887',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 563113100,
#   'name': 'Ardmore Seafarer',
#   'vesseltype': '8-Tanker'},
#  '9355604': {'beam': 43.0,
#   'callsign': 'ZCDZ3',
#   'cargo': '1-HazCatA',
#   'length': 285.0,
#   'mmsi': 310594000,
#   'name': 'Gaslog Singapore',
#   'vesseltype': '8-Tanker'},
#  '9411290': {'beam': 32.0,
#   'callsign': 'A8VH8',
#   'cargo': '0-AllShips',
#   'length': 182.0,
#   'mmsi': 636014611,
#   'name': 'Team Calypso',
#   'vesseltype': '8-Tanker'},
#  '9785158': {'beam': 46.0,
#   'callsign': 'D5NT9',
#   'cargo': '0-AllShips',
#   'length': 295.0,
#   'mmsi': 636018011,
#   'name': 'Kinisis',
#   'vesseltype': '8-Tanker'},
#  '9507881': {'beam': 45.0,
#   'callsign': 'D5MM6',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636017738,
#   'name': 'Navios Aster',
#   'vesseltype': '7-Cargo'},
#  '9188908': {'beam': 30.0,
#   'callsign': '9HA3634',
#   'cargo': '0-AllShips',
#   'length': 186.0,
#   'mmsi': 229815000,
#   'name': 'Murgash',
#   'vesseltype': '7-Cargo'},
#  '9462471': {'beam': 46.0,
#   'callsign': 'D5BF9',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636092375,
#   'name': 'Edwin',
#   'vesseltype': '7-Cargo'},
#  '9198240': {'beam': 45.0,
#   'callsign': 'H3XI',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 357349000,
#   'name': 'Sunny Boke',
#   'vesseltype': '7-Cargo'},
#  '9639579': {'beam': 32.0,
#   'callsign': 'VRLL6',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 477319500,
#   'name': 'Cl Tiffany',
#   'vesseltype': '7-Cargo'},
#  '9624378': {'beam': 32.0,
#   'callsign': 'V7A2011',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 538008143,
#   'name': 'El Comino',
#   'vesseltype': '7-Cargo'},
#  '9515395': {'beam': 32.0,
#   'callsign': '9V9111',
#   'cargo': '0-AllShips',
#   'length': 265.0,
#   'mmsi': 566085000,
#   'name': 'Parsifal',
#   'vesseltype': '7-Cargo'},
#  '9743289': {'beam': 45.0,
#   'callsign': 'V7QM7',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538006933,
#   'name': 'Comanche',
#   'vesseltype': '7-Cargo'},
#  '9547001': {'beam': 32.0,
#   'callsign': '3FLR2',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 353532000,
#   'name': 'Green Phoenix',
#   'vesseltype': '7-Cargo'},
#  '9263112': {'beam': 32.0,
#   'callsign': 'V7A2220',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 538008307,
#   'name': 'Ella',
#   'vesseltype': '7-Cargo'},
#  '9299276': {'beam': 32.0,
#   'callsign': 'LAZR5',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 257323000,
#   'name': 'Spar Virgo',
#   'vesseltype': '7-Cargo'},
#  '9814181': {'beam': 32.0,
#   'callsign': '3FSH3',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 352802000,
#   'name': 'Beagle',
#   'vesseltype': '8-Tanker'},
#  '9357951': {'beam': 40.0,
#   'callsign': '9V8585',
#   'cargo': '0-AllShips',
#   'length': 287.0,
#   'mmsi': 563052200,
#   'name': 'Rio De La Plata',
#   'vesseltype': '7-Cargo'},
#  '9641857': {'beam': 38.0,
#   'callsign': 'D5DG3',
#   'cargo': '0-AllShips',
#   'length': 235.0,
#   'mmsi': 636015871,
#   'name': 'Serifos Warrior',
#   'vesseltype': '7-Cargo'},
#  '9762895': {'beam': 32.0,
#   'callsign': 'D5IZ5',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 636017034,
#   'name': 'Trammo Independent',
#   'vesseltype': '7-Cargo'},
#  '9583213': {'beam': 32.0,
#   'callsign': 'V7ZS5',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 538004903,
#   'name': 'Athinoula',
#   'vesseltype': '7-Cargo'},
#  '9593787': {'beam': 32.0,
#   'callsign': '3FGV',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 373515000,
#   'name': 'Zheng Kai',
#   'vesseltype': '7-Cargo'},
#  '9699036': {'beam': 32.0,
#   'callsign': 'D5HY7',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 636016819,
#   'name': 'Nautical Hilary',
#   'vesseltype': '7-Cargo'},
#  '9448827': {'beam': 32.0,
#   'callsign': '5BZS4',
#   'cargo': '1-HazCatA',
#   'length': 239.0,
#   'mmsi': 209278000,
#   'name': 'Hugo Schulte',
#   'vesseltype': '7-Cargo'},
#  '9800257': {'beam': 48.0,
#   'callsign': 'D5OQ5',
#   'cargo': '0-AllShips',
#   'length': 274.0,
#   'mmsi': 636018206,
#   'name': 'Kasos',
#   'vesseltype': '8-Tanker'},
#  '9837602': {'beam': 60.0,
#   'callsign': '3EMX6',
#   'cargo': '0-AllShips',
#   'length': 336.0,
#   'mmsi': 370289000,
#   'name': 'Universal Winner',
#   'vesseltype': '8-Tanker'},
#  '9242326': {'beam': 32.0,
#   'callsign': '9V2086',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 566915000,
#   'name': 'Mtm Manila',
#   'vesseltype': '8-Tanker'},
#  '9825532': {'beam': 32.0,
#   'callsign': 'C6DW5',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 311000802,
#   'name': 'Balos',
#   'vesseltype': '7-Cargo'},
#  '9705421': {'beam': 32.0,
#   'callsign': 'H9VR',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 357847000,
#   'name': 'Amis Elegance',
#   'vesseltype': '7-Cargo'},
#  '9713806': {'beam': 32.0,
#   'callsign': '3FDD5',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 374101000,
#   'name': 'Sakizaya Elegance',
#   'vesseltype': '7-Cargo'},
#  '9792462': {'beam': 32.0,
#   'callsign': '9V3544',
#   'cargo': '0-AllShips',
#   'length': 200.0,
#   'mmsi': 563040600,
#   'name': 'Sotka',
#   'vesseltype': '7-Cargo'},
#  '9718208': {'beam': 45.0,
#   'callsign': '9HA3921',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 256458000,
#   'name': 'Vittoria',
#   'vesseltype': '7-Cargo'},
#  '9297371': {'beam': 44.0,
#   'callsign': 'V7A2112',
#   'cargo': '0-AllShips',
#   'length': 251.0,
#   'mmsi': 538008231,
#   'name': 'Godam',
#   'vesseltype': '8-Tanker'},
#  '9789257': {'beam': 32.0,
#   'callsign': 'V7NI5',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 538008116,
#   'name': 'Atlantic Falcon',
#   'vesseltype': '8-Tanker'},
#  '9450894': {'beam': 37.0,
#   'callsign': '9HA3684',
#   'cargo': '0-AllShips',
#   'length': 230.0,
#   'mmsi': 229874000,
#   'name': 'Star Despoina',
#   'vesseltype': '7-Cargo'},
#  '9578024': {'beam': 18.0,
#   'callsign': '9V9996',
#   'cargo': '0-AllShips',
#   'length': 100.0,
#   'mmsi': 566679000,
#   'name': 'Js Jaguar',
#   'vesseltype': '8-Tanker'},
#  '9567051': {'beam': 45.0,
#   'callsign': '9HA3774',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 229985000,
#   'name': 'Star Scarlett',
#   'vesseltype': '7-Cargo'},
#  '9518074': {'beam': 32.0,
#   'callsign': '3FXE8',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 351260000,
#   'name': 'Energy Glory',
#   'vesseltype': '7-Cargo'},
#  '9401817': {'beam': 43.0,
#   'callsign': '3FWM3',
#   'cargo': '0-AllShips',
#   'length': 234.0,
#   'mmsi': 354289000,
#   'name': 'Federico Ii',
#   'vesseltype': '7-Cargo'},
#  '9519078': {'beam': 45.0,
#   'callsign': 'A8UT6',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636019128,
#   'name': 'Star Marianne',
#   'vesseltype': '7-Cargo'},
#  '9518919': {'beam': 45.0,
#   'callsign': '5BWU2',
#   'cargo': '9-NoInfo',
#   'length': 292.0,
#   'mmsi': 209596000,
#   'name': 'Cape Breeze',
#   'vesseltype': '7-Cargo'},
#  '9493365': {'beam': 32.0,
#   'callsign': '2ELO7',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 235086166,
#   'name': 'Noble Ace',
#   'vesseltype': '7-Cargo'},
#  '9425552': {'beam': 32.0,
#   'callsign': '9HA4881',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 248951000,
#   'name': 'Kanala',
#   'vesseltype': '8-Tanker'},
#  '9310616': {'beam': 26.0,
#   'callsign': 'VRII9',
#   'cargo': '0-AllShips',
#   'length': 176.0,
#   'mmsi': 477013600,
#   'name': 'Uni Auc One',
#   'vesseltype': '7-Cargo'},
#  '9581693': {'beam': 32.0,
#   'callsign': 'V7CC5',
#   'cargo': '9-NoInfo',
#   'length': 183.0,
#   'mmsi': 538005240,
#   'name': 'Bougainville',
#   'vesseltype': '8-Tanker'},
#  '9513919': {'beam': 32.0,
#   'callsign': 'V7YZ5',
#   'cargo': '0-AllShips',
#   'length': 188.0,
#   'mmsi': 538004771,
#   'name': 'Yasa Sparrow',
#   'vesseltype': '7-Cargo'},
#  '9620607': {'beam': 37.0,
#   'callsign': '9HA3340',
#   'cargo': '1-HazCatA',
#   'length': 228.0,
#   'mmsi': 229452000,
#   'name': 'Merkur Fjord',
#   'vesseltype': '7-Cargo'},
#  '9256482': {'beam': 43.0,
#   'callsign': 'D5UJ6',
#   'cargo': '0-AllShips',
#   'length': 323.0,
#   'mmsi': 636019407,
#   'name': 'Gsl Ningbo',
#   'vesseltype': '7-Cargo'},
#  '9293117': {'beam': 48.0,
#   'callsign': 'V7HX2',
#   'cargo': '0-AllShips',
#   'length': 283.0,
#   'mmsi': 538008767,
#   'name': 'Bari',
#   'vesseltype': '8-Tanker'},
#  '9274305': {'beam': 26.0,
#   'callsign': 'D5AF5',
#   'cargo': '0-AllShips',
#   'length': 159.0,
#   'mmsi': 636015366,
#   'name': 'Stolt Vanguard',
#   'vesseltype': '8-Tanker'},
#  '9350800': {'beam': 48.0,
#   'callsign': 'D5SC8',
#   'cargo': '0-AllShips',
#   'length': 290.0,
#   'mmsi': 636018938,
#   'name': 'Andros Navigator',
#   'vesseltype': '7-Cargo'},
#  '9351426': {'beam': 32.0,
#   'callsign': 'MCMC4',
#   'cargo': '0-AllShips',
#   'length': 228.0,
#   'mmsi': 232013527,
#   'name': 'Hellespont Progress',
#   'vesseltype': '8-Tanker'},
#  '9481257': {'beam': 45.0,
#   'callsign': '3EXD4',
#   'cargo': '0-AllShips',
#   'length': 288.0,
#   'mmsi': 351321000,
#   'name': 'Navios Antares',
#   'vesseltype': '7-Cargo'},
#  '9493511': {'beam': 32.0,
#   'callsign': 'D5WC2',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 636019773,
#   'name': 'Maroulio S',
#   'vesseltype': '7-Cargo'},
#  '9383950': {'beam': 42.0,
#   'callsign': '3FPM',
#   'cargo': '0-AllShips',
#   'length': 244.0,
#   'mmsi': 356783000,
#   'name': 'Champion Prosperity',
#   'vesseltype': '8-Tanker'},
#  '9346756': {'beam': 45.0,
#   'callsign': '9HKL8',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 256080000,
#   'name': 'Ventura',
#   'vesseltype': '7-Cargo'},
#  '9515539': {'beam': 27.0,
#   'callsign': '3FUM3',
#   'cargo': '0-AllShips',
#   'length': 170.0,
#   'mmsi': 351176000,
#   'name': 'Atlantic Diana',
#   'vesseltype': '7-Cargo'},
#  '9459620': {'beam': 27.0,
#   'callsign': '3EYP9',
#   'cargo': '0-AllShips',
#   'length': 171.0,
#   'mmsi': 353961000,
#   'name': 'Ken Sei',
#   'vesseltype': '7-Cargo'},
#  '9803118': {'beam': 20.0,
#   'callsign': 'VRQW7',
#   'cargo': '0-AllShips',
#   'length': 110.0,
#   'mmsi': 477096700,
#   'name': 'Da Wei Shan',
#   'vesseltype': '8-Tanker'},
#  '9586813': {'beam': 46.0,
#   'callsign': 'ONKW',
#   'cargo': '9-NoInfo',
#   'length': 292.0,
#   'mmsi': 205041000,
#   'name': 'Lowlands Prosperity',
#   'vesseltype': '7-Cargo'},
#  '9416824': {'beam': 32.0,
#   'callsign': 'ICBQ',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 247284500,
#   'name': 'Electa',
#   'vesseltype': '8-Tanker'},
#  '9262730': {'beam': 47.0,
#   'callsign': 'C6EA4',
#   'cargo': '0-AllShips',
#   'length': 290.0,
#   'mmsi': 311000836,
#   'name': 'Agios Charalambos',
#   'vesseltype': '7-Cargo'},
#  '9363015': {'beam': 45.0,
#   'callsign': '9HFS9',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 256924000,
#   'name': 'Malindi',
#   'vesseltype': '7-Cargo'},
#  '9590905': {'beam': 32.0,
#   'callsign': '3FUP9',
#   'cargo': '9-NoInfo',
#   'length': 180.0,
#   'mmsi': 357616000,
#   'name': 'Maersk Miyajima',
#   'vesseltype': '8-Tanker'},
#  '9852767': {'beam': 32.0,
#   'callsign': 'D5QO8',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 636018622,
#   'name': 'Al Dhafra',
#   'vesseltype': '7-Cargo'},
#  '9584059': {'beam': 32.0,
#   'callsign': 'C6YU3',
#   'cargo': '9-NoInfo',
#   'length': 200.0,
#   'mmsi': 311045300,
#   'name': 'Neptune Ace',
#   'vesseltype': '7-Cargo'},
#  '9848144': {'beam': 32.0,
#   'callsign': 'V7A2044',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 538008174,
#   'name': 'Yasa Saturn',
#   'vesseltype': '7-Cargo'},
#  '9710141': {'beam': 32.0,
#   'callsign': 'C6CB6',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 311000426,
#   'name': 'Btg Olympos',
#   'vesseltype': '7-Cargo'},
#  '9408695': {'beam': 48.0,
#   'callsign': 'V7HK3',
#   'cargo': '0-AllShips',
#   'length': 275.0,
#   'mmsi': 538006223,
#   'name': 'Front Balder',
#   'vesseltype': '8-Tanker'},
#  '9728655': {'beam': 32.0,
#   'callsign': 'VRNO8',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 477524200,
#   'name': 'Great Progress',
#   'vesseltype': '7-Cargo'},
#  '9268473': {'beam': 45.0,
#   'callsign': 'SYMC',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 240174000,
#   'name': 'Aigaion',
#   'vesseltype': '7-Cargo'},
#  '9731585': {'beam': 50.0,
#   'callsign': 'CQEF',
#   'cargo': '0-AllShips',
#   'length': 299.0,
#   'mmsi': 255805682,
#   'name': 'Hermann Oldendorff',
#   'vesseltype': '7-Cargo'},
#  '9422079': {'beam': 45.0,
#   'callsign': 'V7RP7',
#   'cargo': '0-AllShips',
#   'length': 288.0,
#   'mmsi': 538003558,
#   'name': 'Genco Commodus',
#   'vesseltype': '7-Cargo'},
#  '9406544': {'beam': 50.0,
#   'callsign': '3EMK9',
#   'cargo': '0-AllShips',
#   'length': 300.0,
#   'mmsi': 352084000,
#   'name': 'Berge Odel',
#   'vesseltype': '7-Cargo'},
#  '9661091': {'beam': 32.0,
#   'callsign': 'VRNC2',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 477407700,
#   'name': 'Sitc Hengshan',
#   'vesseltype': '7-Cargo'},
#  '9712486': {'beam': 35.0,
#   'callsign': 'V7IU6',
#   'cargo': '0-AllShips',
#   'length': 228.0,
#   'mmsi': 538005997,
#   'name': 'Sbi Samba',
#   'vesseltype': '7-Cargo'},
#  '9642368': {'beam': 32.0,
#   'callsign': 'D5CW2',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 636015791,
#   'name': 'Atlas',
#   'vesseltype': '7-Cargo'},
#  '9866184': {'beam': 32.0,
#   'callsign': 'D5XA4',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 636019967,
#   'name': 'Lady Anne',
#   'vesseltype': '7-Cargo'},
#  '9876397': {'beam': 32.0,
#   'callsign': '9V6325',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 563104200,
#   'name': 'Petrel Pacific',
#   'vesseltype': '8-Tanker'},
#  '9833591': {'beam': 32.0,
#   'callsign': '9V2676',
#   'cargo': '9-NoInfo',
#   'length': 183.0,
#   'mmsi': 563098600,
#   'name': 'Sti Miracle',
#   'vesseltype': '8-Tanker'},
#  '9538749': {'beam': 45.0,
#   'callsign': '3FOL3',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 373083000,
#   'name': 'Cape Aster',
#   'vesseltype': '7-Cargo'},
#  '9775165': {'beam': 30.0,
#   'callsign': 'VRPU6',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 477537900,
#   'name': 'Uni Harmony',
#   'vesseltype': '7-Cargo'},
#  '9448786': {'beam': 43.0,
#   'callsign': 'VRHE3',
#   'cargo': '9-NoInfo',
#   'length': 334.0,
#   'mmsi': 477831200,
#   'name': 'Cosco Indonesia',
#   'vesseltype': '7-Cargo'},
#  '9792888': {'beam': 32.0,
#   'callsign': 'VRQB2',
#   'cargo': '0-AllShips',
#   'length': 179.0,
#   'mmsi': 477157500,
#   'name': 'Great Profit',
#   'vesseltype': '7-Cargo'},
#  '9293545': {'beam': 20.0,
#   'callsign': 'V7UC8',
#   'cargo': '4-HazCatD',
#   'length': 108.0,
#   'mmsi': 538003932,
#   'name': 'Asphalt Carrier',
#   'vesseltype': '8-Tanker'},
#  '9606027': {'beam': 28.0,
#   'callsign': '9V2076',
#   'cargo': '0-AllShips',
#   'length': 178.0,
#   'mmsi': 564761000,
#   'name': 'Furness Southern Cro',
#   'vesseltype': '7-Cargo'},
#  '9732400': {'beam': 32.0,
#   'callsign': '3ELS3',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 374677000,
#   'name': 'Amis Hero',
#   'vesseltype': '7-Cargo'},
#  '9223277': {'beam': 36.0,
#   'callsign': 'BOKD',
#   'cargo': '0-AllShips',
#   'length': 156.0,
#   'mmsi': 412023000,
#   'name': 'Tai An Kou',
#   'vesseltype': '7-Cargo'},
#  '9669897': {'beam': 32.0,
#   'callsign': 'LARV7',
#   'cargo': '2-HazCatB',
#   'length': 182.0,
#   'mmsi': 258795000,
#   'name': 'Bow Trident',
#   'vesseltype': '8-Tanker'},
#  '9259745': {'beam': 48.0,
#   'callsign': 'BOEF',
#   'cargo': '0-AllShips',
#   'length': 275.0,
#   'mmsi': 413089000,
#   'name': 'Da Li Hu',
#   'vesseltype': '8-Tanker'},
#  '9612143': {'beam': 30.0,
#   'callsign': 'C6ZW9',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 311070400,
#   'name': 'African Osprey',
#   'vesseltype': '7-Cargo'},
#  '9501605': {'beam': 45.0,
#   'callsign': '3FOA2',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 372859000,
#   'name': 'Navios Symphony',
#   'vesseltype': '7-Cargo'},
#  '9312884': {'beam': 42.0,
#   'callsign': 'A8IK2',
#   'cargo': '9-NoInfo',
#   'length': 244.0,
#   'mmsi': 636012855,
#   'name': 'Ns Columbus',
#   'vesseltype': '8-Tanker'},
#  '9484807': {'beam': 45.0,
#   'callsign': '2JAC4',
#   'cargo': '0-AllShips',
#   'length': 291.0,
#   'mmsi': 235114195,
#   'name': 'Cape Stork',
#   'vesseltype': '7-Cargo'},
#  '9490595': {'beam': 45.0,
#   'callsign': '3FCJ6',
#   'cargo': '0-AllShips',
#   'length': 289.0,
#   'mmsi': 356308000,
#   'name': 'Global Enterprise',
#   'vesseltype': '7-Cargo'},
#  '9546813': {'beam': 45.0,
#   'callsign': '3EZC9',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 373275000,
#   'name': 'United Dignity',
#   'vesseltype': '7-Cargo'},
#  '9842712': {'beam': 50.0,
#   'callsign': 'V7A2155',
#   'cargo': '0-AllShips',
#   'length': 300.0,
#   'mmsi': 538008557,
#   'name': 'Golden Coral',
#   'vesseltype': '7-Cargo'},
#  '9702522': {'beam': 32.0,
#   'callsign': 'V7NC9',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 538006435,
#   'name': 'Cp Guangzhou',
#   'vesseltype': '7-Cargo'},
#  '9600645': {'beam': 32.0,
#   'callsign': 'V7QQ6',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 538007493,
#   'name': 'Astarte',
#   'vesseltype': '7-Cargo'},
#  '9479905': {'beam': 45.0,
#   'callsign': '3FXU3',
#   'cargo': '0-AllShips',
#   'length': 288.0,
#   'mmsi': 356812000,
#   'name': 'Cape Violet',
#   'vesseltype': '7-Cargo'},
#  '9583172': {'beam': 32.0,
#   'callsign': '3EVU',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 355311000,
#   'name': 'Pacific Kindness',
#   'vesseltype': '7-Cargo'},
#  '9744104': {'beam': 32.0,
#   'callsign': 'LAVN7',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 258297000,
#   'name': 'Belatlantic',
#   'vesseltype': '7-Cargo'},
#  '9512331': {'beam': 32.0,
#   'callsign': '9HA3255',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 229347000,
#   'name': 'Nba Magritte',
#   'vesseltype': '7-Cargo'},
#  '9440813': {'beam': 32.0,
#   'callsign': 'A8VE3',
#   'cargo': '1-HazCatA',
#   'length': 262.0,
#   'mmsi': 636091992,
#   'name': 'Cpo Norfolk',
#   'vesseltype': '7-Cargo'},
#  '9806330': {'beam': 30.0,
#   'callsign': '3FSH7',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 356813000,
#   'name': 'Apex Voyager',
#   'vesseltype': '7-Cargo'},
#  '9114543': {'beam': 39.0,
#   'callsign': 'V3SQ9',
#   'cargo': '0-AllShips',
#   'length': 170.0,
#   'mmsi': 312974000,
#   'name': 'Amal-t',
#   'vesseltype': '7-Cargo'},
#  '9742900': {'beam': 48.0,
#   'callsign': 'D5JC6',
#   'cargo': '0-AllShips',
#   'length': 277.0,
#   'mmsi': 636017060,
#   'name': 'Goldway',
#   'vesseltype': '8-Tanker'},
#  '9403530': {'beam': 45.0,
#   'callsign': '2CPB4',
#   'cargo': '9-NoInfo',
#   'length': 292.0,
#   'mmsi': 235074621,
#   'name': 'Taurus',
#   'vesseltype': '7-Cargo'},
#  '9732589': {'beam': 48.0,
#   'callsign': 'V7PU6',
#   'cargo': '1-HazCatA',
#   'length': 300.0,
#   'mmsi': 538006664,
#   'name': 'Seamax Rowayton',
#   'vesseltype': '7-Cargo'},
#  '9836713': {'beam': 32.0,
#   'callsign': '3FWG4',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 374155000,
#   'name': 'Medi Oita',
#   'vesseltype': '7-Cargo'},
#  '9370135': {'beam': 28.0,
#   'callsign': 'V7CP3',
#   'cargo': '0-AllShips',
#   'length': 177.0,
#   'mmsi': 538007888,
#   'name': 'Sun Aquamarine',
#   'vesseltype': '7-Cargo'},
#  '9537020': {'beam': 28.0,
#   'callsign': '3FNV7',
#   'cargo': '0-AllShips',
#   'length': 177.0,
#   'mmsi': 373334000,
#   'name': 'Nord Copenhagen',
#   'vesseltype': '7-Cargo'},
#  '9347152': {'beam': 25.0,
#   'callsign': 'S6BB8',
#   'cargo': '0-AllShips',
#   'length': 144.0,
#   'mmsi': 565509000,
#   'name': 'Crimson Ray',
#   'vesseltype': '8-Tanker'},
#  '9432488': {'beam': 32.0,
#   'callsign': '9HA2450',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 248639000,
#   'name': 'Densa Eagle',
#   'vesseltype': '7-Cargo'},
#  '9721023': {'beam': 45.0,
#   'callsign': '9HA4173',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 249254000,
#   'name': 'Maran Victory',
#   'vesseltype': '7-Cargo'},
#  '9606534': {'beam': 27.0,
#   'callsign': 'VRKP5',
#   'cargo': '0-AllShips',
#   'length': 170.0,
#   'mmsi': 477978700,
#   'name': 'Clearwater Bay',
#   'vesseltype': '7-Cargo'},
#  '9342841': {'beam': 32.0,
#   'callsign': 'SVBV6',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 241282000,
#   'name': 'Thessaloniki',
#   'vesseltype': '7-Cargo'},
#  '9742728': {'beam': 50.0,
#   'callsign': 'CQZU',
#   'cargo': '0-AllShips',
#   'length': 299.0,
#   'mmsi': 255805874,
#   'name': 'Hedwig Oldendorff',
#   'vesseltype': '7-Cargo'},
#  '9748758': {'beam': 32.0,
#   'callsign': '9V3387',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 565142000,
#   'name': 'Clover Colossus',
#   'vesseltype': '7-Cargo'},
#  '9613769': {'beam': 32.0,
#   'callsign': 'V7WI3',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 538004305,
#   'name': 'Mv Silver Navigator',
#   'vesseltype': '7-Cargo'},
#  '9852793': {'beam': 32.0,
#   'callsign': '9V5926',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 563077500,
#   'name': 'Aom Sveva',
#   'vesseltype': '7-Cargo'},
#  '9317834': {'beam': 37.0,
#   'callsign': '5BXG3',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 209889000,
#   'name': 'Xenia',
#   'vesseltype': '7-Cargo'},
#  '9474709': {'beam': 32.0,
#   'callsign': '9HA5331',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 215849000,
#   'name': 'Agios Makarios',
#   'vesseltype': '7-Cargo'},
#  '9575149': {'beam': 32.0,
#   'callsign': 'D5OP4',
#   'cargo': '9-NoInfo',
#   'length': 199.0,
#   'mmsi': 636018196,
#   'name': 'Sage Danube',
#   'vesseltype': '7-Cargo'},
#  '9882358': {'beam': 32.0,
#   'callsign': 'HPBH',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 355395000,
#   'name': 'Esteem Discovery',
#   'vesseltype': '8-Tanker'},
#  '9593672': {'beam': 27.0,
#   'callsign': '9V9411',
#   'cargo': '0-AllShips',
#   'length': 161.0,
#   'mmsi': 566307000,
#   'name': 'Kota Bahagia',
#   'vesseltype': '7-Cargo'},
#  '9687942': {'beam': 32.0,
# ...
#  '9602382': {'beam': 32.0,
#   'callsign': '3FPJ5',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 372532000,
#   'name': 'Energy Primavera',
#   'vesseltype': '7-Cargo'},
#  '9883091': {'beam': 32.0,
#   'callsign': '3FLA2',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 371441000,
#   'name': 'Clipper Isadora',
#   'vesseltype': '7-Cargo'},
#  '9278674': {'beam': 27.0,
#   'callsign': '9V3674',
#   'cargo': '0-AllShips',
#   'length': 174.0,
#   'mmsi': 564475000,
#   'name': 'Mtm St Jean',
#   'vesseltype': '8-Tanker'},
#  '9766889': {'beam': 46.0,
#   'callsign': 'D5NT8',
#   'cargo': '0-AllShips',
#   'length': 295.0,
#   'mmsi': 636018010,
#   'name': 'Patris',
#   'vesseltype': '8-Tanker'},
#  '9674177': {'beam': 35.0,
#   'callsign': 'V7CR3',
#   'cargo': '0-AllShips',
#   'length': 199.0,
#   'mmsi': 538005309,
#   'name': 'Glovis Supreme',
#   'vesseltype': '7-Cargo'},
#  '9725914': {'beam': 30.0,
#   'callsign': '9HA4582',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 248262000,
#   'name': 'Zephyr Venture',
#   'vesseltype': '7-Cargo'},
#  '9707625': {'beam': 32.0,
#   'callsign': 'VROA2',
#   'cargo': '0-AllShips',
#   'length': 186.0,
#   'mmsi': 477289300,
#   'name': 'Kellett Island',
#   'vesseltype': '7-Cargo'},
#  '9741580': {'beam': 32.0,
#   'callsign': 'VROU3',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 477301600,
#   'name': 'Xin Hai Tong 10',
#   'vesseltype': '7-Cargo'},
#  '9217462': {'beam': 21.0,
#   'callsign': 'VRJP2',
#   'cargo': '0-AllShips',
#   'length': 130.0,
#   'mmsi': 477847400,
#   'name': 'Mermaid Star',
#   'vesseltype': '7-Cargo'},
#  '9296810': {'beam': 42.0,
#   'callsign': 'YCVR2',
#   'cargo': '0-AllShips',
#   'length': 243.0,
#   'mmsi': 525114057,
#   'name': 'Luna Erawan',
#   'vesseltype': '8-Tanker'},
#  '9372731': {'beam': 53.0,
#   'callsign': 'V7PW3',
#   'cargo': '4-HazCatD',
#   'length': 345.0,
#   'mmsi': 538003300,
#   'name': 'Umm Slal',
#   'vesseltype': '8-Tanker'},
#  '9875331': {'beam': 36.0,
#   'callsign': 'V7A2954',
#   'cargo': '5-Reserved',
#   'length': 199.0,
#   'mmsi': 538008963,
#   'name': 'Draftzilla',
#   'vesseltype': '7-Cargo'},
#  '9771743': {'beam': 60.0,
#   'callsign': '9V3644',
#   'cargo': '0-AllShips',
#   'length': 333.0,
#   'mmsi': 563046600,
#   'name': 'Xin Hui Yang',
#   'vesseltype': '8-Tanker'},
#  '9286657': {'beam': 48.0,
#   'callsign': 'A8FZ9',
#   'cargo': '0-AllShips',
#   'length': 273.0,
#   'mmsi': 636012524,
#   'name': 'South Sea',
#   'vesseltype': '8-Tanker'},
#  '9338802': {'beam': 32.0,
#   'callsign': 'A8LP2',
#   'cargo': '0-AllShips',
#   'length': 182.0,
#   'mmsi': 636013235,
#   'name': 'Salaminia',
#   'vesseltype': '8-Tanker'},
#  '9272668': {'beam': 26.0,
#   'callsign': 'D5MY2',
#   'cargo': '0-AllShips',
#   'length': 170.0,
#   'mmsi': 636017838,
#   'name': 'Stolt Acer',
#   'vesseltype': '8-Tanker'},
#  '9449833': {'beam': 25.0,
#   'callsign': '5BRD2',
#   'cargo': '1-HazCatA',
#   'length': 180.0,
#   'mmsi': 212145000,
#   'name': 'Warnow Master',
#   'vesseltype': '7-Cargo'},
#  '9437658': {'beam': 32.0,
#   'callsign': '9HA5039',
#   'cargo': '4-HazCatD',
#   'length': 228.0,
#   'mmsi': 215283000,
#   'name': 'Sereno',
#   'vesseltype': '8-Tanker'},
#  '9189940': {'beam': 32.0,
#   'callsign': '2ETN8',
#   'cargo': '0-AllShips',
#   'length': 194.0,
#   'mmsi': 235088041,
#   'name': 'Star Maia',
#   'vesseltype': '7-Cargo'},
#  '9749489': {'beam': 48.0,
#   'callsign': 'SVCM2',
#   'cargo': '0-AllShips',
#   'length': 274.0,
#   'mmsi': 241458000,
#   'name': 'Apache',
#   'vesseltype': '8-Tanker'},
#  '9439400': {'beam': 42.0,
#   'callsign': 'ICNT',
#   'cargo': '9-NoInfo',
#   'length': 243.0,
#   'mmsi': 247293500,
#   'name': 'Ps Venezia',
#   'vesseltype': '8-Tanker'},
#  '9729075': {'beam': 49.0,
#   'callsign': '9HA4412',
#   'cargo': '1-HazCatA',
#   'length': 300.0,
#   'mmsi': 249877000,
#   'name': 'Cma Cgm Rodolphe',
#   'vesseltype': '7-Cargo'},
#  '9418602': {'beam': 48.0,
#   'callsign': 'C6CE5',
#   'cargo': '0-AllShips',
#   'length': 275.0,
#   'mmsi': 311000449,
#   'name': 'Moscow Spirit',
#   'vesseltype': '8-Tanker'},
#  '9479216': {'beam': 45.0,
#   'callsign': 'C6EL3',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 311000926,
#   'name': 'Freedom',
#   'vesseltype': '7-Cargo'},
#  '9427471': {'beam': 42.0,
#   'callsign': 'C6XP9',
#   'cargo': '9-NoInfo',
#   'length': 229.0,
#   'mmsi': 311018700,
#   'name': 'Jasmin Joy',
#   'vesseltype': '8-Tanker'},
#  '9574846': {'beam': 33.0,
#   'callsign': '3EYF3',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 352202000,
#   'name': 'Top Fair',
#   'vesseltype': '7-Cargo'},
#  '9222625': {'beam': 32.0,
#   'callsign': '3FXU4',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 353358000,
#   'name': 'Camellia',
#   'vesseltype': '7-Cargo'},
#  '9189110': {'beam': 32.0,
#   'callsign': '3EIR6',
#   'cargo': '0-AllShips',
#   'length': 228.0,
#   'mmsi': 356135000,
#   'name': 'Ocean Schooner',
#   'vesseltype': '8-Tanker'},
#  '9604861': {'beam': 32.0,
#   'callsign': '3EYD8',
#   'cargo': '0-AllShips',
#   'length': 228.0,
#   'mmsi': 356410000,
#   'name': 'Margreth Pissarek',
#   'vesseltype': '7-Cargo'},
#  '9802102': {'beam': 45.0,
#   'callsign': '3EYP6',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 374580000,
#   'name': 'United Eternity',
#   'vesseltype': '7-Cargo'},
#  '9227039': {'beam': 32.0,
#   'callsign': 'VRBH8',
#   'cargo': '9-NoInfo',
#   'length': 260.0,
#   'mmsi': 477020100,
#   'name': 'Seaspan Felixstowe',
#   'vesseltype': '7-Cargo'},
#  '9799161': {'beam': 60.0,
#   'callsign': 'VRRY6',
#   'cargo': '0-AllShips',
#   'length': 333.0,
#   'mmsi': 477191900,
#   'name': 'New Assurance',
#   'vesseltype': '8-Tanker'},
#  '9799202': {'beam': 60.0,
#   'callsign': 'VRSV5',
#   'cargo': '0-AllShips',
#   'length': 333.0,
#   'mmsi': 477369300,
#   'name': 'New Vision',
#   'vesseltype': '8-Tanker'},
#  '9512575': {'beam': 38.0,
#   'callsign': 'VRIJ7',
#   'cargo': '9-NoInfo',
#   'length': 235.0,
#   'mmsi': 477434300,
#   'name': 'Lara Venture',
#   'vesseltype': '7-Cargo'},
#  '9239472': {'beam': 31.0,
#   'callsign': 'VRTF9',
#   'cargo': '2-HazCatB',
#   'length': 175.0,
#   'mmsi': 477538200,
#   'name': 'Quay Star',
#   'vesseltype': '8-Tanker'},
#  '9535785': {'beam': 60.0,
#   'callsign': 'VRNW4',
#   'cargo': '0-AllShips',
#   'length': 330.0,
#   'mmsi': 477585600,
#   'name': 'New Spring',
#   'vesseltype': '8-Tanker'},
#  '9320374': {'beam': 43.0,
#   'callsign': 'V7KE3',
#   'cargo': '9-NoInfo',
#   'length': 285.0,
#   'mmsi': 538002609,
#   'name': 'Golar Maria',
#   'vesseltype': '8-Tanker'},
#  '9332638': {'beam': 32.0,
#   'callsign': 'V7RJ8',
#   'cargo': '9-NoInfo',
#   'length': 228.0,
#   'mmsi': 538003523,
#   'name': 'Arctic Flounder',
#   'vesseltype': '8-Tanker'},
#  '9629586': {'beam': 44.0,
#   'callsign': 'V7AU8',
#   'cargo': '0-AllShips',
#   'length': 288.0,
#   'mmsi': 538005072,
#   'name': 'Yenisei River',
#   'vesseltype': '8-Tanker'},
#  '9630743': {'beam': 32.0,
#   'callsign': 'V7YC2',
#   'cargo': '9-NoInfo',
#   'length': 190.0,
#   'mmsi': 538007633,
#   'name': 'Alis',
#   'vesseltype': '7-Cargo'},
#  '9856086': {'beam': 60.0,
#   'callsign': 'V7A2223',
#   'cargo': '0-AllShips',
#   'length': 333.0,
#   'mmsi': 538008310,
#   'name': 'Nissos Anafi',
#   'vesseltype': '8-Tanker'},
#  '9410870': {'beam': 40.0,
#   'callsign': 'V7A2618',
#   'cargo': '9-NoInfo',
#   'length': 240.0,
#   'mmsi': 538008649,
#   'name': 'Celsius Everett',
#   'vesseltype': '8-Tanker'},
#  '9376828': {'beam': 27.0,
#   'callsign': '9V7636',
#   'cargo': '2-HazCatB',
#   'length': 183.0,
#   'mmsi': 564359000,
#   'name': 'Nord Snow Queen',
#   'vesseltype': '8-Tanker'},
#  '9640994': {'beam': 30.0,
#   'callsign': 'D5JX8',
#   'cargo': '0-AllShips',
#   'length': 172.0,
#   'mmsi': 636017237,
#   'name': 'Aisopos Ii',
#   'vesseltype': '7-Cargo'},
#  '9321976': {'beam': 42.0,
#   'callsign': 'D5KC5',
#   'cargo': '0-AllShips',
#   'length': 238.0,
#   'mmsi': 636017269,
#   'name': 'Mitera Marigo',
#   'vesseltype': '8-Tanker'},
#  '9389124': {'beam': 33.0,
#   'callsign': 'A8NE7',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 636913468,
#   'name': 'Lara',
#   'vesseltype': '7-Cargo'},
#  '9322267': {'beam': 58.0,
#   'callsign': 'SYDB',
#   'cargo': '0-AllShips',
#   'length': 332.0,
#   'mmsi': 240520000,
#   'name': 'Ellinis',
#   'vesseltype': '8-Tanker'},
#  '9161716': {'beam': 39.0,
#   'callsign': 'C6SE5',
#   'cargo': '0-AllShips',
#   'length': 311.0,
#   'mmsi': 311317000,
#   'name': 'Voyager Of The Seas',
#   'vesseltype': '6-Passenger'},
#  '9297412': {'beam': 32.0,
#   'callsign': 'C6UO6',
#   'cargo': '0-AllShips',
#   'length': 228.0,
#   'mmsi': 311981000,
#   'name': 'Gulf Horizon',
#   'vesseltype': '8-Tanker'},
#  '9735610': {'beam': 38.0,
#   'callsign': 'V7IT4',
#   'cargo': '0-AllShips',
#   'length': 219.0,
#   'mmsi': 538005989,
#   'name': 'Sti Experience',
#   'vesseltype': '8-Tanker'},
#  '9470844': {'beam': 27.0,
#   'callsign': 'V7JN8',
#   'cargo': '0-AllShips',
#   'length': 169.0,
#   'mmsi': 538007470,
#   'name': 'Geki Star',
#   'vesseltype': '7-Cargo'},
#  '9870812': {'beam': 60.0,
#   'callsign': 'V7A4294',
#   'cargo': '0-AllShips',
#   'length': 336.0,
#   'mmsi': 538009083,
#   'name': 'Bahla',
#   'vesseltype': '8-Tanker'},
#  '9388778': {'beam': 42.0,
#   'callsign': '9VDM7',
#   'cargo': '0-AllShips',
#   'length': 246.0,
#   'mmsi': 563319000,
#   'name': 'Ocean Pegasus',
#   'vesseltype': '8-Tanker'},
#  '9388780': {'beam': 40.0,
#   'callsign': '9VDM8',
#   'cargo': '0-AllShips',
#   'length': 245.0,
#   'mmsi': 563682000,
#   'name': 'Ocean Unicorn',
#   'vesseltype': '8-Tanker'},
#  '9512185': {'beam': 32.0,
#   'callsign': '9VHR6',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 563962000,
#   'name': 'Bei Jiang',
#   'vesseltype': '8-Tanker'},
#  '9292589': {'beam': 32.0,
#   'callsign': 'S6CB7',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 563973000,
#   'name': 'Ocean     Neptune',
#   'vesseltype': '8-Tanker'},
#  '9388792': {'beam': 42.0,
#   'callsign': '9VEK5',
#   'cargo': '0-AllShips',
#   'length': 245.0,
#   'mmsi': 564147000,
#   'name': 'Ocean Vela',
#   'vesseltype': '8-Tanker'},
#  '9308120': {'beam': 32.0,
#   'callsign': 'S6CB9',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 565031000,
#   'name': 'Ocean Sedna',
#   'vesseltype': '8-Tanker'},
#  '9308132': {'beam': 32.0,
#   'callsign': 'S6EP6',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 565192000,
#   'name': 'Ocean Venus',
#   'vesseltype': '8-Tanker'},
#  '9308144': {'beam': 32.0,
#   'callsign': 'S6CB3',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 565342000,
#   'name': 'Ocean Mars',
#   'vesseltype': '8-Tanker'},
#  '9374868': {'beam': 42.0,
#   'callsign': '9VDL5',
#   'cargo': '0-AllShips',
#   'length': 245.0,
#   'mmsi': 565463000,
#   'name': 'Ocean Crown',
#   'vesseltype': '8-Tanker'},
#  '9308168': {'beam': 32.0,
#   'callsign': 'S6CQ8',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 565556000,
#   'name': 'Ocean Cosmos',
#   'vesseltype': '8-Tanker'},
#  '9388728': {'beam': 42.0,
#   'callsign': '9VDL6',
#   'cargo': '0-AllShips',
#   'length': 245.0,
#   'mmsi': 565572000,
#   'name': 'Ocean Tiara',
#   'vesseltype': '8-Tanker'},
#  '9327009': {'beam': 33.0,
#   'callsign': '9VJZ3',
#   'cargo': '9-NoInfo',
#   'length': 230.0,
#   'mmsi': 565623000,
#   'name': 'Hong Ze Hu',
#   'vesseltype': '8-Tanker'},
#  '9284386': {'beam': 32.0,
#   'callsign': '9VJQ9',
#   'cargo': '9-NoInfo',
#   'length': 229.0,
#   'mmsi': 565625000,
#   'name': 'Dong Ting Hu',
#   'vesseltype': '8-Tanker'},
#  '9402823': {'beam': 23.0,
#   'callsign': 'S6ES4',
#   'cargo': '0-AllShips',
#   'length': 144.0,
#   'mmsi': 566333000,
#   'name': 'Ocean Hero',
#   'vesseltype': '8-Tanker'},
#  '9402835': {'beam': 23.0,
#   'callsign': 'S6ES3',
#   'cargo': '0-AllShips',
#   'length': 142.0,
#   'mmsi': 566354000,
#   'name': 'Ocean Leader',
#   'vesseltype': '8-Tanker'},
#  '9402847': {'beam': 23.0,
#   'callsign': '9V7877',
#   'cargo': '0-AllShips',
#   'length': 144.0,
#   'mmsi': 566543000,
#   'name': 'Ocean Progress',
#   'vesseltype': '8-Tanker'},
#  '9253868': {'beam': 32.0,
#   'callsign': '2HBU3',
#   'cargo': '0-AllShips',
#   'length': 213.0,
#   'mmsi': 235102348,
#   'name': 'Okiana',
#   'vesseltype': '7-Cargo'},
#  '9584138': {'beam': 32.0,
#   'callsign': '9HA2510',
#   'cargo': '0-AllShips',
#   'length': 189.0,
#   'mmsi': 248779000,
#   'name': 'Almyros',
#   'vesseltype': '7-Cargo'},
#  '9295945': {'beam': 40.0,
#   'callsign': 'CQDC',
#   'cargo': '1-HazCatA',
#   'length': 276.0,
#   'mmsi': 255805779,
#   'name': 'Allegoria',
#   'vesseltype': '7-Cargo'},
#  '9390680': {'beam': 44.0,
#   'callsign': 'LADW7',
#   'cargo': '3-HazCatC',
#   'length': 283.0,
#   'mmsi': 257352000,
#   'name': 'Cape Ann',
#   'vesseltype': '8-Tanker'},
#  '9502946': {'beam': 48.0,
#   'callsign': '3FIL',
#   'cargo': '4-HazCatD',
#   'length': 366.0,
#   'mmsi': 355288000,
#   'name': 'Maersk Enshi',
#   'vesseltype': '7-Cargo'},
#  '9575101': {'beam': 60.0,
#   'callsign': 'VRJO7',
#   'cargo': '0-AllShips',
#   'length': 330.0,
#   'mmsi': 477083500,
#   'name': 'Sea Splendor',
#   'vesseltype': '8-Tanker'},
#  '9717981': {'beam': 32.0,
#   'callsign': 'D5MH4',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 636017699,
#   'name': 'Cyl',
#   'vesseltype': '7-Cargo'},
#  '9281580': {'beam': 32.0,
#   'callsign': 'D5XN3',
#   'cargo': '2-HazCatB',
#   'length': 182.0,
#   'mmsi': 636020068,
#   'name': 'Blue Ocean',
#   'vesseltype': '8-Tanker'},
#  '9359387': {'beam': 32.0,
#   'callsign': 'D5OZ7',
#   'cargo': '0-AllShips',
#   'length': 183.0,
#   'mmsi': 636092807,
#   'name': 'Gulf Mishref',
#   'vesseltype': '8-Tanker'},
#  '9267405': {'beam': 32.0,
#   'callsign': 'HOVE',
#   'cargo': '9-NoInfo',
#   'length': 190.0,
#   'mmsi': 356726000,
#   'name': 'Jian Xing',
#   'vesseltype': '7-Cargo'},
#  '9738105': {'beam': 30.0,
#   'callsign': 'VRPA8',
#   'cargo': '0-AllShips',
#   'length': 180.0,
#   'mmsi': 477713300,
#   'name': 'Lan Bao Hai',
#   'vesseltype': '7-Cargo'},
#  '9701372': {'beam': 32.0,
#   'callsign': '9HA3750',
#   'cargo': '0-AllShips',
#   'length': 200.0,
#   'mmsi': 229960000,
#   'name': 'Alexia',
#   'vesseltype': '7-Cargo'},
#  '9311244': {'beam': 21.0,
#   'callsign': 'H9ME',
#   'cargo': '0-AllShips',
#   'length': 120.0,
#   'mmsi': 354508000,
#   'name': 'Hosei 58',
#   'vesseltype': '7-Cargo'},
#  '9624469': {'beam': 45.0,
#   'callsign': 'D5KZ8',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636017448,
#   'name': 'Cape Eagle',
#   'vesseltype': '7-Cargo'},
#  '9617739': {'beam': 32.0,
#   'callsign': '9V9095',
#   'cargo': '0-AllShips',
#   'length': 197.0,
#   'mmsi': 566649000,
#   'name': 'Winning Angel',
#   'vesseltype': '7-Cargo'},
#  '9722730': {'beam': 29.0,
#   'callsign': 'BOAU',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 412478730,
#   'name': 'Tian Le',
#   'vesseltype': '7-Cargo'},
#  '9511416': {'beam': 45.0,
#   'callsign': 'V7WA2',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 538004251,
#   'name': 'Golden Myrtalia',
#   'vesseltype': '7-Cargo'},
#  '9589827': {'beam': 45.0,
#   'callsign': '3FRN4',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 370380000,
#   'name': 'Navios Altamira',
#   'vesseltype': '7-Cargo'},
#  '9666649': {'beam': 32.0,
#   'callsign': '9HA4381',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 249800000,
#   'name': 'Pacific Dream',
#   'vesseltype': '7-Cargo'},
#  '9218088': {'beam': 28.0,
#   'callsign': 'VRXE9',
#   'cargo': '0-AllShips',
#   'length': 170.0,
#   'mmsi': 477924000,
#   'name': 'Cape York',
#   'vesseltype': '7-Cargo'},
#  '9403205': {'beam': 32.0,
#   'callsign': 'V7A2521',
#   'cargo': '0-AllShips',
#   'length': 185.0,
#   'mmsi': 538008568,
#   'name': 'Vienna',
#   'vesseltype': '7-Cargo'},
#  '9509516': {'beam': 33.0,
#   'callsign': 'VRFI9',
#   'cargo': '0-AllShips',
#   'length': 190.0,
#   'mmsi': 477534200,
#   'name': 'Effy N',
#   'vesseltype': '7-Cargo'},
#  '9389215': {'beam': 32.0,
#   'callsign': '5BEL4',
#   'cargo': '9-NoInfo',
#   'length': 190.0,
#   'mmsi': 210895000,
#   'name': 'Anasa',
#   'vesseltype': '7-Cargo'},
#  '9447017': {'beam': 45.0,
#   'callsign': '9HA2198',
#   'cargo': '9-NoInfo',
#   'length': 292.0,
#   'mmsi': 248134000,
#   'name': 'Mariperla',
#   'vesseltype': '7-Cargo'},
#  '9494395': {'beam': 32.0,
#   'callsign': 'BOJT',
#   'cargo': '0-AllShips',
#   'length': 225.0,
#   'mmsi': 413687000,
#   'name': 'Yin Zhu Hai',
#   'vesseltype': '7-Cargo'},
#  '9489302': {'beam': 45.0,
#   'callsign': 'A8UF2',
#   'cargo': '0-AllShips',
#   'length': 292.0,
#   'mmsi': 636014481,
#   'name': 'Cape Alexandros',
#   'vesseltype': '7-Cargo'},
#  '9731822': {'beam': 32.0,
#   'callsign': 'C6CB7',
#   'cargo': '0-AllShips',
#   'length': 229.0,
#   'mmsi': 311000427,
#   'name': 'Btg Matterhorn',
#   'vesseltype': '7-Cargo'},
#  ...}

# %% [markdown]
# # Bring in the wikipedia data and check the IMO numbers if they are unique

# %%
with open('../data/raw/wikipedia_ship_data.json') as f:
    wikipedia_data = json.load(f)

# %%
wikipedia_imo_numbers = list((wikipedia_data.keys()))

# %%
kaggle_imo_numbers = list(thetis_ships.keys())

# %%
len(wikipedia_imo_numbers)
# Out:
# 488

# %%
len(kaggle_imo_numbers)
# Out:
# 3704

# %%
wikipedia_imo_numbers in kaggle_imo_numbers
# Out:
# False

# %%
ship_technical_specs = wikipedia_data | thetis_ships

# %%
with open('../data/raw/ship_technical_specs.json', 'w') as f:
    json.dump(ship_technical_specs, f, indent=4)

# %% [markdown]
# # Add another dataset to the technical specifications data

# %%
with open('../data/raw/sflcorp_ship_data.json') as f:
    sflcorp_data = json.load(f)

# %%
sflcorp_data
# Out:
# {'SFL Yangtze': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2012',
#   'Builder': 'LONGXUE SHIPBUILDING - GUANGZHOU',
#   'IMO Number': '9617947',
#   'Call sign': 'VRJN5',
#   'Class society': 'AMERICAN BUREAU OF SHIPPING',
#   'Capacity': '82.000 DWT',
#   'Length': '229m',
#   'Breadth': '32m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-yangtze'},
#  'SFL Yukon': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'XIAMEN SHIPBUILDING INDUSTRY - XIAMEN',
#   'IMO Number': '9600839',
#   'Call sign': 'VRHQ3',
#   'Class society': 'BUREAU VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '33m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-yukon'},
#  'SFL Sara': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2011',
#   'Builder': 'XIAMEN SHIPBUILDING INDUSTRY - XIAMEN',
#   'IMO Number': '9539834',
#   'Call sign': 'VRHZ6',
#   'Class society': 'BUREAU VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '32m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-sara'},
#  'SFL Kate': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2011',
#   'Builder': 'ZHEJIANG ZHENGHE SHIPBUILDING - ZHOUSHAN',
#   'IMO Number': '9615676',
#   'Call sign': 'VRIX3',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '23m',
#   'Charterer': 'Short Term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-kate'},
#  'SFL Humber': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2012',
#   'Builder': 'ZHEJIANG ZHENGHE SHIPBUILDING - ZHOUSHAN',
#   'IMO Number': '9615561',
#   'Call sign': 'VRIX5',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '32m',
#   'Charterer': 'Short Term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-humber'},
#  'SFL Hudson': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2010',
#   'Builder': 'JIANGSU HANTONG SHIP HEAVY INDUSTRY - TONGZHOU',
#   'IMO Number': '9525821',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '33m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-hudson'},
#  'SFL Pearl': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2012',
#   'Builder': 'LONGXUE SHIPBUILDING - GUANGZHOU',
#   'IMO Number': '9617935',
#   'Call sign': 'VRJN4',
#   'Class society': 'MERICAN BUREAU OF SHIPPING',
#   'Capacity': '82.000 DWT',
#   'Length': '229m',
#   'Breadth': '32m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-pearl'},
#  'KSL China': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2013',
#   'Builder': 'ORIENT SHIPYARD BUSAN - PUSAN',
#   'IMO Number': '9483138',
#   'Call sign': 'V7FF5',
#   'Class society': 'DNV',
#   'Capacity': '180.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/ksl-china'},
#  'Golden Zhoushan': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2011',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9448554',
#   'Call sign': 'VRHS4',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-zhoushan'},
#  'Golden Zhejiang': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9443619',
#   'Call sign': 'VRHH9',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-zhejiang'},
#  'Golden Magnum': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2009',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9494230',
#   'Call sign': 'VRML3',
#   'Class society': 'ABS',
#   'Capacity': '180.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-magnum'},
#  'Golden Future': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9443607',
#   'Call sign': 'VRGC2',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-future'},
#  'Golden Beijing': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9439412',
#   'Call sign': 'VRGC6',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-beijing'},
#  'Belgravia': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2009',
#   'Builder': 'DAEHAN SHIPBUILDING - HWAWONMYUN',
#   'IMO Number': '9443592',
#   'Call sign': 'V7SF4',
#   'Class society': 'DNV',
#   'Capacity': '170.000 DWT',
#   'Length': '291m',
#   'Breadth': '46m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/belgravia'},
#  'Battersea': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2009',
#   'Builder': 'DAEHAN SHIPBUILDING',
#   'IMO Number': '9457402',
#   'Call sign': 'V7SF3',
#   'Class society': 'DNV',
#   'Capacity': '170.000 DWT',
#   'Length': '290m',
#   'Breadth': '45m',
#   'S.DWT': '169\xa0391t',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/battersea'},
#  'Arabian Sea': {'Type': 'Car Carriers',
#   'Flag': 'Marshall Islands',
#   'Built year': '2010',
#   'Builder': 'Xiamen Shipbuilding',
#   'IMO Number': '9483786',
#   'Class society': 'DNV',
#   'Capacity': '4.900 CEU',
#   'Charterer': 'Eukor',
#   'Firm Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/arabian-sea'},
#  'Odin Highway': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2024',
#   'IMO Number': '9948152',
#   'Call sign': 'TBN',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'S.DWT': 'TBNt',
#   'Charterer': 'K Line',
#   'Firm Period Party End Date': 'Q1 2034'},
#  'Wolfsburg': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2023',
#   'IMO Number': '9941790',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q3 2033',
#   'Optional Period Party End Date': 'Q3 2035'},
#  'Emden': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2023',
#   'Builder': 'GSI Nansha',
#   'IMO Number': '9941788',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'S.DWT': 'TBNt',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q2 2033',
#   'Optional Period Party End Date': 'Q2 2035'},
#  'SFL Composer': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2005',
#   'Builder': 'MINAMINIPPON SHIPBUILDING',
#   'IMO Number': '9293583',
#   'Call sign': 'VRBF6',
#   'Class society': 'NIPPON KAIJI KYOKAI',
#   'Capacity': '6.500 CEU',
#   'Length': '200m',
#   'Breadth': '32m',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q1 2027'},
#  'Maersk Pelepas': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2022',
#   'Builder': 'Zhoushan Changhong',
#   'IMO Number': '9936458',
#   'Capacity': '2.500 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2029',
#   'Optional Period Party End Date': 'Q4 2032'},
#  'Maersk Phuket': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2022',
#   'Builder': 'Zhoushan Changhong',
#   'IMO Number': '9936446',
#   'Capacity': '2.500 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2029',
#   'Optional Period Party End Date': 'Q3 2032'},
#  'Savannah Express': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9665607',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q4 2028'},
#  'SFL Hawaii': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'Hanjin Subic',
#   'IMO Number': '9679555',
#   'Class society': 'ABS',
#   'Capacity': '6.800 TEU',
#   'Length': '270.9m',
#   'Breadth': '42.8m',
#   'S.DWT': '80100t',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q1 2028'},
#  'SFL Maui': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2013',
#   'Builder': 'Hyundai Samho Heavy Industries',
#   'IMO Number': '9635688',
#   'Class society': 'ABS',
#   'Capacity': '6.800 TEU',
#   'Length': '270.1m',
#   'Breadth': '42.8m',
#   'S.DWT': '80200t',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2027'},
#  'MSC Reef': {'Type': 'Container',
#   'Flag': 'LIBERIA',
#   'Built year': '2016',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING',
#   'IMO Number': '9754965',
#   'Call sign': 'D5LQ2',
#   'Ownership': '49.9%',
#   'Capacity': '19.400 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2033'},
#  'MSC Erica': {'Type': 'Container',
#   'Flag': 'LIBERIA',
#   'Built year': '2016',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING',
#   'IMO Number': '9755191',
#   'Call sign': 'D5ML4',
#   'Ownership': '49.9%',
#   'Capacity': '19.400 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q4 2033'},
#  'Cap San Juan': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9717204',
#   'Call sign': 'V7OW7',
#   'Class society': 'ABS',
#   'Capacity': '10.600 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2030'},
#  'Cap San Vincent': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'DSME',
#   'IMO Number': '9717228',
#   'Call sign': 'OXST2',
#   'Class society': 'ABS',
#   'Capacity': '10.600 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2030'},
#  'Cap San Lazaro': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'DSME',
#   'IMO Number': '9717216',
#   'Call sign': 'V7XV9',
#   'Class society': 'ABS',
#   'Capacity': '10.600 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2030'},
#  'Maersk Skarstind': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2016',
#   'Builder': 'Hyundai Samho',
#   'IMO Number': '9740457',
#   'Class society': 'DNV',
#   'Capacity': '9.500 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2026'},
#  'San Francisca': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Daewoo, Korea',
#   'IMO Number': '9698654',
#   'Call sign': 'V7GO6',
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q2 2030'},
#  'San Fernando': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9698642',
#   'Call sign': 'V7GO3',
#   'Class society': "Lloyd's Register",
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q1 2030'},
#  'San Felix': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9698630',
#   'Call sign': '538005733',
#   'Class society': "LLOYD'S SHIPPING REGISTER",
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '44m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q1 2030'},
#  'San Felipe': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9698628',
#   'Call sign': 'V7GN7',
#   'Class society': "LLOYD'S SHIPPING REGISTER",
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2029'},
#  'MSC Zlata R.': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES',
#   'IMO Number': '9227314',
#   'Call sign': 'D5GE5',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025'},
#  'MSC Viviana': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2017',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9777216',
#   'Ownership': '49.9%',
#   'Capacity': '19.200 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q1 2032'},
#  'MSC Vidisha R': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES',
#   'IMO Number': '9227326',
#   'Call sign': 'A8IY4',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025'},
#  'MSC Katya R.': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES',
#   'IMO Number': '9227302',
#   'Call sign': 'D5GE4',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025'},
#  'MSC Julia R.': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE',
#   'IMO Number': '9227338',
#   'Call sign': 'A8RK9',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '33m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025'},
#  'MSC Arushi R.': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE',
#   'IMO Number': '9244881',
#   'Call sign': 'A8RL3',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025'},
#  'MSC Anna': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2016',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9777204',
#   'Ownership': '49.9%',
#   'Capacity': '19.200 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q4 2031'},
#  'MSC Anisha R.': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY',
#   'IMO Number': '9227297',
#   'Call sign': 'D5GE3',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025'},
#  'Maersk Shivling': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2016',
#   'Builder': 'Daewoo Mangalia',
#   'IMO Number': '9728253',
#   'Class society': 'DNV',
#   'Capacity': '9.300 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2025',
#   'Optional Period Party End Date': 'Q4 2026'},
#  'Maersk Sarat': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2015',
#   'Builder': 'Huyndai Samho',
#   'IMO Number': '9732591',
#   'Capacity': '9.500 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q2 2026'},
#  'Green Ace': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2005',
#   'Builder': 'WENCHONG SHIPYARD',
#   'IMO Number': '9309162',
#   'Call sign': '9HOT9',
#   'Class society': 'DNV',
#   'Capacity': '1.700 TEU',
#   'Length': '176m',
#   'Breadth': '28m',
#   'Charterer': 'Short term'},
#  'SFL Tigris': {'Type': 'Product tanker',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': '9982691',
#   'Builder': 'NTS',
#   'Capacity': '115.000 DWT',
#   'Charterer': 'Vitol',
#   'Firm Period Party End Date': 'Q4 2029'},
#  'SFL Taurus': {'Type': 'Product tanker',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': '9978339',
#   'Builder': 'NTS',
#   'Capacity': '115.000 DWT',
#   'Charterer': 'Vitol',
#   'Firm Period Party End Date': 'Q3 2029'},
#  'SFL Tucana': {'Type': 'Product tanker',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': '9978327',
#   'Builder': 'NTS',
#   'Capacity': '115.000 DWT',
#   'Charterer': 'Vitol',
#   'Firm Period Party End Date': 'Q2 2029'},
#  'SFL Puma': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664794',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q4 2026',
#   'Optional Period Party End Date': 'Q4 2028'},
#  'SFL Panther': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664782',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029'},
#  'SFL Tiger': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664809',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q4 2026',
#   'Optional Period Party End Date': 'Q4 2028'},
#  'SFL Lion': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664770',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029'},
#  'SFL Trinity': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2017',
#   'Builder': 'Daehan/DSME Group',
#   'IMO Number': '9799862',
#   'Class society': 'ABS',
#   'Capacity': '114.000 DWT',
#   'Charterer': 'Phillips 66',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2029'},
#  'SFL Sabine': {'Type': 'Product tanker',
#   'Flag': 'MARSHALL ISLANDS',
#   'Built year': '2017',
#   'Builder': 'Daehan/DSME Group',
#   'IMO Number': '9799874',
#   'Class society': 'ABS',
#   'Capacity': '114.000 DWT',
#   'Charterer': 'Phillips 66',
#   'Firm Period Party End Date': 'Q3 2024',
#   'Optional Period Party End Date': 'Q3 2029'},
#  'Hercules': {'Type': 'Semi-submersible',
#   'Flag': 'Cyprus',
#   'Built year': '2008',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING',
#   'IMO Number': '8768763',
#   'Call sign': '3EOK9',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '10.000 ft',
#   'Length': '117m',
#   'Breadth': '97m',
#   'Charterer': 'Equinor',
#   'Firm Period Party End Date': 'Q4 2024'},
#  'SFL Albany': {'Type': 'Suezmax',
#   'Flag': 'Marshall Islands',
#   'Built year': '2020',
#   'Builder': 'Hyundai HI',
#   'IMO Number': '9874246',
#   'Class society': 'ABS',
#   'Capacity': '160.000 DWT',
#   'Charterer': 'Koch',
#   'Firm Period Party End Date': 'Q4 2028'},
#  'SFL Fraser': {'Type': 'Suezmax',
#   'Flag': 'Marshall Islands',
#   'Built year': '2020',
#   'Builder': 'Hyundai HI',
#   'IMO Number': '9874258',
#   'Class society': 'ABS',
#   'Capacity': '160.000 DWT',
#   'Charterer': 'Koch',
#   'Firm Period Party End Date': 'Q4 2028'},
#  'SFL Thelon': {'Type': 'Suezmax',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Bohai Shipbuilding',
#   'IMO Number': '9593012',
#   'Class society': 'ABS',
#   'Capacity': '160.000 DWT',
#   'Charterer': 'Koch',
#   'Firm Period Party End Date': 'Q3 2028'},
#  'SFL Ottawa': {'Type': 'Suezmax',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Bohai Shipbuilding',
#   'IMO Number': '9593012',
#   'Class society': 'ABS',
#   'Capacity': '160.000 DWT',
#   'Charterer': 'Koch',
#   'Firm Period Party End Date': 'Q3 2028'},
#  'Marlin Shikoku': {'Type': 'Suezmax',
#   'Flag': '',
#   'Built year': '2019',
#   'Builder': 'New Times Shipbuilding',
#   'IMO Number': '9841627',
#   'Class society': 'ABS',
#   'Capacity': '150.000 DWT',
#   'Length': '274.3m',
#   'Breadth': '48m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029'},
#  'Marlin Santorini': {'Type': 'Suezmax',
#   'Flag': '',
#   'Built year': '2019',
#   'Builder': 'New Times Shipbuilding',
#   'IMO Number': '9835836',
#   'Class society': 'ABS',
#   'Capacity': '150.000 DWT',
#   'Length': '274.3m',
#   'Breadth': '48m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q4 2026',
#   'Optional Period Party End Date': 'Q4 2028'},
#  'Marlin Sicily': {'Type': 'Suezmax',
#   'Flag': '',
#   'Built year': '2019',
#   'Builder': 'New Times Shipbuilding',
#   'IMO Number': '9835848',
#   'Class society': 'ABS',
#   'Capacity': '150.000 DWT',
#   'Length': '274.3m',
#   'Breadth': '48m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029'},
#  'Thor Highway': {'Type': 'Car Carriers',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': 'TBN',
#   'Call sign': 'TBN',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'S.DWT': 'TBNt',
#   'Charterer': 'K Line',
#   'Firm Period Party End Date': 'Q2 2034',
#   'url': 'https://www.sflcorp.com/fleet/tbn-df-pctc-nb-4'},
#  'SFL Conductor': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2006',
#   'Builder': 'SHIN KURUSHIMA HIROSHIMA DOCKYARD',
#   'IMO Number': '9293909',
#   'Call sign': '3EIC6',
#   'Class society': 'NIPPON KAIJI KYOKAI',
#   'Capacity': '6.500 CEU',
#   'Length': '200m',
#   'Breadth': '33m',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q4 2026',
#   'url': 'https://www.sflcorp.com/fleet/golvis-conductor'},
#  'Baltimore Express': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9665621',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q1 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-elpida'},
#  'Maersk Zambezi': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2020',
#   'Builder': 'Zhejiang Ouhua Shipbuilding',
#   'IMO Number': '9786085',
#   'Call sign': 'TBN',
#   'Class society': "Lloyd's Register",
#   'Capacity': '5.300 TEU',
#   'Length': '238m',
#   'Breadth': '38.8m',
#   'S.DWT': '64000t',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2028',
#   'Optional Period Party End Date': 'Q3 2032',
#   'url': 'https://www.sflcorp.com/fleet/tbn-maersk-zambezi'},
#  'Vancouver Express': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR',
#   'IMO Number': '9667186',
#   'Call sign': 'D5QZ2',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q4 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-axia'},
#  'Oakland Express': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'IMO Number': '9667174',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q3 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-doxa'},
#  'Atlanta Express': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR',
#   'IMO Number': '9667162',
#   'Call sign': 'D5QZ3',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q3 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-tyhi'},
#  'Houston Express': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR',
#   'IMO Number': '9667150',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q3 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-mana'},
#  'MSC Vaishnavi R.': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE',
#   'IMO Number': '9227340',
#   'Call sign': 'A8RL2',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '282m',
#   'Breadth': '33m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'url': 'https://www.sflcorp.com/fleet/msc-vaishnavi'},
#  'Asian Ace': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2005',
#   'Builder': 'WENCHONG SHIPYARD - GUANGZHOU',
#   'IMO Number': '9309150',
#   'Call sign': '9HOS9',
#   'Class society': 'DNV',
#   'Capacity': '1.700 TEU',
#   'Length': '176m',
#   'Breadth': '27m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q2 2025',
#   'url': 'https://www.sflcorp.com/fleet/heung-a-green'},
#  'Linus': {'Type': 'Jack Up',
#   'Flag': 'Norway',
#   'Built year': '2014',
#   'Builder': 'Jurong',
#   'IMO Number': '9622356',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '450 ft',
#   'Length': '118m',
#   'Breadth': '97m',
#   'Charterer': 'ConocoPhillips Skandinavia AS',
#   'Firm Period Party End Date': 'Q4 2028',
#   'url': 'https://www.sflcorp.com/fleet/west-linus'}}

# %%
new_dict = {}
for item in sflcorp_data.items():
    print(item)
    new_dict[item[1]['IMO Number']] = item[1] | {"Name": item[0]}
# Out:
# ('SFL Yangtze', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2012', 'Builder': 'LONGXUE SHIPBUILDING - GUANGZHOU', 'IMO Number': '9617947', 'Call sign': 'VRJN5', 'Class society': 'AMERICAN BUREAU OF SHIPPING', 'Capacity': '82.000 DWT', 'Length': '229m', 'Breadth': '32m', 'Charterer': 'Short term', 'url': 'https://www.sflcorp.com/fleet/sfl-yangtze'})
# ('SFL Yukon', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2010', 'Builder': 'XIAMEN SHIPBUILDING INDUSTRY - XIAMEN', 'IMO Number': '9600839', 'Call sign': 'VRHQ3', 'Class society': 'BUREAU VERITAS', 'Capacity': '57.000 DWT', 'Length': '190m', 'Breadth': '33m', 'Charterer': 'Short term', 'url': 'https://www.sflcorp.com/fleet/sfl-yukon'})
# ('SFL Sara', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2011', 'Builder': 'XIAMEN SHIPBUILDING INDUSTRY - XIAMEN', 'IMO Number': '9539834', 'Call sign': 'VRHZ6', 'Class society': 'BUREAU VERITAS', 'Capacity': '57.000 DWT', 'Length': '190m', 'Breadth': '32m', 'Charterer': 'Short term', 'url': 'https://www.sflcorp.com/fleet/sfl-sara'})
# ('SFL Kate', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2011', 'Builder': 'ZHEJIANG ZHENGHE SHIPBUILDING - ZHOUSHAN', 'IMO Number': '9615676', 'Call sign': 'VRIX3', 'Class society': 'DET NORSKE VERITAS', 'Capacity': '57.000 DWT', 'Length': '190m', 'Breadth': '23m', 'Charterer': 'Short Term', 'url': 'https://www.sflcorp.com/fleet/sfl-kate'})
# ('SFL Humber', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2012', 'Builder': 'ZHEJIANG ZHENGHE SHIPBUILDING - ZHOUSHAN', 'IMO Number': '9615561', 'Call sign': 'VRIX5', 'Class society': 'DET NORSKE VERITAS', 'Capacity': '57.000 DWT', 'Length': '190m', 'Breadth': '32m', 'Charterer': 'Short Term', 'url': 'https://www.sflcorp.com/fleet/sfl-humber'})
# ('SFL Hudson', {'Type': 'Bulk', 'Flag': 'Marshall Islands', 'Built year': '2010', 'Builder': 'JIANGSU HANTONG SHIP HEAVY INDUSTRY - TONGZHOU', 'IMO Number': '9525821', 'Capacity': '57.000 DWT', 'Length': '190m', 'Breadth': '33m', 'Charterer': 'Short term', 'url': 'https://www.sflcorp.com/fleet/sfl-hudson'})
# ('SFL Pearl', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2012', 'Builder': 'LONGXUE SHIPBUILDING - GUANGZHOU', 'IMO Number': '9617935', 'Call sign': 'VRJN4', 'Class society': 'MERICAN BUREAU OF SHIPPING', 'Capacity': '82.000 DWT', 'Length': '229m', 'Breadth': '32m', 'Charterer': 'Short term', 'url': 'https://www.sflcorp.com/fleet/sfl-pearl'})
# ('KSL China', {'Type': 'Bulk', 'Flag': 'Marshall Islands', 'Built year': '2013', 'Builder': 'ORIENT SHIPYARD BUSAN - PUSAN', 'IMO Number': '9483138', 'Call sign': 'V7FF5', 'Class society': 'DNV', 'Capacity': '180.000 DWT', 'Length': '292m', 'Breadth': '45m', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/ksl-china'})
# ('Golden Zhoushan', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2011', 'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN', 'IMO Number': '9448554', 'Call sign': 'VRHS4', 'Class society': 'ABS', 'Capacity': '176.000 DWT', 'Length': '292m', 'Breadth': '45m', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/golden-zhoushan'})
# ('Golden Zhejiang', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2010', 'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN', 'IMO Number': '9443619', 'Call sign': 'VRHH9', 'Class society': 'ABS', 'Capacity': '176.000 DWT', 'Length': '292m', 'Breadth': '45m', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/golden-zhejiang'})
# ('Golden Magnum', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2009', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE', 'IMO Number': '9494230', 'Call sign': 'VRML3', 'Class society': 'ABS', 'Capacity': '180.000 DWT', 'Length': '292m', 'Breadth': '45m', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/golden-magnum'})
# ('Golden Future', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2010', 'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN', 'IMO Number': '9443607', 'Call sign': 'VRGC2', 'Class society': 'ABS', 'Capacity': '176.000 DWT', 'Length': '292m', 'Breadth': '45m', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/golden-future'})
# ('Golden Beijing', {'Type': 'Bulk', 'Flag': 'Hong Kong', 'Built year': '2010', 'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN', 'IMO Number': '9439412', 'Call sign': 'VRGC6', 'Class society': 'ABS', 'Capacity': '176.000 DWT', 'Length': '292m', 'Breadth': '45m', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/golden-beijing'})
# ('Belgravia', {'Type': 'Bulk', 'Flag': 'Marshall Islands', 'Built year': '2009', 'Builder': 'DAEHAN SHIPBUILDING - HWAWONMYUN', 'IMO Number': '9443592', 'Call sign': 'V7SF4', 'Class society': 'DNV', 'Capacity': '170.000 DWT', 'Length': '291m', 'Breadth': '46m', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/belgravia'})
# ('Battersea', {'Type': 'Bulk', 'Flag': 'Marshall Islands', 'Built year': '2009', 'Builder': 'DAEHAN SHIPBUILDING', 'IMO Number': '9457402', 'Call sign': 'V7SF3', 'Class society': 'DNV', 'Capacity': '170.000 DWT', 'Length': '290m', 'Breadth': '45m', 'S.DWT': '169\xa0391t', 'Charterer': 'Golden Ocean', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/battersea'})
# ('Arabian Sea', {'Type': 'Car Carriers', 'Flag': 'Marshall Islands', 'Built year': '2010', 'Builder': 'Xiamen Shipbuilding', 'IMO Number': '9483786', 'Class society': 'DNV', 'Capacity': '4.900 CEU', 'Charterer': 'Eukor', 'Firm Period Party End Date': 'Q3 2028', 'url': 'https://www.sflcorp.com/fleet/arabian-sea'})
# ('Odin Highway', {'Type': 'Car Carriers', 'Flag': 'Liberia', 'Built year': '2024', 'IMO Number': '9948152', 'Call sign': 'TBN', 'Class society': 'DNV', 'Capacity': '7.000 CEU', 'Length': '199.9m', 'Breadth': '38m', 'S.DWT': 'TBNt', 'Charterer': 'K Line', 'Firm Period Party End Date': 'Q1 2034'})
# ('Wolfsburg', {'Type': 'Car Carriers', 'Flag': 'Liberia', 'Built year': '2023', 'IMO Number': '9941790', 'Class society': 'DNV', 'Capacity': '7.000 CEU', 'Length': '199.9m', 'Breadth': '38m', 'Charterer': 'Volkswagen', 'Firm Period Party End Date': 'Q3 2033', 'Optional Period Party End Date': 'Q3 2035'})
# ('Emden', {'Type': 'Car Carriers', 'Flag': 'Liberia', 'Built year': '2023', 'Builder': 'GSI Nansha', 'IMO Number': '9941788', 'Class society': 'DNV', 'Capacity': '7.000 CEU', 'Length': '199.9m', 'Breadth': '38m', 'S.DWT': 'TBNt', 'Charterer': 'Volkswagen', 'Firm Period Party End Date': 'Q2 2033', 'Optional Period Party End Date': 'Q2 2035'})
# ('SFL Composer', {'Type': 'Car Carriers', 'Flag': 'Liberia', 'Built year': '2005', 'Builder': 'MINAMINIPPON SHIPBUILDING', 'IMO Number': '9293583', 'Call sign': 'VRBF6', 'Class society': 'NIPPON KAIJI KYOKAI', 'Capacity': '6.500 CEU', 'Length': '200m', 'Breadth': '32m', 'Charterer': 'Volkswagen', 'Firm Period Party End Date': 'Q1 2027'})
# ('Maersk Pelepas', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2022', 'Builder': 'Zhoushan Changhong', 'IMO Number': '9936458', 'Capacity': '2.500 TEU', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q4 2029', 'Optional Period Party End Date': 'Q4 2032'})
# ('Maersk Phuket', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2022', 'Builder': 'Zhoushan Changhong', 'IMO Number': '9936446', 'Capacity': '2.500 TEU', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q3 2029', 'Optional Period Party End Date': 'Q3 2032'})
# ('Savannah Express', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2014', 'Builder': 'Hyundai Heavy Industries', 'IMO Number': '9665607', 'Class society': 'DNV', 'Capacity': '15.400 TEU', 'Charterer': 'Hapag-Lloyd', 'Firm Period Party End Date': 'Q4 2028'})
# ('SFL Hawaii', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2014', 'Builder': 'Hanjin Subic', 'IMO Number': '9679555', 'Class society': 'ABS', 'Capacity': '6.800 TEU', 'Length': '270.9m', 'Breadth': '42.8m', 'S.DWT': '80100t', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q1 2028'})
# ('SFL Maui', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2013', 'Builder': 'Hyundai Samho Heavy Industries', 'IMO Number': '9635688', 'Class society': 'ABS', 'Capacity': '6.800 TEU', 'Length': '270.1m', 'Breadth': '42.8m', 'S.DWT': '80200t', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q4 2027'})
# ('MSC Reef', {'Type': 'Container', 'Flag': 'LIBERIA', 'Built year': '2016', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING', 'IMO Number': '9754965', 'Call sign': 'D5LQ2', 'Ownership': '49.9%', 'Capacity': '19.400 TEU', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2033'})
# ('MSC Erica', {'Type': 'Container', 'Flag': 'LIBERIA', 'Built year': '2016', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING', 'IMO Number': '9755191', 'Call sign': 'D5ML4', 'Ownership': '49.9%', 'Capacity': '19.400 TEU', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q4 2033'})
# ('Cap San Juan', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE', 'IMO Number': '9717204', 'Call sign': 'V7OW7', 'Class society': 'ABS', 'Capacity': '10.600 TEU', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q4 2030'})
# ('Cap San Vincent', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'DSME', 'IMO Number': '9717228', 'Call sign': 'OXST2', 'Class society': 'ABS', 'Capacity': '10.600 TEU', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q3 2030'})
# ('Cap San Lazaro', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'DSME', 'IMO Number': '9717216', 'Call sign': 'V7XV9', 'Class society': 'ABS', 'Capacity': '10.600 TEU', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q3 2030'})
# ('Maersk Skarstind', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2016', 'Builder': 'Hyundai Samho', 'IMO Number': '9740457', 'Class society': 'DNV', 'Capacity': '9.500 TEU', 'Length': '300m', 'Breadth': '48m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2026'})
# ('San Francisca', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'Daewoo, Korea', 'IMO Number': '9698654', 'Call sign': 'V7GO6', 'Capacity': '8.700 TEU', 'Length': '300m', 'Breadth': '48m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q2 2030'})
# ('San Fernando', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2014', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE', 'IMO Number': '9698642', 'Call sign': 'V7GO3', 'Class society': "Lloyd's Register", 'Capacity': '8.700 TEU', 'Length': '300m', 'Breadth': '48m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q1 2030'})
# ('San Felix', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2014', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE', 'IMO Number': '9698630', 'Call sign': '538005733', 'Class society': "LLOYD'S SHIPPING REGISTER", 'Capacity': '8.700 TEU', 'Length': '300m', 'Breadth': '44m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q1 2030'})
# ('San Felipe', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2014', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE', 'IMO Number': '9698628', 'Call sign': 'V7GN7', 'Class society': "LLOYD'S SHIPPING REGISTER", 'Capacity': '8.700 TEU', 'Length': '300m', 'Breadth': '48m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q4 2029'})
# ('MSC Zlata R.', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2002', 'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES', 'IMO Number': '9227314', 'Call sign': 'D5GE5', 'Class society': 'DNVGL', 'Capacity': '4.100 TEU', 'Length': '281m', 'Breadth': '32m', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2025'})
# ('MSC Viviana', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2017', 'Builder': 'Hyundai Heavy Industries', 'IMO Number': '9777216', 'Ownership': '49.9%', 'Capacity': '19.200 TEU', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q1 2032'})
# ('MSC Vidisha R', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2002', 'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES', 'IMO Number': '9227326', 'Call sign': 'A8IY4', 'Class society': 'DNVGL', 'Capacity': '4.100 TEU', 'Length': '281m', 'Breadth': '32m', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2025'})
# ('MSC Katya R.', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2002', 'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES', 'IMO Number': '9227302', 'Call sign': 'D5GE4', 'Class society': 'DNVGL', 'Capacity': '4.100 TEU', 'Length': '281m', 'Breadth': '32m', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2025'})
# ('MSC Julia R.', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2002', 'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE', 'IMO Number': '9227338', 'Call sign': 'A8RK9', 'Class society': 'DNVGL', 'Capacity': '4.100 TEU', 'Length': '281m', 'Breadth': '33m', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2025'})
# ('MSC Arushi R.', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2002', 'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE', 'IMO Number': '9244881', 'Call sign': 'A8RL3', 'Class society': 'DNVGL', 'Capacity': '4.100 TEU', 'Length': '281m', 'Breadth': '32m', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2025'})
# ('MSC Anna', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2016', 'Builder': 'Hyundai Heavy Industries', 'IMO Number': '9777204', 'Ownership': '49.9%', 'Capacity': '19.200 TEU', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q4 2031'})
# ('MSC Anisha R.', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2002', 'Builder': 'SAMSUNG SHIPBUILDING & HEAVY', 'IMO Number': '9227297', 'Call sign': 'D5GE3', 'Class society': 'DNVGL', 'Capacity': '4.100 TEU', 'Length': '281m', 'Breadth': '32m', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2025'})
# ('Maersk Shivling', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2016', 'Builder': 'Daewoo Mangalia', 'IMO Number': '9728253', 'Class society': 'DNV', 'Capacity': '9.300 TEU', 'Length': '300m', 'Breadth': '48m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q4 2025', 'Optional Period Party End Date': 'Q4 2026'})
# ('Maersk Sarat', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2015', 'Builder': 'Huyndai Samho', 'IMO Number': '9732591', 'Capacity': '9.500 TEU', 'Length': '300m', 'Breadth': '48m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q2 2026'})
# ('Green Ace', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2005', 'Builder': 'WENCHONG SHIPYARD', 'IMO Number': '9309162', 'Call sign': '9HOT9', 'Class society': 'DNV', 'Capacity': '1.700 TEU', 'Length': '176m', 'Breadth': '28m', 'Charterer': 'Short term'})
# ('SFL Tigris', {'Type': 'Product tanker', 'Flag': '', 'Built year': '2024', 'IMO Number': '9982691', 'Builder': 'NTS', 'Capacity': '115.000 DWT', 'Charterer': 'Vitol', 'Firm Period Party End Date': 'Q4 2029'})
# ('SFL Taurus', {'Type': 'Product tanker', 'Flag': '', 'Built year': '2024', 'IMO Number': '9978339', 'Builder': 'NTS', 'Capacity': '115.000 DWT', 'Charterer': 'Vitol', 'Firm Period Party End Date': 'Q3 2029'})
# ('SFL Tucana', {'Type': 'Product tanker', 'Flag': '', 'Built year': '2024', 'IMO Number': '9978327', 'Builder': 'NTS', 'Capacity': '115.000 DWT', 'Charterer': 'Vitol', 'Firm Period Party End Date': 'Q2 2029'})
# ('SFL Puma', {'Type': 'Product tanker', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'Guangzhou Longxue', 'IMO Number': '9664794', 'Class society': 'ABS', 'Capacity': '115.000 DWT', 'Length': '250m', 'Breadth': '44m', 'Charterer': 'Trafigura', 'Firm Period Party End Date': 'Q4 2026', 'Optional Period Party End Date': 'Q4 2028'})
# ('SFL Panther', {'Type': 'Product tanker', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'Guangzhou Longxue', 'IMO Number': '9664782', 'Class society': 'ABS', 'Capacity': '115.000 DWT', 'Length': '250m', 'Breadth': '44m', 'Charterer': 'Trafigura', 'Firm Period Party End Date': 'Q1 2027', 'Optional Period Party End Date': 'Q1 2029'})
# ('SFL Tiger', {'Type': 'Product tanker', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'Guangzhou Longxue', 'IMO Number': '9664809', 'Class society': 'ABS', 'Capacity': '115.000 DWT', 'Length': '250m', 'Breadth': '44m', 'Charterer': 'Trafigura', 'Firm Period Party End Date': 'Q4 2026', 'Optional Period Party End Date': 'Q4 2028'})
# ('SFL Lion', {'Type': 'Product tanker', 'Flag': 'Marshall Islands', 'Built year': '2014', 'Builder': 'Guangzhou Longxue', 'IMO Number': '9664770', 'Class society': 'ABS', 'Capacity': '115.000 DWT', 'Length': '250m', 'Breadth': '44m', 'Charterer': 'Trafigura', 'Firm Period Party End Date': 'Q1 2027', 'Optional Period Party End Date': 'Q1 2029'})
# ('SFL Trinity', {'Type': 'Product tanker', 'Flag': 'Marshall Islands', 'Built year': '2017', 'Builder': 'Daehan/DSME Group', 'IMO Number': '9799862', 'Class society': 'ABS', 'Capacity': '114.000 DWT', 'Charterer': 'Phillips 66', 'Firm Period Party End Date': 'Q3 2025', 'Optional Period Party End Date': 'Q3 2029'})
# ('SFL Sabine', {'Type': 'Product tanker', 'Flag': 'MARSHALL ISLANDS', 'Built year': '2017', 'Builder': 'Daehan/DSME Group', 'IMO Number': '9799874', 'Class society': 'ABS', 'Capacity': '114.000 DWT', 'Charterer': 'Phillips 66', 'Firm Period Party End Date': 'Q3 2024', 'Optional Period Party End Date': 'Q3 2029'})
# ('Hercules', {'Type': 'Semi-submersible', 'Flag': 'Cyprus', 'Built year': '2008', 'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING', 'IMO Number': '8768763', 'Call sign': '3EOK9', 'Class society': 'DET NORSKE VERITAS', 'Capacity': '10.000 ft', 'Length': '117m', 'Breadth': '97m', 'Charterer': 'Equinor', 'Firm Period Party End Date': 'Q4 2024'})
# ('SFL Albany', {'Type': 'Suezmax', 'Flag': 'Marshall Islands', 'Built year': '2020', 'Builder': 'Hyundai HI', 'IMO Number': '9874246', 'Class society': 'ABS', 'Capacity': '160.000 DWT', 'Charterer': 'Koch', 'Firm Period Party End Date': 'Q4 2028'})
# ('SFL Fraser', {'Type': 'Suezmax', 'Flag': 'Marshall Islands', 'Built year': '2020', 'Builder': 'Hyundai HI', 'IMO Number': '9874258', 'Class society': 'ABS', 'Capacity': '160.000 DWT', 'Charterer': 'Koch', 'Firm Period Party End Date': 'Q4 2028'})
# ('SFL Thelon', {'Type': 'Suezmax', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'Bohai Shipbuilding', 'IMO Number': '9593012', 'Class society': 'ABS', 'Capacity': '160.000 DWT', 'Charterer': 'Koch', 'Firm Period Party End Date': 'Q3 2028'})
# ('SFL Ottawa', {'Type': 'Suezmax', 'Flag': 'Marshall Islands', 'Built year': '2015', 'Builder': 'Bohai Shipbuilding', 'IMO Number': '9593012', 'Class society': 'ABS', 'Capacity': '160.000 DWT', 'Charterer': 'Koch', 'Firm Period Party End Date': 'Q3 2028'})
# ('Marlin Shikoku', {'Type': 'Suezmax', 'Flag': '', 'Built year': '2019', 'Builder': 'New Times Shipbuilding', 'IMO Number': '9841627', 'Class society': 'ABS', 'Capacity': '150.000 DWT', 'Length': '274.3m', 'Breadth': '48m', 'Charterer': 'Trafigura', 'Firm Period Party End Date': 'Q1 2027', 'Optional Period Party End Date': 'Q1 2029'})
# ('Marlin Santorini', {'Type': 'Suezmax', 'Flag': '', 'Built year': '2019', 'Builder': 'New Times Shipbuilding', 'IMO Number': '9835836', 'Class society': 'ABS', 'Capacity': '150.000 DWT', 'Length': '274.3m', 'Breadth': '48m', 'Charterer': 'Trafigura', 'Firm Period Party End Date': 'Q4 2026', 'Optional Period Party End Date': 'Q4 2028'})
# ('Marlin Sicily', {'Type': 'Suezmax', 'Flag': '', 'Built year': '2019', 'Builder': 'New Times Shipbuilding', 'IMO Number': '9835848', 'Class society': 'ABS', 'Capacity': '150.000 DWT', 'Length': '274.3m', 'Breadth': '48m', 'Charterer': 'Trafigura', 'Firm Period Party End Date': 'Q1 2027', 'Optional Period Party End Date': 'Q1 2029'})
# ('Thor Highway', {'Type': 'Car Carriers', 'Flag': '', 'Built year': '2024', 'IMO Number': 'TBN', 'Call sign': 'TBN', 'Class society': 'DNV', 'Capacity': '7.000 CEU', 'Length': '199.9m', 'Breadth': '38m', 'S.DWT': 'TBNt', 'Charterer': 'K Line', 'Firm Period Party End Date': 'Q2 2034', 'url': 'https://www.sflcorp.com/fleet/tbn-df-pctc-nb-4'})
# ('SFL Conductor', {'Type': 'Car Carriers', 'Flag': 'Liberia', 'Built year': '2006', 'Builder': 'SHIN KURUSHIMA HIROSHIMA DOCKYARD', 'IMO Number': '9293909', 'Call sign': '3EIC6', 'Class society': 'NIPPON KAIJI KYOKAI', 'Capacity': '6.500 CEU', 'Length': '200m', 'Breadth': '33m', 'Charterer': 'Volkswagen', 'Firm Period Party End Date': 'Q4 2026', 'url': 'https://www.sflcorp.com/fleet/golvis-conductor'})
# ('Baltimore Express', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2014', 'Builder': 'Hyundai Heavy Industries', 'IMO Number': '9665621', 'Class society': 'DNV', 'Capacity': '15.400 TEU', 'Charterer': 'Hapag-Lloyd', 'Firm Period Party End Date': 'Q1 2029', 'url': 'https://www.sflcorp.com/fleet/thalassa-elpida'})
# ('Maersk Zambezi', {'Type': 'Container', 'Flag': 'Marshall Islands', 'Built year': '2020', 'Builder': 'Zhejiang Ouhua Shipbuilding', 'IMO Number': '9786085', 'Call sign': 'TBN', 'Class society': "Lloyd's Register", 'Capacity': '5.300 TEU', 'Length': '238m', 'Breadth': '38.8m', 'S.DWT': '64000t', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q3 2028', 'Optional Period Party End Date': 'Q3 2032', 'url': 'https://www.sflcorp.com/fleet/tbn-maersk-zambezi'})
# ('Vancouver Express', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2014', 'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR', 'IMO Number': '9667186', 'Call sign': 'D5QZ2', 'Class society': 'DNV', 'Capacity': '15.400 TEU', 'Charterer': 'Hapag-Lloyd', 'Firm Period Party End Date': 'Q4 2029', 'url': 'https://www.sflcorp.com/fleet/thalassa-axia'})
# ('Oakland Express', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2014', 'IMO Number': '9667174', 'Class society': 'DNV', 'Capacity': '15.400 TEU', 'Charterer': 'Hapag-Lloyd', 'Firm Period Party End Date': 'Q3 2029', 'url': 'https://www.sflcorp.com/fleet/thalassa-doxa'})
# ('Atlanta Express', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2014', 'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR', 'IMO Number': '9667162', 'Call sign': 'D5QZ3', 'Class society': 'DNV', 'Capacity': '15.400 TEU', 'Charterer': 'Hapag-Lloyd', 'Firm Period Party End Date': 'Q3 2029', 'url': 'https://www.sflcorp.com/fleet/thalassa-tyhi'})
# ('Houston Express', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2014', 'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR', 'IMO Number': '9667150', 'Class society': 'DNV', 'Capacity': '15.400 TEU', 'Charterer': 'Hapag-Lloyd', 'Firm Period Party End Date': 'Q3 2029', 'url': 'https://www.sflcorp.com/fleet/thalassa-mana'})
# ('MSC Vaishnavi R.', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2002', 'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE', 'IMO Number': '9227340', 'Call sign': 'A8RL2', 'Class society': 'DNVGL', 'Capacity': '4.100 TEU', 'Length': '282m', 'Breadth': '33m', 'Charterer': 'MSC', 'Firm Period Party End Date': 'Q3 2025', 'url': 'https://www.sflcorp.com/fleet/msc-vaishnavi'})
# ('Asian Ace', {'Type': 'Container', 'Flag': 'Liberia', 'Built year': '2005', 'Builder': 'WENCHONG SHIPYARD - GUANGZHOU', 'IMO Number': '9309150', 'Call sign': '9HOS9', 'Class society': 'DNV', 'Capacity': '1.700 TEU', 'Length': '176m', 'Breadth': '27m', 'Charterer': 'Maersk', 'Firm Period Party End Date': 'Q2 2025', 'url': 'https://www.sflcorp.com/fleet/heung-a-green'})
# ('Linus', {'Type': 'Jack Up', 'Flag': 'Norway', 'Built year': '2014', 'Builder': 'Jurong', 'IMO Number': '9622356', 'Class society': 'DET NORSKE VERITAS', 'Capacity': '450 ft', 'Length': '118m', 'Breadth': '97m', 'Charterer': 'ConocoPhillips Skandinavia AS', 'Firm Period Party End Date': 'Q4 2028', 'url': 'https://www.sflcorp.com/fleet/west-linus'})

# %%
new_dict
# Out:
# {'9617947': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2012',
#   'Builder': 'LONGXUE SHIPBUILDING - GUANGZHOU',
#   'IMO Number': '9617947',
#   'Call sign': 'VRJN5',
#   'Class society': 'AMERICAN BUREAU OF SHIPPING',
#   'Capacity': '82.000 DWT',
#   'Length': '229m',
#   'Breadth': '32m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-yangtze',
#   'Name': 'SFL Yangtze'},
#  '9600839': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'XIAMEN SHIPBUILDING INDUSTRY - XIAMEN',
#   'IMO Number': '9600839',
#   'Call sign': 'VRHQ3',
#   'Class society': 'BUREAU VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '33m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-yukon',
#   'Name': 'SFL Yukon'},
#  '9539834': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2011',
#   'Builder': 'XIAMEN SHIPBUILDING INDUSTRY - XIAMEN',
#   'IMO Number': '9539834',
#   'Call sign': 'VRHZ6',
#   'Class society': 'BUREAU VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '32m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-sara',
#   'Name': 'SFL Sara'},
#  '9615676': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2011',
#   'Builder': 'ZHEJIANG ZHENGHE SHIPBUILDING - ZHOUSHAN',
#   'IMO Number': '9615676',
#   'Call sign': 'VRIX3',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '23m',
#   'Charterer': 'Short Term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-kate',
#   'Name': 'SFL Kate'},
#  '9615561': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2012',
#   'Builder': 'ZHEJIANG ZHENGHE SHIPBUILDING - ZHOUSHAN',
#   'IMO Number': '9615561',
#   'Call sign': 'VRIX5',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '32m',
#   'Charterer': 'Short Term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-humber',
#   'Name': 'SFL Humber'},
#  '9525821': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2010',
#   'Builder': 'JIANGSU HANTONG SHIP HEAVY INDUSTRY - TONGZHOU',
#   'IMO Number': '9525821',
#   'Capacity': '57.000 DWT',
#   'Length': '190m',
#   'Breadth': '33m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-hudson',
#   'Name': 'SFL Hudson'},
#  '9617935': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2012',
#   'Builder': 'LONGXUE SHIPBUILDING - GUANGZHOU',
#   'IMO Number': '9617935',
#   'Call sign': 'VRJN4',
#   'Class society': 'MERICAN BUREAU OF SHIPPING',
#   'Capacity': '82.000 DWT',
#   'Length': '229m',
#   'Breadth': '32m',
#   'Charterer': 'Short term',
#   'url': 'https://www.sflcorp.com/fleet/sfl-pearl',
#   'Name': 'SFL Pearl'},
#  '9483138': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2013',
#   'Builder': 'ORIENT SHIPYARD BUSAN - PUSAN',
#   'IMO Number': '9483138',
#   'Call sign': 'V7FF5',
#   'Class society': 'DNV',
#   'Capacity': '180.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/ksl-china',
#   'Name': 'KSL China'},
#  '9448554': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2011',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9448554',
#   'Call sign': 'VRHS4',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-zhoushan',
#   'Name': 'Golden Zhoushan'},
#  '9443619': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9443619',
#   'Call sign': 'VRHH9',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-zhejiang',
#   'Name': 'Golden Zhejiang'},
#  '9494230': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2009',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9494230',
#   'Call sign': 'VRML3',
#   'Class society': 'ABS',
#   'Capacity': '180.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-magnum',
#   'Name': 'Golden Magnum'},
#  '9443607': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9443607',
#   'Call sign': 'VRGC2',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-future',
#   'Name': 'Golden Future'},
#  '9439412': {'Type': 'Bulk',
#   'Flag': 'Hong Kong',
#   'Built year': '2010',
#   'Builder': 'JINHAI HEAVY INDUSTRY - ZHOUSHAN',
#   'IMO Number': '9439412',
#   'Call sign': 'VRGC6',
#   'Class society': 'ABS',
#   'Capacity': '176.000 DWT',
#   'Length': '292m',
#   'Breadth': '45m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/golden-beijing',
#   'Name': 'Golden Beijing'},
#  '9443592': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2009',
#   'Builder': 'DAEHAN SHIPBUILDING - HWAWONMYUN',
#   'IMO Number': '9443592',
#   'Call sign': 'V7SF4',
#   'Class society': 'DNV',
#   'Capacity': '170.000 DWT',
#   'Length': '291m',
#   'Breadth': '46m',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/belgravia',
#   'Name': 'Belgravia'},
#  '9457402': {'Type': 'Bulk',
#   'Flag': 'Marshall Islands',
#   'Built year': '2009',
#   'Builder': 'DAEHAN SHIPBUILDING',
#   'IMO Number': '9457402',
#   'Call sign': 'V7SF3',
#   'Class society': 'DNV',
#   'Capacity': '170.000 DWT',
#   'Length': '290m',
#   'Breadth': '45m',
#   'S.DWT': '169\xa0391t',
#   'Charterer': 'Golden Ocean',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/battersea',
#   'Name': 'Battersea'},
#  '9483786': {'Type': 'Car Carriers',
#   'Flag': 'Marshall Islands',
#   'Built year': '2010',
#   'Builder': 'Xiamen Shipbuilding',
#   'IMO Number': '9483786',
#   'Class society': 'DNV',
#   'Capacity': '4.900 CEU',
#   'Charterer': 'Eukor',
#   'Firm Period Party End Date': 'Q3 2028',
#   'url': 'https://www.sflcorp.com/fleet/arabian-sea',
#   'Name': 'Arabian Sea'},
#  '9948152': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2024',
#   'IMO Number': '9948152',
#   'Call sign': 'TBN',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'S.DWT': 'TBNt',
#   'Charterer': 'K Line',
#   'Firm Period Party End Date': 'Q1 2034',
#   'Name': 'Odin Highway'},
#  '9941790': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2023',
#   'IMO Number': '9941790',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q3 2033',
#   'Optional Period Party End Date': 'Q3 2035',
#   'Name': 'Wolfsburg'},
#  '9941788': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2023',
#   'Builder': 'GSI Nansha',
#   'IMO Number': '9941788',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'S.DWT': 'TBNt',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q2 2033',
#   'Optional Period Party End Date': 'Q2 2035',
#   'Name': 'Emden'},
#  '9293583': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2005',
#   'Builder': 'MINAMINIPPON SHIPBUILDING',
#   'IMO Number': '9293583',
#   'Call sign': 'VRBF6',
#   'Class society': 'NIPPON KAIJI KYOKAI',
#   'Capacity': '6.500 CEU',
#   'Length': '200m',
#   'Breadth': '32m',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Name': 'SFL Composer'},
#  '9936458': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2022',
#   'Builder': 'Zhoushan Changhong',
#   'IMO Number': '9936458',
#   'Capacity': '2.500 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2029',
#   'Optional Period Party End Date': 'Q4 2032',
#   'Name': 'Maersk Pelepas'},
#  '9936446': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2022',
#   'Builder': 'Zhoushan Changhong',
#   'IMO Number': '9936446',
#   'Capacity': '2.500 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2029',
#   'Optional Period Party End Date': 'Q3 2032',
#   'Name': 'Maersk Phuket'},
#  '9665607': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9665607',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q4 2028',
#   'Name': 'Savannah Express'},
#  '9679555': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'Hanjin Subic',
#   'IMO Number': '9679555',
#   'Class society': 'ABS',
#   'Capacity': '6.800 TEU',
#   'Length': '270.9m',
#   'Breadth': '42.8m',
#   'S.DWT': '80100t',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q1 2028',
#   'Name': 'SFL Hawaii'},
#  '9635688': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2013',
#   'Builder': 'Hyundai Samho Heavy Industries',
#   'IMO Number': '9635688',
#   'Class society': 'ABS',
#   'Capacity': '6.800 TEU',
#   'Length': '270.1m',
#   'Breadth': '42.8m',
#   'S.DWT': '80200t',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2027',
#   'Name': 'SFL Maui'},
#  '9754965': {'Type': 'Container',
#   'Flag': 'LIBERIA',
#   'Built year': '2016',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING',
#   'IMO Number': '9754965',
#   'Call sign': 'D5LQ2',
#   'Ownership': '49.9%',
#   'Capacity': '19.400 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2033',
#   'Name': 'MSC Reef'},
#  '9755191': {'Type': 'Container',
#   'Flag': 'LIBERIA',
#   'Built year': '2016',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING',
#   'IMO Number': '9755191',
#   'Call sign': 'D5ML4',
#   'Ownership': '49.9%',
#   'Capacity': '19.400 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q4 2033',
#   'Name': 'MSC Erica'},
#  '9717204': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9717204',
#   'Call sign': 'V7OW7',
#   'Class society': 'ABS',
#   'Capacity': '10.600 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2030',
#   'Name': 'Cap San Juan'},
#  '9717228': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'DSME',
#   'IMO Number': '9717228',
#   'Call sign': 'OXST2',
#   'Class society': 'ABS',
#   'Capacity': '10.600 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2030',
#   'Name': 'Cap San Vincent'},
#  '9717216': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'DSME',
#   'IMO Number': '9717216',
#   'Call sign': 'V7XV9',
#   'Class society': 'ABS',
#   'Capacity': '10.600 TEU',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2030',
#   'Name': 'Cap San Lazaro'},
#  '9740457': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2016',
#   'Builder': 'Hyundai Samho',
#   'IMO Number': '9740457',
#   'Class society': 'DNV',
#   'Capacity': '9.500 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2026',
#   'Name': 'Maersk Skarstind'},
#  '9698654': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Daewoo, Korea',
#   'IMO Number': '9698654',
#   'Call sign': 'V7GO6',
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q2 2030',
#   'Name': 'San Francisca'},
#  '9698642': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9698642',
#   'Call sign': 'V7GO3',
#   'Class society': "Lloyd's Register",
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q1 2030',
#   'Name': 'San Fernando'},
#  '9698630': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9698630',
#   'Call sign': '538005733',
#   'Class society': "LLOYD'S SHIPPING REGISTER",
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '44m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q1 2030',
#   'Name': 'San Felix'},
#  '9698628': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING - GEOJE',
#   'IMO Number': '9698628',
#   'Call sign': 'V7GN7',
#   'Class society': "LLOYD'S SHIPPING REGISTER",
#   'Capacity': '8.700 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2029',
#   'Name': 'San Felipe'},
#  '9227314': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES',
#   'IMO Number': '9227314',
#   'Call sign': 'D5GE5',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Name': 'MSC Zlata R.'},
#  '9777216': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2017',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9777216',
#   'Ownership': '49.9%',
#   'Capacity': '19.200 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q1 2032',
#   'Name': 'MSC Viviana'},
#  '9227326': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES',
#   'IMO Number': '9227326',
#   'Call sign': 'A8IY4',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Name': 'MSC Vidisha R'},
#  '9227302': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES',
#   'IMO Number': '9227302',
#   'Call sign': 'D5GE4',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Name': 'MSC Katya R.'},
#  '9227338': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE',
#   'IMO Number': '9227338',
#   'Call sign': 'A8RK9',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '33m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Name': 'MSC Julia R.'},
#  '9244881': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE',
#   'IMO Number': '9244881',
#   'Call sign': 'A8RL3',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Name': 'MSC Arushi R.'},
#  '9777204': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2016',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9777204',
#   'Ownership': '49.9%',
#   'Capacity': '19.200 TEU',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q4 2031',
#   'Name': 'MSC Anna'},
#  '9227297': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY',
#   'IMO Number': '9227297',
#   'Call sign': 'D5GE3',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '281m',
#   'Breadth': '32m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Name': 'MSC Anisha R.'},
#  '9728253': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2016',
#   'Builder': 'Daewoo Mangalia',
#   'IMO Number': '9728253',
#   'Class society': 'DNV',
#   'Capacity': '9.300 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q4 2025',
#   'Optional Period Party End Date': 'Q4 2026',
#   'Name': 'Maersk Shivling'},
#  '9732591': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2015',
#   'Builder': 'Huyndai Samho',
#   'IMO Number': '9732591',
#   'Capacity': '9.500 TEU',
#   'Length': '300m',
#   'Breadth': '48m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q2 2026',
#   'Name': 'Maersk Sarat'},
#  '9309162': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2005',
#   'Builder': 'WENCHONG SHIPYARD',
#   'IMO Number': '9309162',
#   'Call sign': '9HOT9',
#   'Class society': 'DNV',
#   'Capacity': '1.700 TEU',
#   'Length': '176m',
#   'Breadth': '28m',
#   'Charterer': 'Short term',
#   'Name': 'Green Ace'},
#  '9982691': {'Type': 'Product tanker',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': '9982691',
#   'Builder': 'NTS',
#   'Capacity': '115.000 DWT',
#   'Charterer': 'Vitol',
#   'Firm Period Party End Date': 'Q4 2029',
#   'Name': 'SFL Tigris'},
#  '9978339': {'Type': 'Product tanker',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': '9978339',
#   'Builder': 'NTS',
#   'Capacity': '115.000 DWT',
#   'Charterer': 'Vitol',
#   'Firm Period Party End Date': 'Q3 2029',
#   'Name': 'SFL Taurus'},
#  '9978327': {'Type': 'Product tanker',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': '9978327',
#   'Builder': 'NTS',
#   'Capacity': '115.000 DWT',
#   'Charterer': 'Vitol',
#   'Firm Period Party End Date': 'Q2 2029',
#   'Name': 'SFL Tucana'},
#  '9664794': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664794',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q4 2026',
#   'Optional Period Party End Date': 'Q4 2028',
#   'Name': 'SFL Puma'},
#  '9664782': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664782',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029',
#   'Name': 'SFL Panther'},
#  '9664809': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664809',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q4 2026',
#   'Optional Period Party End Date': 'Q4 2028',
#   'Name': 'SFL Tiger'},
#  '9664770': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2014',
#   'Builder': 'Guangzhou Longxue',
#   'IMO Number': '9664770',
#   'Class society': 'ABS',
#   'Capacity': '115.000 DWT',
#   'Length': '250m',
#   'Breadth': '44m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029',
#   'Name': 'SFL Lion'},
#  '9799862': {'Type': 'Product tanker',
#   'Flag': 'Marshall Islands',
#   'Built year': '2017',
#   'Builder': 'Daehan/DSME Group',
#   'IMO Number': '9799862',
#   'Class society': 'ABS',
#   'Capacity': '114.000 DWT',
#   'Charterer': 'Phillips 66',
#   'Firm Period Party End Date': 'Q3 2025',
#   'Optional Period Party End Date': 'Q3 2029',
#   'Name': 'SFL Trinity'},
#  '9799874': {'Type': 'Product tanker',
#   'Flag': 'MARSHALL ISLANDS',
#   'Built year': '2017',
#   'Builder': 'Daehan/DSME Group',
#   'IMO Number': '9799874',
#   'Class society': 'ABS',
#   'Capacity': '114.000 DWT',
#   'Charterer': 'Phillips 66',
#   'Firm Period Party End Date': 'Q3 2024',
#   'Optional Period Party End Date': 'Q3 2029',
#   'Name': 'SFL Sabine'},
#  '8768763': {'Type': 'Semi-submersible',
#   'Flag': 'Cyprus',
#   'Built year': '2008',
#   'Builder': 'DAEWOO SHIPBUILDING & MARINE ENGINEERING',
#   'IMO Number': '8768763',
#   'Call sign': '3EOK9',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '10.000 ft',
#   'Length': '117m',
#   'Breadth': '97m',
#   'Charterer': 'Equinor',
#   'Firm Period Party End Date': 'Q4 2024',
#   'Name': 'Hercules'},
#  '9874246': {'Type': 'Suezmax',
#   'Flag': 'Marshall Islands',
#   'Built year': '2020',
#   'Builder': 'Hyundai HI',
#   'IMO Number': '9874246',
#   'Class society': 'ABS',
#   'Capacity': '160.000 DWT',
#   'Charterer': 'Koch',
#   'Firm Period Party End Date': 'Q4 2028',
#   'Name': 'SFL Albany'},
#  '9874258': {'Type': 'Suezmax',
#   'Flag': 'Marshall Islands',
#   'Built year': '2020',
#   'Builder': 'Hyundai HI',
#   'IMO Number': '9874258',
#   'Class society': 'ABS',
#   'Capacity': '160.000 DWT',
#   'Charterer': 'Koch',
#   'Firm Period Party End Date': 'Q4 2028',
#   'Name': 'SFL Fraser'},
#  '9593012': {'Type': 'Suezmax',
#   'Flag': 'Marshall Islands',
#   'Built year': '2015',
#   'Builder': 'Bohai Shipbuilding',
#   'IMO Number': '9593012',
#   'Class society': 'ABS',
#   'Capacity': '160.000 DWT',
#   'Charterer': 'Koch',
#   'Firm Period Party End Date': 'Q3 2028',
#   'Name': 'SFL Ottawa'},
#  '9841627': {'Type': 'Suezmax',
#   'Flag': '',
#   'Built year': '2019',
#   'Builder': 'New Times Shipbuilding',
#   'IMO Number': '9841627',
#   'Class society': 'ABS',
#   'Capacity': '150.000 DWT',
#   'Length': '274.3m',
#   'Breadth': '48m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029',
#   'Name': 'Marlin Shikoku'},
#  '9835836': {'Type': 'Suezmax',
#   'Flag': '',
#   'Built year': '2019',
#   'Builder': 'New Times Shipbuilding',
#   'IMO Number': '9835836',
#   'Class society': 'ABS',
#   'Capacity': '150.000 DWT',
#   'Length': '274.3m',
#   'Breadth': '48m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q4 2026',
#   'Optional Period Party End Date': 'Q4 2028',
#   'Name': 'Marlin Santorini'},
#  '9835848': {'Type': 'Suezmax',
#   'Flag': '',
#   'Built year': '2019',
#   'Builder': 'New Times Shipbuilding',
#   'IMO Number': '9835848',
#   'Class society': 'ABS',
#   'Capacity': '150.000 DWT',
#   'Length': '274.3m',
#   'Breadth': '48m',
#   'Charterer': 'Trafigura',
#   'Firm Period Party End Date': 'Q1 2027',
#   'Optional Period Party End Date': 'Q1 2029',
#   'Name': 'Marlin Sicily'},
#  'TBN': {'Type': 'Car Carriers',
#   'Flag': '',
#   'Built year': '2024',
#   'IMO Number': 'TBN',
#   'Call sign': 'TBN',
#   'Class society': 'DNV',
#   'Capacity': '7.000 CEU',
#   'Length': '199.9m',
#   'Breadth': '38m',
#   'S.DWT': 'TBNt',
#   'Charterer': 'K Line',
#   'Firm Period Party End Date': 'Q2 2034',
#   'url': 'https://www.sflcorp.com/fleet/tbn-df-pctc-nb-4',
#   'Name': 'Thor Highway'},
#  '9293909': {'Type': 'Car Carriers',
#   'Flag': 'Liberia',
#   'Built year': '2006',
#   'Builder': 'SHIN KURUSHIMA HIROSHIMA DOCKYARD',
#   'IMO Number': '9293909',
#   'Call sign': '3EIC6',
#   'Class society': 'NIPPON KAIJI KYOKAI',
#   'Capacity': '6.500 CEU',
#   'Length': '200m',
#   'Breadth': '33m',
#   'Charterer': 'Volkswagen',
#   'Firm Period Party End Date': 'Q4 2026',
#   'url': 'https://www.sflcorp.com/fleet/golvis-conductor',
#   'Name': 'SFL Conductor'},
#  '9665621': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'Hyundai Heavy Industries',
#   'IMO Number': '9665621',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q1 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-elpida',
#   'Name': 'Baltimore Express'},
#  '9786085': {'Type': 'Container',
#   'Flag': 'Marshall Islands',
#   'Built year': '2020',
#   'Builder': 'Zhejiang Ouhua Shipbuilding',
#   'IMO Number': '9786085',
#   'Call sign': 'TBN',
#   'Class society': "Lloyd's Register",
#   'Capacity': '5.300 TEU',
#   'Length': '238m',
#   'Breadth': '38.8m',
#   'S.DWT': '64000t',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q3 2028',
#   'Optional Period Party End Date': 'Q3 2032',
#   'url': 'https://www.sflcorp.com/fleet/tbn-maersk-zambezi',
#   'Name': 'Maersk Zambezi'},
#  '9667186': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR',
#   'IMO Number': '9667186',
#   'Call sign': 'D5QZ2',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q4 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-axia',
#   'Name': 'Vancouver Express'},
#  '9667174': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'IMO Number': '9667174',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q3 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-doxa',
#   'Name': 'Oakland Express'},
#  '9667162': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR',
#   'IMO Number': '9667162',
#   'Call sign': 'D5QZ3',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q3 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-tyhi',
#   'Name': 'Atlanta Express'},
#  '9667150': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2014',
#   'Builder': 'HYUNDAI HEAVY INDUSTRIES - ULSAN, KR',
#   'IMO Number': '9667150',
#   'Class society': 'DNV',
#   'Capacity': '15.400 TEU',
#   'Charterer': 'Hapag-Lloyd',
#   'Firm Period Party End Date': 'Q3 2029',
#   'url': 'https://www.sflcorp.com/fleet/thalassa-mana',
#   'Name': 'Houston Express'},
#  '9227340': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2002',
#   'Builder': 'SAMSUNG SHIPBUILDING & HEAVY INDUSTRIES - GEOJE',
#   'IMO Number': '9227340',
#   'Call sign': 'A8RL2',
#   'Class society': 'DNVGL',
#   'Capacity': '4.100 TEU',
#   'Length': '282m',
#   'Breadth': '33m',
#   'Charterer': 'MSC',
#   'Firm Period Party End Date': 'Q3 2025',
#   'url': 'https://www.sflcorp.com/fleet/msc-vaishnavi',
#   'Name': 'MSC Vaishnavi R.'},
#  '9309150': {'Type': 'Container',
#   'Flag': 'Liberia',
#   'Built year': '2005',
#   'Builder': 'WENCHONG SHIPYARD - GUANGZHOU',
#   'IMO Number': '9309150',
#   'Call sign': '9HOS9',
#   'Class society': 'DNV',
#   'Capacity': '1.700 TEU',
#   'Length': '176m',
#   'Breadth': '27m',
#   'Charterer': 'Maersk',
#   'Firm Period Party End Date': 'Q2 2025',
#   'url': 'https://www.sflcorp.com/fleet/heung-a-green',
#   'Name': 'Asian Ace'},
#  '9622356': {'Type': 'Jack Up',
#   'Flag': 'Norway',
#   'Built year': '2014',
#   'Builder': 'Jurong',
#   'IMO Number': '9622356',
#   'Class society': 'DET NORSKE VERITAS',
#   'Capacity': '450 ft',
#   'Length': '118m',
#   'Breadth': '97m',
#   'Charterer': 'ConocoPhillips Skandinavia AS',
#   'Firm Period Party End Date': 'Q4 2028',
#   'url': 'https://www.sflcorp.com/fleet/west-linus',
#   'Name': 'Linus'}}

# %%
with open('../data/raw/sflcorp_ship_data_updated.json', 'w') as f:
    json.dump(new_dict, f, indent=4)

# %%
ship_technical_specs = ship_technical_specs | new_dict

# %%
len(ship_technical_specs.keys())
# Out:
# 4228

# %%
with open('../data/raw/ship_technical_specs.json', 'w') as f:
    json.dump(ship_technical_specs, f, indent=4)

# %% [markdown]
# # Add another dataset

# %%
with open('../data/raw/pleiadesgr_fleet.json') as f:
    pleiadesgr_data = json.load(f)

# %%
pleiades_new_dict = {}
for item in pleiadesgr_data.items():
    print(item)
    pleiades_new_dict[item[1]['IMO Number']] = item[1] | {"Name": item[0]}
# Out:
# ('Ladon', {'url': 'https://pleiades.gr/ships/ladon/', 'dateDelivered': '2018-04-30', 'Built year': 2018, 'deadweight': {'value': 50028, 'unit': 'tonnes'}, 'Builder': 'Hyundai Mipo Dockyard Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'D5OD2', 'IMO Number': '9798961', 'Type': 'Oil Tanker (Scrubber Fitted)', 'typeOfHull': '6 Grades (7 with Slop)', 'Length': {'value': 183.0, 'unit': 'm'}, 'Breadth': {'value': 32.2, 'unit': 'm'}, 'mouldedDepth': {'value': 19.1, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 175.15, 'unit': 'm'}, 'grossTonnage': 29878, 'netTonnage': 13917})
# ('Strimon', {'url': 'https://pleiades.gr/ships/strimon/', 'dateDelivered': '2018-05-31', 'Built year': 2018, 'deadweight': {'value': 50028, 'unit': 'tonnes'}, 'Builder': 'Hyundai Mipo Dockyard Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'D5OD3', 'IMO Number': '9798973', 'Type': 'Oil Tanker (Scrubber Fitted)', 'Length': {'value': 183.0, 'unit': 'm'}, 'Breadth': {'value': 32.2, 'unit': 'm'}, 'mouldedDepth': {'value': 19.1, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 175.15, 'unit': 'm'}, 'grossTonnage': 29878, 'netTonnage': 13917})
# ('Xanthos', {'url': 'https://pleiades.gr/ships/xanthos/', 'dateDelivered': '2005-02-01', 'Built year': 2005, 'deadweight': {'value': 61369, 'unit': 'tonnes'}, 'Builder': 'Sumitomo Heavy Industries Marine & Engineering Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'A8FJ4', 'IMO Number': '9289178', 'Type': 'Oil Tanker', 'Length': {'value': 213.354, 'unit': 'm'}, 'Breadth': {'value': 32.292, 'unit': 'm'}, 'mouldedDepth': {'value': 18.5, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 206.565, 'unit': 'm'}, 'grossTonnage': 35711, 'netTonnage': 16707})
# ('Evrotas', {'url': 'https://pleiades.gr/ships/evrotas/', 'dateDelivered': '2006-01-06', 'Built year': 2006, 'deadweight': {'value': 61281, 'unit': 'tonnes'}, 'Builder': 'Sumitomo Heavy Industries Marine & Engineering Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'A8HR9', 'IMO Number': '9309241', 'Type': 'Oil Tanker', 'Length': {'value': 213.354, 'unit': 'm'}, 'Breadth': {'value': 32.292, 'unit': 'm'}, 'mouldedDepth': {'value': 18.5, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 206.565, 'unit': 'm'}, 'grossTonnage': 35711, 'netTonnage': 16707})
# ('Aliakmon', {'url': 'https://pleiades.gr/ships/aliakmon/', 'dateDelivered': '2006-03-30', 'Built year': 2006, 'deadweight': {'value': 61284, 'unit': 'tonnes'}, 'Builder': 'Sumitomo Heavy Industries Marine & Engineering Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'A8HS5', 'IMO Number': '9323962', 'Type': 'Oil Tanker', 'Length': {'value': 213.354, 'unit': 'm'}, 'Breadth': {'value': 32.292, 'unit': 'm'}, 'mouldedDepth': {'value': 18.5, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 206.565, 'unit': 'm'}, 'grossTonnage': 35711, 'netTonnage': 16707})
# ('Tavropos', {'url': 'https://pleiades.gr/ships/tavropos/', 'dateDelivered': '2014-10-09', 'Built year': 2006, 'deadweight': {'value': 61204, 'unit': 'tonnes'}, 'Builder': 'Sumitomo Heavy Industries Marine & Engineering Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'D5HM8', 'IMO Number': '9307334', 'Type': 'Oil Tanker', 'Length': {'value': 213.354, 'unit': 'm'}, 'Breadth': {'value': 32.292, 'unit': 'm'}, 'mouldedDepth': {'value': 18.5, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 206.565, 'unit': 'm'}, 'grossTonnage': 35711, 'netTonnage': 16707})
# ('Axios I', {'url': 'https://pleiades.gr/ships/axios/', 'dateDelivered': '2022-01-05', 'Built year': 2022, 'deadweight': {'value': 115527.5, 'unit': 'tonnes'}, 'Builder': 'Daehan Shipbuilding Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'D5YH6', 'IMO Number': '9912854', 'Type': 'Oil Tanker (Scrubber Fitted)', 'Length': {'value': 249.9, 'unit': 'm'}, 'Breadth': {'value': 44.0, 'unit': 'm'}, 'mouldedDepth': {'value': 21.2, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 242.0, 'unit': 'm'}, 'grossTonnage': 62809, 'netTonnage': 36148})
# ('Alfios I', {'url': 'https://pleiades.gr/ships/alfios-i/', 'dateDelivered': '2022-03-28', 'Built year': 2022, 'deadweight': {'value': 115351, 'unit': 'tonnes'}, 'Builder': 'Daehan Shipbuilding Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'D5ZU7', 'IMO Number': '9923009', 'Type': 'Oil Tanker (Scrubber Fitted)', 'Length': {'value': 249.9, 'unit': 'm'}, 'Breadth': {'value': 44.0, 'unit': 'm'}, 'mouldedDepth': {'value': 21.2, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 242.0, 'unit': 'm'}, 'grossTonnage': 62568, 'netTonnage': 36148})
# ('Ardas I', {'url': 'https://pleiades.gr/ships/ardas-i/', 'dateDelivered': '2023-01-05', 'Built year': 2023, 'deadweight': {'value': 115335, 'unit': 'tonnes'}, 'Builder': 'Daehan Shipbuilding Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': '5LCF5', 'IMO Number': '9930624', 'Type': 'LR2 Tanker (Scrubber Fitted)', 'Length': {'value': 249.9, 'unit': 'm'}, 'Breadth': {'value': 44.0, 'unit': 'm'}, 'mouldedDepth': {'value': 21.2, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 242.0, 'unit': 'm'}, 'grossTonnage': 62694, 'netTonnage': 35938})
# ('Arachthos I', {'url': 'https://pleiades.gr/ships/arachtos-i/', 'dateDelivered': '2023-01-10', 'Built year': 2023, 'deadweight': {'value': 115198, 'unit': 'tonnes'}, 'Builder': 'Daehan Shipbuilding Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': '5LCF6', 'IMO Number': '9935143', 'Type': 'Oil Tanker (Scrubber Fitted)', 'Length': {'value': 249.9, 'unit': 'm'}, 'Breadth': {'value': 44.0, 'unit': 'm'}, 'mouldedDepth': {'value': 21.2, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 242.0, 'unit': 'm'}, 'grossTonnage': 62955, 'netTonnage': 35938})
# ('Asopos', {'url': 'https://pleiades.gr/ships/asopos/', 'dateDelivered': '2006-03-09', 'Built year': 2006, 'deadweight': {'value': 61286, 'unit': 'tonnes'}, 'Builder': 'Sumitomo Heavy Industries Marine & Engineering Co., Ltd.', 'Flag': 'Liberian', 'portOfRegistry': 'Monrovia', 'callSign': 'A8HS6', 'IMO Number': '9309253', 'Type': 'Oil Tanker', 'Length': {'value': 213.354, 'unit': 'm'}, 'Breadth': {'value': 32.292, 'unit': 'm'}, 'mouldedDepth': {'value': 18.5, 'unit': 'm'}, 'lengthBetweenPerpendiculars': {'value': 206.565, 'unit': 'm'}, 'grossTonnage': 35711, 'netTonnage': 16707})

# %%
ship_technical_specs = ship_technical_specs | pleiades_new_dict

# %%
len(ship_technical_specs.keys())
# Out:
# 4239

# %%
with open('../data/raw/ship_technical_specs.json', 'w') as f:
    json.dump(ship_technical_specs, f, indent=4)

# %% [markdown]
# # Add another dataset to the technical specs

# %%
cmb_data = pd.read_csv('../data/raw/cmb-tech-fleet-export-2025-01-09_134234.csv')

# %%
cmb_data
# Out:
#                   Brand        Name     Type Flag  Built Owned  Interest  \
# 0               Euronav      Aegean     VLCC   BE   2016   Yes     100.0
# 1               Euronav      Alsace     VLCC   FR   2012   Yes     100.0
# 2               Euronav    Antigone     VLCC   FR   2015   Yes     100.0
# 3               Euronav       Brest  Suezmax   GR   2023   Yes     100.0
# 4               Euronav     Bristol  Suezmax   GR   2024   Yes     100.0
# ..                  ...         ...      ...  ...    ...   ...       ...
# 153             Windcat  Windcat 63      CTV  NaN   2025   Yes       NaN
# 154             Windcat   Windcat 7      CTV   UK   2007   Yes     100.0
# 155  Tugboats & ferries  HydroBingo    Ferry   JP   2021   Yes      50.0
# 156  Tugboats & ferries    Hydrotug  Tugboat   BE   2022   Yes       NaN
# 157  Tugboats & ferries  Hydroville    Ferry   BE   2017   Yes     100.0
#
#       Spot TC  Draft (m)  Length (m) IMO Number  \
# 0        SPOT      21.62      332.97    9732553
# 1        SPOT      22.50      330.00    9530905
# 2        SPOT      21.60      333.00    9709075
# 3        SPOT      17.65      270.00    9941867
# 4        SPOT      17.65      270.00    9941879
# ..        ...        ...         ...        ...
# 153       TBA       1.80       27.00        NaN
# 154    TC Out       1.80       15.86     913037
# 155       NaN       1.75       19.40        NaN
# 156  Bareboat        NaN       30.00        NaN
# 157       NaN       1.23       14.10    9842578
#
#                                             Shipyard
# 0           Hyundai Samho Heavy Industries Co., Ltd.
# 1                                            Samsung
# 2           Hyundai Samho Heavy Industries Co., Ltd.
# 3           Hyundai Samho Heavy Industries Co., Ltd.
# 4           Hyundai Samho Heavy Industries Co., Ltd.
# ..                                               ...
# 153                                          Neptune
# 154                                 Island Boats Inc
# 155  Tsuneishi Facilities and Craft, Urasaki factory
# 156                                            Armon
# 157                                        BW Seacat
#
# [158 rows x 12 columns]

# %%
cmb_data.dropna(subset=['IMO Number'], inplace=True)

# %%
cmb_data.shape
# Out:
# (122, 12)

# %%
cmb_data.set_index('IMO Number', inplace=True)

# %%
cmb_data_json = json.loads(cmb_data.to_json(orient='index'))

# %%
for index, ship in enumerate(cmb_data_json.items()):
    ship_name = ship[1]['Name']
    
    html_page = requests.get(f"https://cmb.tech/fleet/{ship_name}")
    soup = BeautifulSoup(html_page.text, "html.parser")
    rows = soup.find_all('div', attrs={'class': 'Specs-item Specs-item--dwt'})
    
    for row in rows:
        label = row.find('div', class_='Specs-item-label').text.strip()
        value = row.find('div', class_='Specs-item-value').text.strip()
        ship[1][label] = value

    print(f"{index} -> {ship_name}")
    time.sleep(8)
# Out:
# 0 -> Aegean
# 1 -> Alsace
# 2 -> Antigone
# 3 -> Brest
# 4 -> Bristol
# 5 -> Brugge
# 6 -> Cap Corpus Christi
# 7 -> Cap Lara
# 8 -> Cap Pembroke
# 9 -> Cap Port Arthur
# 10 -> Cap Quebec
# 11 -> Cap Theodora
# 12 -> Captain Michael
# 13 -> Cedar
# 14 -> Cypres
# 15 -> Daishan
# 16 -> Dalma
# 17 -> Dia
# 18 -> Donoussa
# 19 -> Fraternity
# 20 -> FSO Africa
# 21 -> FSO Asia
# 22 -> H5105
# 23 -> H5106
# 24 -> Hakata
# 25 -> Hakone
# 26 -> Helios
# 27 -> Hirado
# 28 -> Hojo
# 29 -> Ilma
# 30 -> Ingrid
# 31 -> Iris
# 32 -> Maria
# 33 -> Orion
# 34 -> Sienna
# 35 -> Sofia
# 36 -> Stella
# 37 -> TK300K-3
# 38 -> BC210K-47
# 39 -> BC210K-48
# 40 -> BC210K-49
# 41 -> BC210K-50
# 42 -> BC210K-51
# 43 -> BC210K-52
# 44 -> BC210K-53
# 45 -> BC210K-54
# 46 -> BC210K-55
# 47 -> Mineral Belgie
# 48 -> Mineral Denmark
# 49 -> Mineral Deutschland
# 50 -> Mineral Eire
# 51 -> Mineral Espana
# 52 -> Mineral France
# 53 -> Mineral Hellas
# 54 -> Mineral Italia
# 55 -> Mineral Luxembourg
# 56 -> Mineral Nederland
# 57 -> CMA CGM Dolomites
# 58 -> CMA CGM Etosha
# 59 -> CMA CGM Masai Mara
# 60 -> CMA CGM Zingaro
# 61 -> Bochem Brisbane
# 62 -> Bochem Cassablanca
# 63 -> Bochem Houston
# 64 -> Bochem New Orleans
# 65 -> Bochem Rotterdam
# 66 -> Bochem Shanghai
# 67 -> 552205
# 68 -> 552206
# 69 -> 552207
# 70 -> FRS Hydrocat 55
# 71 -> Hydrocat 48
# 72 -> TSM Windcat 49
# 73 -> TSM Windcat 52
# 74 -> TSM Windcat 53
# 75 -> TSM Windcat 54
# 76 -> WC Dorothea
# 77 -> Windcat 1
# 78 -> Windcat 10
# 79 -> Windcat 101
# 80 -> Windcat 11
# 81 -> Windcat 14
# 82 -> Windcat 15
# 83 -> Windcat 16
# 84 -> Windcat 17
# 85 -> Windcat 18
# 86 -> Windcat 19
# 87 -> Windcat 2
# 88 -> Windcat 20
# 89 -> Windcat 21
# 90 -> Windcat 22
# 91 -> Windcat 23
# 92 -> Windcat 24
# 93 -> Windcat 25
# 94 -> Windcat 26
# 95 -> Windcat 27
# 96 -> Windcat 28
# 97 -> Windcat 29
# 98 -> Windcat 3
# 99 -> Windcat 30
# 100 -> Windcat 31
# 101 -> Windcat 32
# 102 -> Windcat 33
# 103 -> Windcat 34
# 104 -> Windcat 35
# 105 -> Windcat 36
# 106 -> Windcat 37
# 107 -> Windcat 38
# 108 -> Windcat 39
# 109 -> Windcat 4
# 110 -> Windcat 40
# 111 -> Windcat 41
# 112 -> Windcat 42
# 113 -> Windcat 43
# 114 -> Windcat 45
# 115 -> Windcat 46
# 116 -> Windcat 47
# 117 -> Windcat 50
# 118 -> Windcat 51
# 119 -> Windcat 6
# 120 -> Windcat 7
# 121 -> Hydroville

# %%
with open('../data/raw/cmb-tech-fleet.json', 'w') as f:
    json.dump(cmb_data_json, f, indent=4)

# %%
len(ship_technical_specs.keys())
# Out:
# 4239

# %%
ship_technical_specs = ship_technical_specs | cmb_data_json

# %%
len(ship_technical_specs.keys())
# Out:
# 4357

# %%
with open('../data/raw/ship_technical_specs.json', 'w') as f:
    json.dump(ship_technical_specs, f, indent=4)

# %% [markdown]
# # Add the final dataset

# %%
new_df = pd.read_csv('../data/raw/Cleaned_ships_data.csv')

# %%
new_df
# Out:
#           Company_Name                ship_name  built_year      gt     dwt  \
# 0              PRELUDE  Offshore Support Vessel        2017  499167  394330
# 1           MSC LORETO           Container Ship        2023  236184  240000
# 2             MSC FEBE           Container Ship        2019  232618  228149
# 3            MSC ARINA           Container Ship        2019  228741  228111
# 4          EVER GOVERN           Container Ship        2019  219688  198937
# ..                 ...                      ...         ...     ...     ...
# 195          HONORSHIP             Bulk Carrier        2010   90423  180242
# 196  MARAN TRANSPORTER             Bulk Carrier        2010   90136  179719
# 197   MARAN ASTRONOMER             Bulk Carrier        2012   90104  179719
# 198    WINNING LOYALTY             Bulk Carrier        2004   90091  180310
# 199       BRAVE SAILOR             Bulk Carrier        2011   89991  176283
#
#      length  width
# 0       489     74
# 1       399     60
# 2       400     62
# 3       400     61
# 4       400     59
# ..      ...    ...
# 195     289     45
# 196     292     45
# 197     292     45
# 198     289     45
# 199     292     45
#
# [200 rows x 7 columns]

# %%
query = f"""
    WITH latest_versions AS (
        SELECT CAST(year AS INTEGER) AS year, MAX(CAST(version AS INTEGER)) AS latest_version
        FROM "{DATABASE}"."{TABLE}"
        GROUP BY CAST(year AS INTEGER)
    ),

    latest_data AS (
        SELECT *
        FROM "{DATABASE}"."{TABLE}" se
        JOIN latest_versions lv
        ON CAST(se.year AS INT) = lv.year
        AND CAST(se.version AS INT) = lv.latest_version
    )
    
    SELECT DISTINCT(imo_number), name FROM latest_data;
"""
athena_ship_name = wr.athena.read_sql_query(query, database=DATABASE, boto3_session=my_session)

# %%
athena_ship_name.head()
# Out:
#    imo_number              name
# 0     7128332          SEA WIND
# 1     7305253  CORSICA VICTORIA
# 2     7310507          FIDELITY
# 3     7360605      MOBY VINCENT
# 4     7360617     SARDINIA VERA

# %%
athena_ship_name.shape
# Out:
# (24738, 2)

# %%
new_df
# Out:
#           Company_Name                ship_name  built_year      gt     dwt  \
# 0              PRELUDE  Offshore Support Vessel        2017  499167  394330
# 1           MSC LORETO           Container Ship        2023  236184  240000
# 2             MSC FEBE           Container Ship        2019  232618  228149
# 3            MSC ARINA           Container Ship        2019  228741  228111
# 4          EVER GOVERN           Container Ship        2019  219688  198937
# ..                 ...                      ...         ...     ...     ...
# 195          HONORSHIP             Bulk Carrier        2010   90423  180242
# 196  MARAN TRANSPORTER             Bulk Carrier        2010   90136  179719
# 197   MARAN ASTRONOMER             Bulk Carrier        2012   90104  179719
# 198    WINNING LOYALTY             Bulk Carrier        2004   90091  180310
# 199       BRAVE SAILOR             Bulk Carrier        2011   89991  176283
#
#      length  width
# 0       489     74
# 1       399     60
# 2       400     62
# 3       400     61
# 4       400     59
# ..      ...    ...
# 195     289     45
# 196     292     45
# 197     292     45
# 198     289     45
# 199     292     45
#
# [200 rows x 7 columns]

# %%
data_dict = {}
unmatched_names = []

for index, row in new_df.iterrows():
    print(row['Company_Name'], row.to_json(orient='index'))
    
    if row['Company_Name'] in athena_ship_name['name'].to_list():
        imo_number = athena_ship_name[athena_ship_name['name'] == row['Company_Name']]['imo_number'].values[0]
        data_dict[imo_number] = row.to_json(orient='index')
    else:
        unmatched_names.append(row['Company_Name'])
    print()
# Out:
# PRELUDE {"Company_Name":"PRELUDE","ship_name":"Offshore Support Vessel","built_year":2017,"gt":499167,"dwt":394330,"length":489,"width":74}
#
# MSC LORETO {"Company_Name":"MSC LORETO","ship_name":"Container Ship","built_year":2023,"gt":236184,"dwt":240000,"length":399,"width":60}
#
# MSC FEBE {"Company_Name":"MSC FEBE","ship_name":"Container Ship","built_year":2019,"gt":232618,"dwt":228149,"length":400,"width":62}
#
# MSC ARINA {"Company_Name":"MSC ARINA","ship_name":"Container Ship","built_year":2019,"gt":228741,"dwt":228111,"length":400,"width":61}
#
# EVER GOVERN {"Company_Name":"EVER GOVERN","ship_name":"Container Ship","built_year":2019,"gt":219688,"dwt":198937,"length":400,"width":59}
#
# MAASTRICHT MAERSK {"Company_Name":"MAASTRICHT MAERSK","ship_name":"Container Ship","built_year":2019,"gt":214286,"dwt":190326,"length":399,"width":59}
#
# ONE TREASURE {"Company_Name":"ONE TREASURE","ship_name":"Container Ship","built_year":2018,"gt":210691,"dwt":189766,"length":400,"width":58}
#
# ORE SHENZHEN {"Company_Name":"ORE SHENZHEN","ship_name":"Bulk Carrier","built_year":2018,"gt":203953,"dwt":398997,"length":362,"width":65}
#
# SAHAM MAX {"Company_Name":"SAHAM MAX","ship_name":"Bulk Carrier","built_year":2013,"gt":201705,"dwt":400694,"length":360,"width":65}
#
# BARZAN {"Company_Name":"BARZAN","ship_name":"Container Ship","built_year":2015,"gt":195636,"dwt":199744,"length":400,"width":59}
#
# MARSTAL MAERSK {"Company_Name":"MARSTAL MAERSK","ship_name":"Container Ship","built_year":2014,"gt":194849,"dwt":213971,"length":399,"width":59}
#
# MSC DIANA {"Company_Name":"MSC DIANA","ship_name":"Container Ship","built_year":2016,"gt":194250,"dwt":202036,"length":400,"width":59}
#
# COSTA TOSCANA {"Company_Name":"COSTA TOSCANA","ship_name":"Passenger (Cruise) Ship","built_year":2021,"gt":186364,"dwt":13000,"length":337,"width":42}
#
# MSC NEW YORK {"Company_Name":"MSC NEW YORK","ship_name":"Container Ship","built_year":2014,"gt":176490,"dwt":186766,"length":399,"width":54}
#
# MSC MERAVIGLIA {"Company_Name":"MSC MERAVIGLIA","ship_name":"Passenger (Cruise) Ship","built_year":2017,"gt":171598,"dwt":12200,"length":316,"width":43}
#
# ATHERINA {"Company_Name":"ATHERINA","ship_name":"Crude Oil Tanker","built_year":2011,"gt":169919,"dwt":319471,"length":340,"width":60}
#
# AL GHUWAIRIYA {"Company_Name":"AL GHUWAIRIYA","ship_name":"LNG Tanker","built_year":2008,"gt":168189,"dwt":154940,"length":345,"width":55}
#
# HONG KONG SPIRIT {"Company_Name":"HONG KONG SPIRIT","ship_name":"Crude Oil Tanker","built_year":2013,"gt":166231,"dwt":318473,"length":333,"width":60}
#
# NEW PROSPERITY {"Company_Name":"NEW PROSPERITY","ship_name":"Crude Oil Tanker","built_year":2015,"gt":165209,"dwt":318607,"length":333,"width":60}
#
# NEW WISDOM {"Company_Name":"NEW WISDOM","ship_name":"Crude Oil Tanker","built_year":2011,"gt":164680,"dwt":317960,"length":333,"width":60}
#
# DAN {"Company_Name":"DAN","ship_name":"Crude Oil Tanker","built_year":2009,"gt":164241,"dwt":319999,"length":333,"width":60}
#
# ATBAN {"Company_Name":"ATBAN","ship_name":"Crude Oil Tanker","built_year":1996,"gt":163882,"dwt":300361,"length":340,"width":56}
#
# SAN RAMON VOYAGER {"Company_Name":"SAN RAMON VOYAGER","ship_name":"Crude Oil Tanker","built_year":2019,"gt":163214,"dwt":318608,"length":336,"width":60}
#
# NISALAH {"Company_Name":"NISALAH","ship_name":"Crude Oil Tanker","built_year":2010,"gt":162863,"dwt":319287,"length":333,"width":60}
#
# DHT OPAL {"Company_Name":"DHT OPAL","ship_name":"Crude Oil Tanker","built_year":2012,"gt":162557,"dwt":320105,"length":333,"width":60}
#
# JAHAM {"Company_Name":"JAHAM","ship_name":"Crude Oil Tanker","built_year":2008,"gt":162252,"dwt":319430,"length":332,"width":60}
#
# MARAN THETIS {"Company_Name":"MARAN THETIS","ship_name":"Crude Oil Tanker","built_year":2012,"gt":162018,"dwt":320105,"length":333,"width":60}
#
# GENT {"Company_Name":"GENT","ship_name":"Crude Oil Tanker","built_year":2005,"gt":161632,"dwt":319180,"length":333,"width":60}
#
# SEAWAYS DIAMOND HEAD {"Company_Name":"SEAWAYS DIAMOND HEAD","ship_name":"Crude Oil Tanker","built_year":2016,"gt":161319,"dwt":299989,"length":333,"width":60}
#
# BIG STAR {"Company_Name":"BIG STAR","ship_name":"Crude Oil Tanker","built_year":2004,"gt":161175,"dwt":319247,"length":333,"width":60}
#
# OLYMPIC LIFE {"Company_Name":"OLYMPIC LIFE","ship_name":"Crude Oil Tanker","built_year":2019,"gt":160874,"dwt":318676,"length":333,"width":60}
#
# STELLAR RIO {"Company_Name":"STELLAR RIO","ship_name":"Bulk Carrier","built_year":1994,"gt":160666,"dwt":298450,"length":332,"width":58}
#
# AWTAD {"Company_Name":"AWTAD","ship_name":"Crude Oil Tanker","built_year":2011,"gt":160493,"dwt":309988,"length":333,"width":60}
#
# SPLENDOR {"Company_Name":"SPLENDOR","ship_name":"Crude Oil Tanker","built_year":1993,"gt":160299,"dwt":306474,"length":331,"width":58}
#
# PIONEER {"Company_Name":"PIONEER","ship_name":"Crude Oil Tanker","built_year":1999,"gt":160216,"dwt":306397,"length":334,"width":58}
#
# BASRA {"Company_Name":"BASRA","ship_name":"Crude Oil Tanker","built_year":2021,"gt":160087,"dwt":298981,"length":339,"width":60}
#
# NEW PEARL {"Company_Name":"NEW PEARL","ship_name":"Crude Oil Tanker","built_year":2011,"gt":160043,"dwt":301866,"length":333,"width":60}
#
# SAKE {"Company_Name":"SAKE","ship_name":"Crude Oil Tanker","built_year":2005,"gt":159938,"dwt":300390,"length":333,"width":60}
#
# NEW PRIME {"Company_Name":"NEW PRIME","ship_name":"Crude Oil Tanker","built_year":2018,"gt":159843,"dwt":311003,"length":333,"width":60}
#
# PLATA GLORY {"Company_Name":"PLATA GLORY","ship_name":"Crude Oil Tanker","built_year":1999,"gt":159423,"dwt":300133,"length":333,"width":60}
#
# DHT BAUHINIA {"Company_Name":"DHT BAUHINIA","ship_name":"Crude Oil Tanker","built_year":2007,"gt":159158,"dwt":301019,"length":332,"width":58}
#
# TAKAMATSU MARU {"Company_Name":"TAKAMATSU MARU","ship_name":"Crude Oil Tanker","built_year":2012,"gt":158424,"dwt":311087,"length":333,"width":60}
#
# LEXIE {"Company_Name":"LEXIE","ship_name":"Crude Oil Tanker","built_year":2001,"gt":157831,"dwt":298911,"length":332,"width":58}
#
# MAXIM {"Company_Name":"MAXIM","ship_name":"Crude Oil Tanker","built_year":2011,"gt":157351,"dwt":296887,"length":330,"width":60}
#
# NEW PIONEER {"Company_Name":"NEW PIONEER","ship_name":"Crude Oil Tanker","built_year":2010,"gt":157052,"dwt":297058,"length":330,"width":60}
#
# NEW PROSPECT {"Company_Name":"NEW PROSPECT","ship_name":"Crude Oil Tanker","built_year":2009,"gt":156921,"dwt":297934,"length":330,"width":60}
#
# NASHA {"Company_Name":"NASHA","ship_name":"Crude Oil Tanker","built_year":1996,"gt":156809,"dwt":298732,"length":332,"width":58}
#
# GAZA MARINE TERMINAL {"Company_Name":"GAZA MARINE TERMINAL","ship_name":"FSO","built_year":2016,"gt":156510,"dwt":265869,"length":338,"width":51}
#
# STELLAR UNICORN {"Company_Name":"STELLAR UNICORN","ship_name":"Bulk Carrier","built_year":1993,"gt":156352,"dwt":279022,"length":330,"width":56}
#
# SEAWAYS ENTERPRISE {"Company_Name":"SEAWAYS ENTERPRISE","ship_name":"Crude Oil Tanker","built_year":2023,"gt":156186,"dwt":300000,"length":336,"width":60}
#
# YIANNIS LATSIS {"Company_Name":"YIANNIS LATSIS","ship_name":"Crude Oil Tanker","built_year":2022,"gt":154792,"dwt":299999,"length":330,"width":60}
#
# ALICE {"Company_Name":"ALICE","ship_name":"Crude Oil Tanker","built_year":2016,"gt":154379,"dwt":299320,"length":333,"width":60}
#
# SEAPASSION {"Company_Name":"SEAPASSION","ship_name":"Crude Oil Tanker","built_year":2017,"gt":154182,"dwt":299271,"length":333,"width":60}
#
# BING N {"Company_Name":"BING N","ship_name":"Bulk Carrier","built_year":1992,"gt":154030,"dwt":322941,"length":339,"width":55}
#
# MAERSK HANOI {"Company_Name":"MAERSK HANOI","ship_name":"Container Ship","built_year":2018,"gt":153773,"dwt":178257,"length":353,"width":54}
#
# MSC SEASIDE {"Company_Name":"MSC SEASIDE","ship_name":"Passenger (Cruise) Ship","built_year":2017,"gt":153516,"dwt":19209,"length":323,"width":41}
#
# MSC VALERIA {"Company_Name":"MSC VALERIA","ship_name":"Container Ship","built_year":2012,"gt":153115,"dwt":165966,"length":366,"width":51}
#
# COSRICH LAKE {"Company_Name":"COSRICH LAKE","ship_name":"Crude Oil Tanker","built_year":2012,"gt":152727,"dwt":297336,"length":330,"width":60}
#
# EROS {"Company_Name":"EROS","ship_name":"Crude Oil Tanker","built_year":2000,"gt":152139,"dwt":284170,"length":330,"width":60}
#
# GEMMA {"Company_Name":"GEMMA","ship_name":"Bulk Carrier","built_year":2012,"gt":151915,"dwt":313049,"length":330,"width":57}
#
# HUGO N {"Company_Name":"HUGO N","ship_name":"Bulk Carrier","built_year":2011,"gt":151448,"dwt":297088,"length":327,"width":55}
#
# CMA CGM ARCTIC {"Company_Name":"CMA CGM ARCTIC","ship_name":"Container Ship","built_year":2022,"gt":150844,"dwt":159614,"length":366,"width":51}
#
# MANARA {"Company_Name":"MANARA","ship_name":"Passenger (Cruise) Ship","built_year":2017,"gt":150695,"dwt":15370,"length":335,"width":44}
#
# MSC VIRGO {"Company_Name":"MSC VIRGO","ship_name":"Container Ship","built_year":2020,"gt":149525,"dwt":158097,"length":366,"width":48}
#
# THESEUS {"Company_Name":"THESEUS","ship_name":"Container Ship","built_year":2016,"gt":149210,"dwt":153594,"length":369,"width":51}
#
# PACIFIC CORAL {"Company_Name":"PACIFIC CORAL","ship_name":"Bulk Carrier","built_year":1995,"gt":148169,"dwt":265278,"length":324,"width":56}
#
# YM WHOLESOME {"Company_Name":"YM WHOLESOME","ship_name":"Container Ship","built_year":2015,"gt":145324,"dwt":145502,"length":368,"width":51}
#
# DIAMOND GAS ROSE {"Company_Name":"DIAMOND GAS ROSE","ship_name":"LNG Tanker","built_year":2018,"gt":144828,"dwt":94145,"length":294,"width":49}
#
# ULSAN EXPRESS {"Company_Name":"ULSAN EXPRESS","ship_name":"Container Ship","built_year":2014,"gt":143262,"dwt":142023,"length":367,"width":48}
#
# HYUNDAI PRIDE {"Company_Name":"HYUNDAI PRIDE","ship_name":"Container Ship","built_year":2014,"gt":142620,"dwt":145683,"length":366,"width":48}
#
# COSCO GLORY {"Company_Name":"COSCO GLORY","ship_name":"Container Ship","built_year":2011,"gt":141823,"dwt":140637,"length":366,"width":48}
#
# MAERSK ESSEN {"Company_Name":"MAERSK ESSEN","ship_name":"Container Ship","built_year":2010,"gt":141716,"dwt":148723,"length":366,"width":48}
#
# CELEBRITY BEYOND {"Company_Name":"CELEBRITY BEYOND","ship_name":"Passenger (Cruise) Ship","built_year":2022,"gt":141420,"dwt":13991,"length":306,"width":39}
#
# OOCL POLAND {"Company_Name":"OOCL POLAND","ship_name":"Container Ship","built_year":2013,"gt":141003,"dwt":144342,"length":366,"width":48}
#
# MARINER OF THE SEAS {"Company_Name":"MARINER OF THE SEAS","ship_name":"Passenger (Cruise) Ship","built_year":2003,"gt":139863,"dwt":9616,"length":311,"width":39}
#
# ONAIZA {"Company_Name":"ONAIZA","ship_name":"LNG Tanker","built_year":2009,"gt":136980,"dwt":121939,"length":315,"width":50}
#
# AL GHARRAFA {"Company_Name":"AL GHARRAFA","ship_name":"LNG Tanker","built_year":2008,"gt":136410,"dwt":106898,"length":315,"width":50}
#
# BERGE ELBRUS {"Company_Name":"BERGE ELBRUS","ship_name":"Bulk Carrier","built_year":2015,"gt":135472,"dwt":250379,"length":325,"width":57}
#
# SERI CAMELLIA {"Company_Name":"SERI CAMELLIA","ship_name":"LNG Tanker","built_year":2016,"gt":133948,"dwt":84333,"length":290,"width":46}
#
# INDIGO HOPE {"Company_Name":"INDIGO HOPE","ship_name":"Bulk Carrier","built_year":2013,"gt":132508,"dwt":251019,"length":330,"width":57}
#
# PETROBRAS-47 {"Company_Name":"PETROBRAS-47","ship_name":"Offshore Support Vessel","built_year":1976,"gt":131242,"dwt":260349,"length":344,"width":52}
#
# MARVEL EAGLE {"Company_Name":"MARVEL EAGLE","ship_name":"LNG Tanker","built_year":2018,"gt":128917,"dwt":83571,"length":300,"width":49}
#
# ENSHU MARU {"Company_Name":"ENSHU MARU","ship_name":"LNG Tanker","built_year":2018,"gt":127088,"dwt":83708,"length":293,"width":49}
#
# ALTO ACRUX {"Company_Name":"ALTO ACRUX","ship_name":"LNG Tanker","built_year":2008,"gt":122361,"dwt":80229,"length":288,"width":49}
#
# LNG JUPITER {"Company_Name":"LNG JUPITER","ship_name":"LNG Tanker","built_year":2009,"gt":121675,"dwt":81950,"length":290,"width":49}
#
# ENERGY FRONTIER {"Company_Name":"ENERGY FRONTIER","ship_name":"LNG Tanker","built_year":2003,"gt":119393,"dwt":73795,"length":290,"width":49}
#
# ELISA AQUILA {"Company_Name":"ELISA AQUILA","ship_name":"LNG Tanker","built_year":2022,"gt":118753,"dwt":95131,"length":297,"width":47}
#
# YM TUTORIAL {"Company_Name":"YM TUTORIAL","ship_name":"Container Ship","built_year":2022,"gt":118523,"dwt":136899,"length":333,"width":48}
#
# EVER FUTURE {"Company_Name":"EVER FUTURE","ship_name":"Container Ship","built_year":2021,"gt":117340,"dwt":127076,"length":334,"width":48}
#
# UMM AL ASHTAN {"Company_Name":"UMM AL ASHTAN","ship_name":"LNG Tanker","built_year":1997,"gt":116703,"dwt":73100,"length":290,"width":48}
#
# CSCL SOUTH CHINA SEA {"Company_Name":"CSCL SOUTH CHINA SEA","ship_name":"Container Ship","built_year":2014,"gt":116568,"dwt":121185,"length":335,"width":49}
#
# COOL RACER {"Company_Name":"COOL RACER","ship_name":"LNG Tanker","built_year":2021,"gt":116354,"dwt":93423,"length":299,"width":46}
#
# VENTURA {"Company_Name":"VENTURA","ship_name":"Passenger (Cruise) Ship","built_year":2008,"gt":116017,"dwt":8044,"length":289,"width":36}
#
# GASLOG GEORGETOWN {"Company_Name":"GASLOG GEORGETOWN","ship_name":"LNG Tanker","built_year":2020,"gt":115636,"dwt":88184,"length":293,"width":46}
#
# BW ENN SNOW LOTUS {"Company_Name":"BW ENN SNOW LOTUS","ship_name":"LNG Tanker","built_year":2022,"gt":115373,"dwt":93980,"length":295,"width":46}
#
# PAN AFRICA {"Company_Name":"PAN AFRICA","ship_name":"LNG Tanker","built_year":2019,"gt":114996,"dwt":88438,"length":290,"width":47}
#
# BW PAVILIONARANTHERA {"Company_Name":"BW PAVILIONARANTHERA","ship_name":"LNG Tanker","built_year":2020,"gt":114622,"dwt":95788,"length":295,"width":46}
#
# SPIRIT OF HELA {"Company_Name":"SPIRIT OF HELA","ship_name":"LNG Tanker","built_year":2010,"gt":114277,"dwt":87130,"length":298,"width":46}
#
# BEIDOU STAR {"Company_Name":"BEIDOU STAR","ship_name":"LNG Tanker","built_year":2015,"gt":114166,"dwt":96355,"length":290,"width":47}
#
# EXPRESS ROME {"Company_Name":"EXPRESS ROME","ship_name":"Container Ship","built_year":2011,"gt":113973,"dwt":122961,"length":349,"width":46}
#
# MARAN GAS ANDROS {"Company_Name":"MARAN GAS ANDROS","ship_name":"LNG Tanker","built_year":2019,"gt":113793,"dwt":94638,"length":295,"width":46}
#
# MACOMA {"Company_Name":"MACOMA","ship_name":"LNG Tanker","built_year":2017,"gt":113557,"dwt":95253,"length":295,"width":46}
#
# NAVIOS UNISON {"Company_Name":"NAVIOS UNISON","ship_name":"Container Ship","built_year":2010,"gt":113412,"dwt":118800,"length":350,"width":46}
#
# FLEX ENDEAVOUR {"Company_Name":"FLEX ENDEAVOUR","ship_name":"LNG Tanker","built_year":2018,"gt":113049,"dwt":95803,"length":295,"width":46}
#
# SEASPAN THAMES {"Company_Name":"SEASPAN THAMES","ship_name":"Container Ship","built_year":2014,"gt":112967,"dwt":115304,"length":337,"width":48}
#
# GASLOG GENEVA {"Company_Name":"GASLOG GENEVA","ship_name":"LNG Tanker","built_year":2016,"gt":112764,"dwt":87760,"length":291,"width":46}
#
# CMA CGM PELLEAS {"Company_Name":"CMA CGM PELLEAS","ship_name":"Container Ship","built_year":2008,"gt":111249,"dwt":120854,"length":350,"width":43}
#
# ISH {"Company_Name":"ISH","ship_name":"FSO","built_year":1995,"gt":110895,"dwt":71564,"length":293,"width":46}
#
# CARNIVAL CONQUEST {"Company_Name":"CARNIVAL CONQUEST","ship_name":"Passenger (Cruise) Ship","built_year":2002,"gt":110475,"dwt":10000,"length":290,"width":36}
#
# GOLDEN SPRAY {"Company_Name":"GOLDEN SPRAY","ship_name":"Bulk Carrier","built_year":2021,"gt":109716,"dwt":210667,"length":300,"width":49}
#
# APL MIAMI {"Company_Name":"APL MIAMI","ship_name":"Container Ship","built_year":2014,"gt":109712,"dwt":115036,"length":328,"width":45}
#
# ZIM YANTIAN {"Company_Name":"ZIM YANTIAN","ship_name":"Container Ship","built_year":2006,"gt":109149,"dwt":107492,"length":351,"width":43}
#
# CAPE BROLGA {"Company_Name":"CAPE BROLGA","ship_name":"Bulk Carrier","built_year":2021,"gt":108697,"dwt":211982,"length":300,"width":50}
#
# MINERAL YANGFAN {"Company_Name":"MINERAL YANGFAN","ship_name":"Bulk Carrier","built_year":2019,"gt":108130,"dwt":206392,"length":300,"width":50}
#
# MINERAL HIROSHIGE {"Company_Name":"MINERAL HIROSHIGE","ship_name":"Bulk Carrier","built_year":2019,"gt":107916,"dwt":208572,"length":300,"width":50}
#
# GUANG LI HAI {"Company_Name":"GUANG LI HAI","ship_name":"Bulk Carrier","built_year":2017,"gt":107844,"dwt":207241,"length":300,"width":50}
#
# GOLDEN COMFORT {"Company_Name":"GOLDEN COMFORT","ship_name":"Bulk Carrier","built_year":2020,"gt":107737,"dwt":208385,"length":300,"width":50}
#
# HENRIETTE OLDENDORFF {"Company_Name":"HENRIETTE OLDENDORFF","ship_name":"Bulk Carrier","built_year":2016,"gt":107700,"dwt":209067,"length":300,"width":50}
#
# LINDA OLDENDORFF {"Company_Name":"LINDA OLDENDORFF","ship_name":"Bulk Carrier","built_year":2014,"gt":107553,"dwt":207562,"length":300,"width":50}
#
# FRIEDRICH OLDENDORFF {"Company_Name":"FRIEDRICH OLDENDORFF","ship_name":"Bulk Carrier","built_year":2020,"gt":107450,"dwt":208822,"length":300,"width":50}
#
# SAMJOHN DREAM {"Company_Name":"SAMJOHN DREAM","ship_name":"Bulk Carrier","built_year":2012,"gt":107198,"dwt":206610,"length":300,"width":50}
#
# FPMC B NATURE {"Company_Name":"FPMC B NATURE","ship_name":"Bulk Carrier","built_year":2015,"gt":107026,"dwt":207987,"length":300,"width":50}
#
# MATHILDE OLDENDORFF {"Company_Name":"MATHILDE OLDENDORFF","ship_name":"Bulk Carrier","built_year":2013,"gt":106847,"dwt":206080,"length":300,"width":50}
#
# CAPE SASANQUA {"Company_Name":"CAPE SASANQUA","ship_name":"Bulk Carrier","built_year":2011,"gt":106413,"dwt":207860,"length":300,"width":50}
#
# BAO GUO {"Company_Name":"BAO GUO","ship_name":"Bulk Carrier","built_year":2007,"gt":106367,"dwt":207875,"length":300,"width":50}
#
# C.S. BRILLIANCE {"Company_Name":"C.S. BRILLIANCE","ship_name":"Bulk Carrier","built_year":2019,"gt":105964,"dwt":208480,"length":300,"width":50}
#
# ONE ARCADIA {"Company_Name":"ONE ARCADIA","ship_name":"Container Ship","built_year":2011,"gt":105644,"dwt":95660,"length":332,"width":45}
#
# NETADOLA {"Company_Name":"NETADOLA","ship_name":"Bulk Carrier","built_year":2007,"gt":104721,"dwt":206312,"length":300,"width":50}
#
# MARAN GAS DELPHI {"Company_Name":"MARAN GAS DELPHI","ship_name":"LNG Tanker","built_year":2014,"gt":103928,"dwt":89670,"length":294,"width":44}
#
# COSTA FORTUNA {"Company_Name":"COSTA FORTUNA","ship_name":"Passenger (Cruise) Ship","built_year":2003,"gt":102669,"dwt":8200,"length":272,"width":36}
#
# KOOL CRYSTAL {"Company_Name":"KOOL CRYSTAL","ship_name":"LNG Tanker","built_year":2014,"gt":102100,"dwt":82058,"length":286,"width":43}
#
# CAPE KORI {"Company_Name":"CAPE KORI","ship_name":"Bulk Carrier","built_year":2004,"gt":101933,"dwt":203277,"length":300,"width":50}
#
# EVER LISSOME {"Company_Name":"EVER LISSOME","ship_name":"Container Ship","built_year":2014,"gt":101063,"dwt":103891,"length":335,"width":46}
#
# ATLANTIC SEA {"Company_Name":"ATLANTIC SEA","ship_name":"Container Ship","built_year":2016,"gt":100430,"dwt":55738,"length":296,"width":38}
#
# EVER LIVELY {"Company_Name":"EVER LIVELY","ship_name":"Container Ship","built_year":2014,"gt":99995,"dwt":103668,"length":335,"width":46}
#
# MEIN SCHIFF 3 {"Company_Name":"MEIN SCHIFF 3","ship_name":"Passenger (Cruise) Ship","built_year":2014,"gt":99526,"dwt":7900,"length":293,"width":42}
#
# LNG IMO {"Company_Name":"LNG IMO","ship_name":"LNG Tanker","built_year":2008,"gt":98798,"dwt":83688,"length":288,"width":43}
#
# AMALI {"Company_Name":"AMALI","ship_name":"LNG Tanker","built_year":2011,"gt":98490,"dwt":72800,"length":284,"width":43}
#
# NYK VENUS {"Company_Name":"NYK VENUS","ship_name":"Container Ship","built_year":2007,"gt":97825,"dwt":103207,"length":338,"width":46}
#
# ENERGOS MARIA {"Company_Name":"ENERGOS MARIA","ship_name":"LNG Tanker","built_year":2006,"gt":97491,"dwt":84823,"length":277,"width":43}
#
# TRAIGUEN {"Company_Name":"TRAIGUEN","ship_name":"Container Ship","built_year":2013,"gt":96628,"dwt":116384,"length":300,"width":48}
#
# MSC ELODIE {"Company_Name":"MSC ELODIE","ship_name":"Container Ship","built_year":2015,"gt":96333,"dwt":127360,"length":300,"width":48}
#
# CMA CGM JEAN GABRIEL {"Company_Name":"CMA CGM JEAN GABRIEL","ship_name":"Container Ship","built_year":2018,"gt":96223,"dwt":110200,"length":300,"width":48}
#
# MSC ELAINE {"Company_Name":"MSC ELAINE","ship_name":"Container Ship","built_year":2009,"gt":95681,"dwt":98968,"length":340,"width":46}
#
# MSC JEONGMIN {"Company_Name":"MSC JEONGMIN","ship_name":"Container Ship","built_year":2016,"gt":95514,"dwt":110482,"length":300,"width":48}
#
# MSC AZOV {"Company_Name":"MSC AZOV","ship_name":"Container Ship","built_year":2014,"gt":95166,"dwt":112434,"length":300,"width":48}
#
# STAR OPHELIA {"Company_Name":"STAR OPHELIA","ship_name":"Bulk Carrier","built_year":2010,"gt":95047,"dwt":180716,"length":292,"width":45}
#
# GOLAR ARCTIC {"Company_Name":"GOLAR ARCTIC","ship_name":"LNG Tanker","built_year":2003,"gt":94934,"dwt":74894,"length":280,"width":43}
#
# SG FOUNDATION {"Company_Name":"SG FOUNDATION","ship_name":"Bulk Carrier","built_year":2009,"gt":94863,"dwt":180403,"length":295,"width":46}
#
# RAMBO {"Company_Name":"RAMBO","ship_name":"Bulk Carrier","built_year":2003,"gt":94779,"dwt":184872,"length":290,"width":47}
#
# EVER DEVOTION {"Company_Name":"EVER DEVOTION","ship_name":"Bulk Carrier","built_year":2012,"gt":94710,"dwt":180125,"length":295,"width":46}
#
# MILLIE {"Company_Name":"MILLIE","ship_name":"Bulk Carrier","built_year":2009,"gt":94710,"dwt":180311,"length":295,"width":46}
#
# COSCOSHIPPING DANUBE {"Company_Name":"COSCOSHIPPING DANUBE","ship_name":"Container Ship","built_year":2016,"gt":94623,"dwt":111290,"length":300,"width":48}
#
# WANG MAY {"Company_Name":"WANG MAY","ship_name":"Bulk Carrier","built_year":2019,"gt":94528,"dwt":180682,"length":292,"width":45}
#
# MSC AGADIR {"Company_Name":"MSC AGADIR","ship_name":"Container Ship","built_year":2012,"gt":94453,"dwt":112516,"length":299,"width":48}
#
# JUDITH SCHULTE {"Company_Name":"JUDITH SCHULTE","ship_name":"Container Ship","built_year":2013,"gt":94402,"dwt":111861,"length":300,"width":48}
#
# MARIPERLA {"Company_Name":"MARIPERLA","ship_name":"Bulk Carrier","built_year":2009,"gt":94232,"dwt":179759,"length":292,"width":45}
#
# DISHA {"Company_Name":"DISHA","ship_name":"LNG Tanker","built_year":2004,"gt":94058,"dwt":81097,"length":277,"width":43}
#
# MARIGO P {"Company_Name":"MARIGO P","ship_name":"Bulk Carrier","built_year":2016,"gt":94009,"dwt":179218,"length":292,"width":45}
#
# HL GLADSTONE {"Company_Name":"HL GLADSTONE","ship_name":"Bulk Carrier","built_year":2011,"gt":93872,"dwt":179851,"length":292,"width":45}
#
# VIENNA EXPRESS {"Company_Name":"VIENNA EXPRESS","ship_name":"Container Ship","built_year":2010,"gt":93750,"dwt":103648,"length":335,"width":43}
#
# CAPE CORMORANT {"Company_Name":"CAPE CORMORANT","ship_name":"Bulk Carrier","built_year":2022,"gt":93719,"dwt":181500,"length":292,"width":45}
#
# CORCOVADO {"Company_Name":"CORCOVADO","ship_name":"Container Ship","built_year":2015,"gt":93685,"dwt":116933,"length":300,"width":48}
#
# MEYNELL {"Company_Name":"MEYNELL","ship_name":"Bulk Carrier","built_year":1997,"gt":93629,"dwt":185767,"length":292,"width":48}
#
# GLOVIS ADVANCE {"Company_Name":"GLOVIS ADVANCE","ship_name":"Bulk Carrier","built_year":2012,"gt":93544,"dwt":179217,"length":292,"width":45}
#
# MAERSK SYDNEY {"Company_Name":"MAERSK SYDNEY","ship_name":"Container Ship","built_year":2005,"gt":93511,"dwt":102861,"length":335,"width":43}
#
# HL SALDANHA BAY {"Company_Name":"HL SALDANHA BAY","ship_name":"Bulk Carrier","built_year":2010,"gt":93461,"dwt":179147,"length":292,"width":45}
#
# PAROS {"Company_Name":"PAROS","ship_name":"Bulk Carrier","built_year":2010,"gt":93360,"dwt":182060,"length":292,"width":45}
#
# GENCO TIGER {"Company_Name":"GENCO TIGER","ship_name":"Bulk Carrier","built_year":2011,"gt":93290,"dwt":179185,"length":292,"width":45}
#
# CAPE KEYSTONE {"Company_Name":"CAPE KEYSTONE","ship_name":"Bulk Carrier","built_year":2011,"gt":93227,"dwt":179250,"length":292,"width":45}
#
# WINNING SPIRIT {"Company_Name":"WINNING SPIRIT","ship_name":"Bulk Carrier","built_year":2011,"gt":93175,"dwt":179213,"length":292,"width":45}
#
# SEAUNITY {"Company_Name":"SEAUNITY","ship_name":"Bulk Carrier","built_year":2010,"gt":93074,"dwt":181360,"length":292,"width":45}
#
# TRUE CAPTAIN {"Company_Name":"TRUE CAPTAIN","ship_name":"Bulk Carrier","built_year":2016,"gt":92992,"dwt":180981,"length":292,"width":45}
#
# EREIKOUSSA {"Company_Name":"EREIKOUSSA","ship_name":"Bulk Carrier","built_year":2012,"gt":92865,"dwt":178896,"length":292,"width":45}
#
# LAKE D {"Company_Name":"LAKE D","ship_name":"Bulk Carrier","built_year":2011,"gt":92752,"dwt":181458,"length":292,"width":45}
#
# KINOKAWA MARU {"Company_Name":"KINOKAWA MARU","ship_name":"Bulk Carrier","built_year":2013,"gt":92752,"dwt":181392,"length":292,"width":45}
#
# BERGE MAWSON {"Company_Name":"BERGE MAWSON","ship_name":"Bulk Carrier","built_year":2015,"gt":92732,"dwt":181160,"length":292,"width":45}
#
# THALASSINI NJORD {"Company_Name":"THALASSINI NJORD","ship_name":"Bulk Carrier","built_year":2016,"gt":92696,"dwt":181218,"length":292,"width":45}
#
# NAVIOS CANARY {"Company_Name":"NAVIOS CANARY","ship_name":"Bulk Carrier","built_year":2015,"gt":92379,"dwt":180528,"length":292,"width":45}
#
# GOLDEN BEIJING {"Company_Name":"GOLDEN BEIJING","ship_name":"Bulk Carrier","built_year":2010,"gt":92270,"dwt":175820,"length":292,"width":45}
#
# SKAGEN MAERSK {"Company_Name":"SKAGEN MAERSK","ship_name":"Container Ship","built_year":1999,"gt":92198,"dwt":110387,"length":347,"width":43}
#
# OOCL UTAH {"Company_Name":"OOCL UTAH","ship_name":"Container Ship","built_year":2015,"gt":92111,"dwt":101279,"length":335,"width":43}
#
# CAPE SUN {"Company_Name":"CAPE SUN","ship_name":"Bulk Carrier","built_year":2010,"gt":92050,"dwt":175611,"length":292,"width":45}
#
# CIC ROLACO {"Company_Name":"CIC ROLACO","ship_name":"Bulk Carrier","built_year":2012,"gt":91971,"dwt":175641,"length":292,"width":45}
#
# CAPE SANDRA {"Company_Name":"CAPE SANDRA","ship_name":"Bulk Carrier","built_year":2011,"gt":91910,"dwt":175607,"length":290,"width":45}
#
# MALINDI {"Company_Name":"MALINDI","ship_name":"Bulk Carrier","built_year":2008,"gt":91739,"dwt":177987,"length":292,"width":45}
#
# CAPE SHANGHAI {"Company_Name":"CAPE SHANGHAI","ship_name":"Bulk Carrier","built_year":2012,"gt":91625,"dwt":176460,"length":292,"width":45}
#
# OOCL TAIPEI {"Company_Name":"OOCL TAIPEI","ship_name":"Container Ship","built_year":2015,"gt":91499,"dwt":101147,"length":335,"width":43}
#
# AFALES {"Company_Name":"AFALES","ship_name":"Bulk Carrier","built_year":2012,"gt":91407,"dwt":177935,"length":292,"width":45}
#
# EDWARD N {"Company_Name":"EDWARD N","ship_name":"Bulk Carrier","built_year":2011,"gt":91374,"dwt":176216,"length":292,"width":45}
#
# CASTA DIVA {"Company_Name":"CASTA DIVA","ship_name":"Bulk Carrier","built_year":2011,"gt":91373,"dwt":177807,"length":292,"width":45}
#
# LILA NINGBO {"Company_Name":"LILA NINGBO","ship_name":"Bulk Carrier","built_year":2002,"gt":91178,"dwt":175775,"length":282,"width":45}
#
# COSCO VIETNAM {"Company_Name":"COSCO VIETNAM","ship_name":"Container Ship","built_year":2011,"gt":91051,"dwt":102875,"length":334,"width":43}
#
# BILBAO KNUTSEN {"Company_Name":"BILBAO KNUTSEN","ship_name":"LNG Tanker","built_year":2004,"gt":90835,"dwt":77217,"length":284,"width":43}
#
# BAO CHANG HAI {"Company_Name":"BAO CHANG HAI","ship_name":"Bulk Carrier","built_year":1990,"gt":90633,"dwt":173329,"length":290,"width":46}
#
# HONORSHIP {"Company_Name":"HONORSHIP","ship_name":"Bulk Carrier","built_year":2010,"gt":90423,"dwt":180242,"length":289,"width":45}
#
# MARAN TRANSPORTER {"Company_Name":"MARAN TRANSPORTER","ship_name":"Bulk Carrier","built_year":2010,"gt":90136,"dwt":179719,"length":292,"width":45}
#
# MARAN ASTRONOMER {"Company_Name":"MARAN ASTRONOMER","ship_name":"Bulk Carrier","built_year":2012,"gt":90104,"dwt":179719,"length":292,"width":45}
#
# WINNING LOYALTY {"Company_Name":"WINNING LOYALTY","ship_name":"Bulk Carrier","built_year":2004,"gt":90091,"dwt":180310,"length":289,"width":45}
#
# BRAVE SAILOR {"Company_Name":"BRAVE SAILOR","ship_name":"Bulk Carrier","built_year":2011,"gt":89991,"dwt":176283,"length":292,"width":45}

# %%
len(ship_technical_specs.keys())
# Out:
# 4357

# %%
ship_technical_specs = data_dict | ship_technical_specs
# Out:
# {9810654: '{"Company_Name":"PRELUDE","ship_name":"Offshore Support Vessel","built_year":2017,"gt":499167,"dwt":394330,"length":489,"width":74}',
#  9934735: '{"Company_Name":"MSC LORETO","ship_name":"Container Ship","built_year":2023,"gt":236184,"dwt":240000,"length":399,"width":60}',
#  9839478: '{"Company_Name":"MSC FEBE","ship_name":"Container Ship","built_year":2019,"gt":232618,"dwt":228149,"length":400,"width":62}',
#  9839284: '{"Company_Name":"MSC ARINA","ship_name":"Container Ship","built_year":2019,"gt":228741,"dwt":228111,"length":400,"width":61}',
#  9832717: '{"Company_Name":"EVER GOVERN","ship_name":"Container Ship","built_year":2019,"gt":219688,"dwt":198937,"length":400,"width":59}',
#  9780483: '{"Company_Name":"MAASTRICHT MAERSK","ship_name":"Container Ship","built_year":2019,"gt":214286,"dwt":190326,"length":399,"width":59}',
#  9773222: '{"Company_Name":"ONE TREASURE","ship_name":"Container Ship","built_year":2018,"gt":210691,"dwt":189766,"length":400,"width":58}',
#  9708851: '{"Company_Name":"BARZAN","ship_name":"Container Ship","built_year":2015,"gt":195636,"dwt":199744,"length":400,"width":59}',
#  9619971: '{"Company_Name":"MARSTAL MAERSK","ship_name":"Container Ship","built_year":2014,"gt":194849,"dwt":213971,"length":399,"width":59}',
#  9755933: '{"Company_Name":"MSC DIANA","ship_name":"Container Ship","built_year":2016,"gt":194250,"dwt":202036,"length":400,"width":59}',
#  9781891: '{"Company_Name":"COSTA TOSCANA","ship_name":"Passenger (Cruise) Ship","built_year":2021,"gt":186364,"dwt":13000,"length":337,"width":42}',
#  9606314: '{"Company_Name":"MSC NEW YORK","ship_name":"Container Ship","built_year":2014,"gt":176490,"dwt":186766,"length":399,"width":54}',
#  9760512: '{"Company_Name":"MSC MERAVIGLIA","ship_name":"Passenger (Cruise) Ship","built_year":2017,"gt":171598,"dwt":12200,"length":316,"width":43}',
#  9403152: '{"Company_Name":"ATHERINA","ship_name":"Crude Oil Tanker","built_year":2011,"gt":169919,"dwt":319471,"length":340,"width":60}',
#  9372743: '{"Company_Name":"AL GHUWAIRIYA","ship_name":"LNG Tanker","built_year":2008,"gt":168189,"dwt":154940,"length":345,"width":55}',
#  9689988: '{"Company_Name":"NEW PROSPERITY","ship_name":"Crude Oil Tanker","built_year":2015,"gt":165209,"dwt":318607,"length":333,"width":60}',
#  9486506: '{"Company_Name":"NEW WISDOM","ship_name":"Crude Oil Tanker","built_year":2011,"gt":164680,"dwt":317960,"length":333,"width":60}',
#  9484730: '{"Company_Name":"NISALAH","ship_name":"Crude Oil Tanker","built_year":2010,"gt":162863,"dwt":319287,"length":333,"width":60}',
#  9378541: '{"Company_Name":"JAHAM","ship_name":"Crude Oil Tanker","built_year":2008,"gt":162252,"dwt":319430,"length":332,"width":60}',
#  9727039: '{"Company_Name":"SEAWAYS DIAMOND HEAD","ship_name":"Crude Oil Tanker","built_year":2016,"gt":161319,"dwt":299989,"length":333,"width":60}',
#  9844277: '{"Company_Name":"OLYMPIC LIFE","ship_name":"Crude Oil Tanker","built_year":2019,"gt":160874,"dwt":318676,"length":333,"width":60}',
#  9519717: '{"Company_Name":"AWTAD","ship_name":"Crude Oil Tanker","built_year":2011,"gt":160493,"dwt":309988,"length":333,"width":60}',
#  9260079: '{"Company_Name":"PIONEER","ship_name":"Crude Oil Tanker","built_year":1999,"gt":160216,"dwt":306397,"length":334,"width":58}',
#  9389899: '{"Company_Name":"BASRA","ship_name":"Crude Oil Tanker","built_year":2021,"gt":160087,"dwt":298981,"length":339,"width":60}',
#  9468322: '{"Company_Name":"NEW PEARL","ship_name":"Crude Oil Tanker","built_year":2011,"gt":160043,"dwt":301866,"length":333,"width":60}',
#  9799123: '{"Company_Name":"NEW PRIME","ship_name":"Crude Oil Tanker","built_year":2018,"gt":159843,"dwt":311003,"length":333,"width":60}',
#  9604079: '{"Company_Name":"MAXIM","ship_name":"Crude Oil Tanker","built_year":2011,"gt":157351,"dwt":296887,"length":330,"width":60}',
#  9486532: '{"Company_Name":"NEW PIONEER","ship_name":"Crude Oil Tanker","built_year":2010,"gt":157052,"dwt":297058,"length":330,"width":60}',
#  9398058: '{"Company_Name":"NEW PROSPECT","ship_name":"Crude Oil Tanker","built_year":2009,"gt":156921,"dwt":297934,"length":330,"width":60}',
#  9933585: '{"Company_Name":"SEAWAYS ENTERPRISE","ship_name":"Crude Oil Tanker","built_year":2023,"gt":156186,"dwt":300000,"length":336,"width":60}',
#  9923487: '{"Company_Name":"YIANNIS LATSIS","ship_name":"Crude Oil Tanker","built_year":2022,"gt":154792,"dwt":299999,"length":330,"width":60}',
#  9323792: '{"Company_Name":"ALICE","ship_name":"Crude Oil Tanker","built_year":2016,"gt":154379,"dwt":299320,"length":333,"width":60}',
#  9783734: '{"Company_Name":"SEAPASSION","ship_name":"Crude Oil Tanker","built_year":2017,"gt":154182,"dwt":299271,"length":333,"width":60}',
#  9784295: '{"Company_Name":"MAERSK HANOI","ship_name":"Container Ship","built_year":2018,"gt":153773,"dwt":178257,"length":353,"width":54}',
#  9745366: '{"Company_Name":"MSC SEASIDE","ship_name":"Passenger (Cruise) Ship","built_year":2017,"gt":153516,"dwt":19209,"length":323,"width":41}',
#  9461439: '{"Company_Name":"MSC VALERIA","ship_name":"Container Ship","built_year":2012,"gt":153115,"dwt":165966,"length":366,"width":51}',
#  9808314: '{"Company_Name":"GEMMA","ship_name":"Bulk Carrier","built_year":2012,"gt":151915,"dwt":313049,"length":330,"width":57}',
#  9867841: '{"Company_Name":"CMA CGM ARCTIC","ship_name":"Container Ship","built_year":2022,"gt":150844,"dwt":159614,"length":366,"width":51}',
#  9857171: '{"Company_Name":"MSC VIRGO","ship_name":"Container Ship","built_year":2020,"gt":149525,"dwt":158097,"length":366,"width":48}',
#  9728954: '{"Company_Name":"THESEUS","ship_name":"Container Ship","built_year":2016,"gt":149210,"dwt":153594,"length":369,"width":51}',
#  9893113: '{"Company_Name":"PACIFIC CORAL","ship_name":"Bulk Carrier","built_year":1995,"gt":148169,"dwt":265278,"length":324,"width":56}',
#  9704611: '{"Company_Name":"YM WHOLESOME","ship_name":"Container Ship","built_year":2015,"gt":145324,"dwt":145502,"length":368,"width":51}',
#  9779238: '{"Company_Name":"DIAMOND GAS ROSE","ship_name":"LNG Tanker","built_year":2018,"gt":144828,"dwt":94145,"length":294,"width":49}',
#  9613020: '{"Company_Name":"ULSAN EXPRESS","ship_name":"Container Ship","built_year":2014,"gt":143262,"dwt":142023,"length":367,"width":48}',
#  9466245: '{"Company_Name":"COSCO GLORY","ship_name":"Container Ship","built_year":2011,"gt":141823,"dwt":140637,"length":366,"width":48}',
#  9456783: '{"Company_Name":"MAERSK ESSEN","ship_name":"Container Ship","built_year":2010,"gt":141716,"dwt":148723,"length":366,"width":48}',
#  9838395: '{"Company_Name":"CELEBRITY BEYOND","ship_name":"Passenger (Cruise) Ship","built_year":2022,"gt":141420,"dwt":13991,"length":306,"width":39}',
#  9227510: '{"Company_Name":"MARINER OF THE SEAS","ship_name":"Passenger (Cruise) Ship","built_year":2003,"gt":139863,"dwt":9616,"length":311,"width":39}',
#  9397353: '{"Company_Name":"ONAIZA","ship_name":"LNG Tanker","built_year":2009,"gt":136980,"dwt":121939,"length":315,"width":50}',
#  9337717: '{"Company_Name":"AL GHARRAFA","ship_name":"LNG Tanker","built_year":2008,"gt":136410,"dwt":106898,"length":315,"width":50}',
#  9714276: '{"Company_Name":"SERI CAMELLIA","ship_name":"LNG Tanker","built_year":2016,"gt":133948,"dwt":84333,"length":290,"width":46}',
#  9759240: '{"Company_Name":"MARVEL EAGLE","ship_name":"LNG Tanker","built_year":2018,"gt":128917,"dwt":83571,"length":300,"width":49}',
#  9749609: '{"Company_Name":"ENSHU MARU","ship_name":"LNG Tanker","built_year":2018,"gt":127088,"dwt":83708,"length":293,"width":49}',
#  9884473: '{"Company_Name":"ELISA AQUILA","ship_name":"LNG Tanker","built_year":2022,"gt":118753,"dwt":95131,"length":297,"width":47}',
#  9645920: '{"Company_Name":"CSCL SOUTH CHINA SEA","ship_name":"Container Ship","built_year":2014,"gt":116568,"dwt":121185,"length":335,"width":49}',
#  9869265: '{"Company_Name":"COOL RACER","ship_name":"LNG Tanker","built_year":2021,"gt":116354,"dwt":93423,"length":299,"width":46}',
#  9333175: '{"Company_Name":"VENTURA","ship_name":"Passenger (Cruise) Ship","built_year":2008,"gt":116017,"dwt":8044,"length":289,"width":36}',
#  9864916: '{"Company_Name":"GASLOG GEORGETOWN","ship_name":"LNG Tanker","built_year":2020,"gt":115636,"dwt":88184,"length":293,"width":46}',
#  9896921: '{"Company_Name":"BW ENN SNOW LOTUS","ship_name":"LNG Tanker","built_year":2022,"gt":115373,"dwt":93980,"length":295,"width":46}',
#  9484936: '{"Company_Name":"EXPRESS ROME","ship_name":"Container Ship","built_year":2011,"gt":113973,"dwt":122961,"length":349,"width":46}',
#  9810379: '{"Company_Name":"MARAN GAS ANDROS","ship_name":"LNG Tanker","built_year":2019,"gt":113793,"dwt":94638,"length":295,"width":46}',
#  9705653: '{"Company_Name":"MACOMA","ship_name":"LNG Tanker","built_year":2017,"gt":113557,"dwt":95253,"length":295,"width":46}',
#  9408853: '{"Company_Name":"NAVIOS UNISON","ship_name":"Container Ship","built_year":2010,"gt":113412,"dwt":118800,"length":350,"width":46}',
#  9762261: '{"Company_Name":"FLEX ENDEAVOUR","ship_name":"LNG Tanker","built_year":2018,"gt":113049,"dwt":95803,"length":295,"width":46}',
#  9630377: '{"Company_Name":"SEASPAN THAMES","ship_name":"Container Ship","built_year":2014,"gt":112967,"dwt":115304,"length":337,"width":48}',
#  9707508: '{"Company_Name":"GASLOG GENEVA","ship_name":"LNG Tanker","built_year":2016,"gt":112764,"dwt":87760,"length":291,"width":46}',
#  9597549: '{"Company_Name":"APL MIAMI","ship_name":"Container Ship","built_year":2014,"gt":109712,"dwt":115036,"length":328,"width":45}',
#  9738571: '{"Company_Name":"MINERAL YANGFAN","ship_name":"Bulk Carrier","built_year":2019,"gt":108130,"dwt":206392,"length":300,"width":50}',
#  9713052: '{"Company_Name":"HENRIETTE OLDENDORFF","ship_name":"Bulk Carrier","built_year":2016,"gt":107700,"dwt":209067,"length":300,"width":50}',
#  9691929: '{"Company_Name":"LINDA OLDENDORFF","ship_name":"Bulk Carrier","built_year":2014,"gt":107553,"dwt":207562,"length":300,"width":50}',
#  9889265: '{"Company_Name":"FRIEDRICH OLDENDORFF","ship_name":"Bulk Carrier","built_year":2020,"gt":107450,"dwt":208822,"length":300,"width":50}',
#  9612064: '{"Company_Name":"SAMJOHN DREAM","ship_name":"Bulk Carrier","built_year":2012,"gt":107198,"dwt":206610,"length":300,"width":50}',
#  9678800: '{"Company_Name":"MATHILDE OLDENDORFF","ship_name":"Bulk Carrier","built_year":2013,"gt":106847,"dwt":206080,"length":300,"width":50}',
#  9468310: '{"Company_Name":"ONE ARCADIA","ship_name":"Container Ship","built_year":2011,"gt":105644,"dwt":95660,"length":332,"width":45}',
#  9633173: '{"Company_Name":"MARAN GAS DELPHI","ship_name":"LNG Tanker","built_year":2014,"gt":103928,"dwt":89670,"length":294,"width":44}',
#  9239783: '{"Company_Name":"COSTA FORTUNA","ship_name":"Passenger (Cruise) Ship","built_year":2003,"gt":102669,"dwt":8200,"length":272,"width":36}',
#  9624926: '{"Company_Name":"KOOL CRYSTAL","ship_name":"LNG Tanker","built_year":2014,"gt":102100,"dwt":82058,"length":286,"width":43}',
#  9271559: '{"Company_Name":"CAPE KORI","ship_name":"Bulk Carrier","built_year":2004,"gt":101933,"dwt":203277,"length":300,"width":50}',
#  9670597: '{"Company_Name":"ATLANTIC SEA","ship_name":"Container Ship","built_year":2016,"gt":100430,"dwt":55738,"length":296,"width":38}',
#  9641730: '{"Company_Name":"MEIN SCHIFF 3","ship_name":"Passenger (Cruise) Ship","built_year":2014,"gt":99526,"dwt":7900,"length":293,"width":42}',
#  9311581: '{"Company_Name":"LNG IMO","ship_name":"LNG Tanker","built_year":2008,"gt":98798,"dwt":83688,"length":288,"width":43}',
#  9312793: '{"Company_Name":"NYK VENUS","ship_name":"Container Ship","built_year":2007,"gt":97825,"dwt":103207,"length":338,"width":46}',
#  9627904: '{"Company_Name":"TRAIGUEN","ship_name":"Container Ship","built_year":2013,"gt":96628,"dwt":116384,"length":300,"width":48}',
#  9704972: '{"Company_Name":"MSC ELODIE","ship_name":"Container Ship","built_year":2015,"gt":96333,"dwt":127360,"length":300,"width":48}',
#  9729128: '{"Company_Name":"CMA CGM JEAN GABRIEL","ship_name":"Container Ship","built_year":2018,"gt":96223,"dwt":110200,"length":300,"width":48}',
#  9393321: '{"Company_Name":"MSC ELAINE","ship_name":"Container Ship","built_year":2009,"gt":95681,"dwt":98968,"length":340,"width":46}',
#  9720471: '{"Company_Name":"MSC JEONGMIN","ship_name":"Container Ship","built_year":2016,"gt":95514,"dwt":110482,"length":300,"width":48}',
#  9605255: '{"Company_Name":"MSC AZOV","ship_name":"Container Ship","built_year":2014,"gt":95166,"dwt":112434,"length":300,"width":48}',
#  9486726: '{"Company_Name":"STAR OPHELIA","ship_name":"Bulk Carrier","built_year":2010,"gt":95047,"dwt":180716,"length":292,"width":45}',
#  9253105: '{"Company_Name":"GOLAR ARCTIC","ship_name":"LNG Tanker","built_year":2003,"gt":94934,"dwt":74894,"length":280,"width":43}',
#  9837327: '{"Company_Name":"WANG MAY","ship_name":"Bulk Carrier","built_year":2019,"gt":94528,"dwt":180682,"length":292,"width":45}',
#  9619464: '{"Company_Name":"MSC AGADIR","ship_name":"Container Ship","built_year":2012,"gt":94453,"dwt":112516,"length":299,"width":48}',
#  9605152: '{"Company_Name":"JUDITH SCHULTE","ship_name":"Container Ship","built_year":2013,"gt":94402,"dwt":111861,"length":300,"width":48}',
#  9447017: '{"Company_Name":"MARIPERLA","ship_name":"Bulk Carrier","built_year":2009,"gt":94232,"dwt":179759,"length":292,"width":45}',
#  9689706: '{"Company_Name":"MARIGO P","ship_name":"Bulk Carrier","built_year":2016,"gt":94009,"dwt":179218,"length":292,"width":45}',
#  9450416: '{"Company_Name":"VIENNA EXPRESS","ship_name":"Container Ship","built_year":2010,"gt":93750,"dwt":103648,"length":335,"width":43}',
#  9942718: '{"Company_Name":"CAPE CORMORANT","ship_name":"Bulk Carrier","built_year":2022,"gt":93719,"dwt":181500,"length":292,"width":45}',
#  9241463: '{"Company_Name":"CORCOVADO","ship_name":"Container Ship","built_year":2015,"gt":93685,"dwt":116933,"length":300,"width":48}',
#  9289958: '{"Company_Name":"MAERSK SYDNEY","ship_name":"Container Ship","built_year":2005,"gt":93511,"dwt":102861,"length":335,"width":43}',
#  9296195: '{"Company_Name":"PAROS","ship_name":"Bulk Carrier","built_year":2010,"gt":93360,"dwt":182060,"length":292,"width":45}',
#  9463334: '{"Company_Name":"CAPE KEYSTONE","ship_name":"Bulk Carrier","built_year":2011,"gt":93227,"dwt":179250,"length":292,"width":45}',
#  9747883: '{"Company_Name":"TRUE CAPTAIN","ship_name":"Bulk Carrier","built_year":2016,"gt":92992,"dwt":180981,"length":292,"width":45}',
#  9591739: '{"Company_Name":"EREIKOUSSA","ship_name":"Bulk Carrier","built_year":2012,"gt":92865,"dwt":178896,"length":292,"width":45}',
#  9590840: '{"Company_Name":"LAKE D","ship_name":"Bulk Carrier","built_year":2011,"gt":92752,"dwt":181458,"length":292,"width":45}',
#  9738868: '{"Company_Name":"BERGE MAWSON","ship_name":"Bulk Carrier","built_year":2015,"gt":92732,"dwt":181160,"length":292,"width":45}',
#  9757838: '{"Company_Name":"THALASSINI NJORD","ship_name":"Bulk Carrier","built_year":2016,"gt":92696,"dwt":181218,"length":292,"width":45}',
#  9439412: '{"Company_Name":"GOLDEN BEIJING","ship_name":"Bulk Carrier","built_year":2010,"gt":92270,"dwt":175820,"length":292,"width":45}',
#  9486087: '{"Company_Name":"OOCL UTAH","ship_name":"Container Ship","built_year":2015,"gt":92111,"dwt":101279,"length":335,"width":43}',
#  9546899: '{"Company_Name":"CAPE SUN","ship_name":"Bulk Carrier","built_year":2010,"gt":92050,"dwt":175611,"length":292,"width":45}',
#  9567116: '{"Company_Name":"CIC ROLACO","ship_name":"Bulk Carrier","built_year":2012,"gt":91971,"dwt":175641,"length":292,"width":45}',
#  9446908: '{"Company_Name":"CAPE SANDRA","ship_name":"Bulk Carrier","built_year":2011,"gt":91910,"dwt":175607,"length":290,"width":45}',
#  9363015: '{"Company_Name":"MALINDI","ship_name":"Bulk Carrier","built_year":2008,"gt":91739,"dwt":177987,"length":292,"width":45}',
#  9619555: '{"Company_Name":"AFALES","ship_name":"Bulk Carrier","built_year":2012,"gt":91407,"dwt":177935,"length":292,"width":45}',
#  9448815: '{"Company_Name":"COSCO VIETNAM","ship_name":"Container Ship","built_year":2011,"gt":91051,"dwt":102875,"length":334,"width":43}',
#  9236432: '{"Company_Name":"BILBAO KNUTSEN","ship_name":"LNG Tanker","built_year":2004,"gt":90835,"dwt":77217,"length":284,"width":43}',
#  9439060: '{"Company_Name":"MARAN TRANSPORTER","ship_name":"Bulk Carrier","built_year":2010,"gt":90136,"dwt":179719,"length":292,"width":45}',
#  9581239: '{"Company_Name":"MARAN ASTRONOMER","ship_name":"Bulk Carrier","built_year":2012,"gt":90104,"dwt":179719,"length":292,"width":45}'}

# %%
with open('../data/raw/ship_technical_specs.json', 'w') as f:
    json.dump(ship_technical_specs, f, indent=4)
